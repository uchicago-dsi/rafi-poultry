# %% [markdown]
# ## Load-In Data

# %%
import pandas as pd
import numpy as np
import folium
import geopandas as gpd

# %%
master = pd.read_csv("../../data/master-df.csv")
master = master.dropna(subset=['LONGITUDE', 'LATITUDE', 'COMPANY'])
arkansas = master.loc[master.STATE == 'AR']
arkansas.drop(columns=['Unnamed: 0']).head(3)
# Out:
#               COMPANY       ADDRESS LINE 1       CITY STATE  ZIPCODE  \
# 8   SIMMONS FOODS INC  2101 TWIN CIRCLE DR  VAN BUREN    AR  72956.0
# 9   SIMMONS FOODS INC  2101 TWIN CIRCLE DR  VAN BUREN    AR  72956.0
# 10  SIMMONS FOODS INC  2101 TWIN CIRCLE DR  VAN BUREN    AR  72956.0
#
#     PRIMARY SIC CODE  ARCHIVE VERSION YEAR  YEAR ESTABLISHED        ABI  \
# 8           201501.0                  2022                 0  512247248
# 9           201501.0                  2021                 0  512247248
# 10          201501.0                  2020                 0  512247248
#
#     COMPANY HOLDING STATUS  PARENT NUMBER   LATITUDE  LONGITUDE  \
# 8                        0        7534076  35.428061 -94.336725
# 9                        0        7534076  35.428061 -94.336725
# 10                       0        7534076  35.428061 -94.336725
#
#     YEAR 1ST APPEARED        PARENT NAME CHANGE_BOOL  CHANGE_NUM
# 8                   0  Simmons Foods Inc        None         1.0
# 9                1999  Simmons Foods Inc        None         1.0
# 10                  0  Simmons Foods Inc        None         1.0

# %%
arkansas.isnull().sum()
# Out:
# Unnamed: 0                 0
# COMPANY                    0
# ADDRESS LINE 1            25
# CITY                       0
# STATE                      0
# ZIPCODE                    0
# PRIMARY SIC CODE           0
# ARCHIVE VERSION YEAR       0
# YEAR ESTABLISHED           0
# ABI                        0
# COMPANY HOLDING STATUS     0
# PARENT NUMBER              0
# LATITUDE                   0
# LONGITUDE                  0
# YEAR 1ST APPEARED          0
# PARENT NAME                0
# CHANGE_BOOL                0
# CHANGE_NUM                 0
# dtype: int64

# %% [markdown]
# ## Separate by Years; Arkansas

# %%
df_2022 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2022].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2021 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2021].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2020 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2020].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2019 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2019].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2018 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2018].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2017 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2017].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2016 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2016].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2015 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2015].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2014 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2014].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2013 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2013].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2012 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2012].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2011 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2011].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2010 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2010].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2009 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2009].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2008 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2008].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2007 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2007].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2006 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2006].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2005 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2005].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2004 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2004].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2003 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2003].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2002 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2002].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2001 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2001].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2000 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2000].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_1999 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 1999].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_1998 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 1998].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_1997 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 1997].reset_index(drop=True).drop(columns=['Unnamed: 0'])

# %% [markdown]
# ## Making Arkansas Maps

# %%
AR_LAT = 35.2010
AR_LNG = -91.8318

# %%
arkansas['PARENT NAME'].value_counts()
# Out:
# Tyson Foods Inc         660
# None                    492
# JBS USA                  89
# Cargil Inc               78
# George's Inc             60
# Simmons Foods Inc        56
# Small Biz                51
# Continental Grain Co     27
# Conagra Brands Inc       27
# Mountaire Corp           24
# Cal-main Foods Inc       23
# Pilgrim's Pride Corp     23
# Peco Foods Inc           12
# Foster Farms              8
# Name: PARENT NAME, dtype: int64

# %%
# create a new column that contains folium color names in order to color-code the map markers

col_dict = dict({'None': 'lightgray', 
                "Tyson Foods Inc": 'green', 
                "Simmons Foods Inc": 'orange', 
                "George's Inc": 'blue', 
                "JBS USA": 'red', 
                "Cargil Inc": 'purple',
                "Small Biz": 'lightgray',
                "Foster Farms": 'lightgray',
                "Conagra Brands Inc": 'lightgray',
                "Peco Foods Inc": 'lightgray',
                "Continental Grain Co": 'lightgray',
                "Mountaire Corp": 'lightgray',
                "Pilgrim's Pride Corp": 'lightgray',
                "Cal-main Foods Inc": 'lightgray'})

# %%
df_2022['COLOR'] = df_2022['PARENT NAME'].map(col_dict)
df_2022.head(3)
# Out:
#              COMPANY       ADDRESS LINE 1            CITY STATE  ZIPCODE  \
# 0  SIMMONS FOODS INC  2101 TWIN CIRCLE DR       VAN BUREN    AR  72956.0
# 1    TYSON FOODS INC         620 TYLER RD    RUSSELLVILLE    AR  72802.0
# 2  SIMMONS FOODS INC  814 S WASHINGTON ST  SILOAM SPRINGS    AR  72761.0
#
#    PRIMARY SIC CODE  ARCHIVE VERSION YEAR  YEAR ESTABLISHED        ABI  \
# 0          201501.0                  2022                 0  512247248
# 1          514704.0                  2022                 0  382158996
# 2          201501.0                  2022              1949  712259047
#
#    COMPANY HOLDING STATUS  PARENT NUMBER   LATITUDE  LONGITUDE  \
# 0                       0        7534076  35.428061 -94.336725
# 1                       0        7537913  35.269775 -93.085968
# 2                       0        7534076  36.177236 -94.537565
#
#    YEAR 1ST APPEARED        PARENT NAME CHANGE_BOOL  CHANGE_NUM   COLOR
# 0                  0  Simmons Foods Inc        None         1.0  orange
# 1                  0    Tyson Foods Inc       False         0.0   green
# 2                  0  Simmons Foods Inc       False         0.0  orange

# %%
# create a map-making functon so I can easily create a new map for each year

def make_map(df, map_name):
    map_name = folium.Map(location=[AR_LAT, AR_LNG],zoom_start=6)
    
    df['COLOR'] = df['PARENT NAME'].map(col_dict)

    for index, location_info in df.iterrows():
        folium.Marker([location_info["LATITUDE"], location_info["LONGITUDE"]], popup = location_info['PARENT NAME'],
                icon=folium.Icon(color=location_info['COLOR'])).add_to(map_name)
        
    display(map_name)

# %%
make_map(df_1997, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d3bf904eaa02a3f607de8f11da3716b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d3bf904eaa02a3f607de8f11da3716b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d3bf904eaa02a3f607de8f11da3716b = L.map(
#                 &quot;map_4d3bf904eaa02a3f607de8f11da3716b&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e02fbe319afb0c085918b83cdf09e2c7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4d3bf904eaa02a3f607de8f11da3716b);
#
#
#             var marker_16a2d65db6133e4b02ff0080a7465ced = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_4d3bf904eaa02a3f607de8f11da3716b);
#
#
#             var icon_4ce9e182070f600f1bb8ed8856e46c5e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16a2d65db6133e4b02ff0080a7465ced.setIcon(icon_4ce9e182070f600f1bb8ed8856e46c5e);
#
#
#         var popup_8697d3135cc9d577b717d6c8f54c4f10 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_60f1cf33d2d1ed19154213ddc8b5f096 = $(`&lt;div id=&quot;html_60f1cf33d2d1ed19154213ddc8b5f096&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_8697d3135cc9d577b717d6c8f54c4f10.setContent(html_60f1cf33d2d1ed19154213ddc8b5f096);
#
#
#
#         marker_16a2d65db6133e4b02ff0080a7465ced.bindPopup(popup_8697d3135cc9d577b717d6c8f54c4f10)
#         ;
#
#
#
#
#             var marker_dae1330d91dae15c21fcf8fbfcede1f0 = L.marker(
#                 [36.33113, -93.42862],
#                 {}
#             ).addTo(map_4d3bf904eaa02a3f607de8f11da3716b);
#
#
#             var icon_ff9c75054859413a9130bb340490fa31 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dae1330d91dae15c21fcf8fbfcede1f0.setIcon(icon_ff9c75054859413a9130bb340490fa31);
#
#
#         var popup_1ba86b4dafb1692d5ca128f4a7220502 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a62fe145a97a529e5d952a00eb1c85d = $(`&lt;div id=&quot;html_9a62fe145a97a529e5d952a00eb1c85d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_1ba86b4dafb1692d5ca128f4a7220502.setContent(html_9a62fe145a97a529e5d952a00eb1c85d);
#
#
#
#         marker_dae1330d91dae15c21fcf8fbfcede1f0.bindPopup(popup_1ba86b4dafb1692d5ca128f4a7220502)
#         ;
#
#
#
#
#             var marker_cd4cc78feea1545d26be7c03e06d3b6e = L.marker(
#                 [36.317124, -94.121375],
#                 {}
#             ).addTo(map_4d3bf904eaa02a3f607de8f11da3716b);
#
#
#             var icon_f0b13455e31bb639b769c22f6a20cc6f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cd4cc78feea1545d26be7c03e06d3b6e.setIcon(icon_f0b13455e31bb639b769c22f6a20cc6f);
#
#
#         var popup_a6816837b22b2b180835cc766a927852 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5566e8b313f275b2c47a1223818641a9 = $(`&lt;div id=&quot;html_5566e8b313f275b2c47a1223818641a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_a6816837b22b2b180835cc766a927852.setContent(html_5566e8b313f275b2c47a1223818641a9);
#
#
#
#         marker_cd4cc78feea1545d26be7c03e06d3b6e.bindPopup(popup_a6816837b22b2b180835cc766a927852)
#         ;
#
#
#
#
#             var marker_ad110d8342c422bb33c41e41352863ba = L.marker(
#                 [36.167844, -94.137676],
#                 {}
#             ).addTo(map_4d3bf904eaa02a3f607de8f11da3716b);
#
#
#             var icon_fadff5a35fbfbeb6acbfdf7f386fa6e7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-

# %%
make_map(df_1998, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b61d7e58f512e7d208d323f847dc942 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b61d7e58f512e7d208d323f847dc942&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b61d7e58f512e7d208d323f847dc942 = L.map(
#                 &quot;map_7b61d7e58f512e7d208d323f847dc942&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_324907befe1e9d933c5ccc4ab819dbb6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7b61d7e58f512e7d208d323f847dc942);
#
#
#             var marker_de5a0f768e8f2c47454a2a0b69db3197 = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_7b61d7e58f512e7d208d323f847dc942);
#
#
#             var icon_f41123d9939ff22e2ffbad16bcbcc52e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_de5a0f768e8f2c47454a2a0b69db3197.setIcon(icon_f41123d9939ff22e2ffbad16bcbcc52e);
#
#
#         var popup_b13fff1d7925a5237433dd4f750fda2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e08ff40009788819d8e7ffe185ea4083 = $(`&lt;div id=&quot;html_e08ff40009788819d8e7ffe185ea4083&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_b13fff1d7925a5237433dd4f750fda2f.setContent(html_e08ff40009788819d8e7ffe185ea4083);
#
#
#
#         marker_de5a0f768e8f2c47454a2a0b69db3197.bindPopup(popup_b13fff1d7925a5237433dd4f750fda2f)
#         ;
#
#
#
#
#             var marker_02dc4b66b96d5a4d9eca8c8d31c273ec = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_7b61d7e58f512e7d208d323f847dc942);
#
#
#             var icon_337eef01a0c9bda55eefb74f7c048ffa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_02dc4b66b96d5a4d9eca8c8d31c273ec.setIcon(icon_337eef01a0c9bda55eefb74f7c048ffa);
#
#
#         var popup_1d84c04d2dac39b95368ed43383c70c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8d94061bb0b6fd2b813f5a083304afb = $(`&lt;div id=&quot;html_e8d94061bb0b6fd2b813f5a083304afb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_1d84c04d2dac39b95368ed43383c70c3.setContent(html_e8d94061bb0b6fd2b813f5a083304afb);
#
#
#
#         marker_02dc4b66b96d5a4d9eca8c8d31c273ec.bindPopup(popup_1d84c04d2dac39b95368ed43383c70c3)
#         ;
#
#
#
#
#             var marker_9afe6cb8ab3d828a66a0ac3d2ec02205 = L.marker(
#                 [36.181573, -94.131369],
#                 {}
#             ).addTo(map_7b61d7e58f512e7d208d323f847dc942);
#
#
#             var icon_092e04ade7c17d3f58e18f7a13416cc9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9afe6cb8ab3d828a66a0ac3d2ec02205.setIcon(icon_092e04ade7c17d3f58e18f7a13416cc9);
#
#
#         var popup_076fa119f78d59f7ee27f5ec7f7674df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a99ddddfaaf0eecf7a7a054e826e093b = $(`&lt;div id=&quot;html_a99ddddfaaf0eecf7a7a054e826e093b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cargil Inc&lt;/div&gt;`)[0];
#                 popup_076fa119f78d59f7ee27f5ec7f7674df.setContent(html_a99ddddfaaf0eecf7a7a054e826e093b);
#
#
#
#         marker_9afe6cb8ab3d828a66a0ac3d2ec02205.bindPopup(popup_076fa119f78d59f7ee27f5ec7f7674df)
#         ;
#
#
#
#
#             var marker_df81cf20eb66fefa24ff938c4ad1963a = L.marker(
#                 [36.035059, -94.169424],
#                 {}
#             ).addTo(map_7b61d7e58f512e7d208d323f847dc942);
#
#
#             var icon_eefce112de6ba7f5d7be1f34fbbd371f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-si

# %%
make_map(df_1999, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09f8c640a0a9d3aee98e63599d150675 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09f8c640a0a9d3aee98e63599d150675&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09f8c640a0a9d3aee98e63599d150675 = L.map(
#                 &quot;map_09f8c640a0a9d3aee98e63599d150675&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d1e75bde4ece8f4f2a2b2a88f8ff978 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_09f8c640a0a9d3aee98e63599d150675);
#
#
#             var marker_f0c07ed982b458611969e9896e1ca936 = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_09f8c640a0a9d3aee98e63599d150675);
#
#
#             var icon_620008113fc9cf355911a9069f584962 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f0c07ed982b458611969e9896e1ca936.setIcon(icon_620008113fc9cf355911a9069f584962);
#
#
#         var popup_87504f3119b4e9ad604ad6edd581684d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b18dcde7a382d383a200ee1cb652d66 = $(`&lt;div id=&quot;html_8b18dcde7a382d383a200ee1cb652d66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_87504f3119b4e9ad604ad6edd581684d.setContent(html_8b18dcde7a382d383a200ee1cb652d66);
#
#
#
#         marker_f0c07ed982b458611969e9896e1ca936.bindPopup(popup_87504f3119b4e9ad604ad6edd581684d)
#         ;
#
#
#
#
#             var marker_1f8c57cbfce9b588d5b1b0621af9a5c0 = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_09f8c640a0a9d3aee98e63599d150675);
#
#
#             var icon_6f96b8cf5599c8796a9b8004937fff88 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1f8c57cbfce9b588d5b1b0621af9a5c0.setIcon(icon_6f96b8cf5599c8796a9b8004937fff88);
#
#
#         var popup_edb5535c478b2a43497a216bd03c9117 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45bb28531800f77c3a94775609030f0a = $(`&lt;div id=&quot;html_45bb28531800f77c3a94775609030f0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_edb5535c478b2a43497a216bd03c9117.setContent(html_45bb28531800f77c3a94775609030f0a);
#
#
#
#         marker_1f8c57cbfce9b588d5b1b0621af9a5c0.bindPopup(popup_edb5535c478b2a43497a216bd03c9117)
#         ;
#
#
#
#
#             var marker_bb1489fc9b46d918f24a102728856e27 = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_09f8c640a0a9d3aee98e63599d150675);
#
#
#             var icon_aff044250465a7d683f39484dc0b8318 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bb1489fc9b46d918f24a102728856e27.setIcon(icon_aff044250465a7d683f39484dc0b8318);
#
#
#         var popup_2c7696bfd3b4111be735779b97441a1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37f694ea5c49cfea091aef2a5892e861 = $(`&lt;div id=&quot;html_37f694ea5c49cfea091aef2a5892e861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_2c7696bfd3b4111be735779b97441a1d.setContent(html_37f694ea5c49cfea091aef2a5892e861);
#
#
#
#         marker_bb1489fc9b46d918f24a102728856e27.bindPopup(popup_2c7696bfd3b4111be735779b97441a1d)
#         ;
#
#
#
#
#             var marker_dd2186845bd384999efcc7b65aa527c8 = L.marker(
#                 [36.18153, -94.13086],
#                 {}
#             ).addTo(map_09f8c640a0a9d3aee98e63599d150675);
#
#
#             var icon_a5091b70babed43fc79e12cdb7b36621 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&qu

# %%
make_map(df_2000, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03630b89ddd2a28798614cb2bb3a1e50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03630b89ddd2a28798614cb2bb3a1e50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03630b89ddd2a28798614cb2bb3a1e50 = L.map(
#                 &quot;map_03630b89ddd2a28798614cb2bb3a1e50&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e410cd2bf6a3cd302e06ca3ec6c5d6f6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_03630b89ddd2a28798614cb2bb3a1e50);
#
#
#             var marker_a8477c658912891074fe800a39643f06 = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_03630b89ddd2a28798614cb2bb3a1e50);
#
#
#             var icon_c48a1d632fee4e0edf19180ff931578f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a8477c658912891074fe800a39643f06.setIcon(icon_c48a1d632fee4e0edf19180ff931578f);
#
#
#         var popup_0dae35150362654ba0c884a3fca01bab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e092e8f98798bf33acdabc10c96a332 = $(`&lt;div id=&quot;html_6e092e8f98798bf33acdabc10c96a332&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_0dae35150362654ba0c884a3fca01bab.setContent(html_6e092e8f98798bf33acdabc10c96a332);
#
#
#
#         marker_a8477c658912891074fe800a39643f06.bindPopup(popup_0dae35150362654ba0c884a3fca01bab)
#         ;
#
#
#
#
#             var marker_34d894aad88824f9d2755493c70cff22 = L.marker(
#                 [35.771495, -91.649756],
#                 {}
#             ).addTo(map_03630b89ddd2a28798614cb2bb3a1e50);
#
#
#             var icon_4530b74c5d6fae8ebbfdea2eb86f1b5e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34d894aad88824f9d2755493c70cff22.setIcon(icon_4530b74c5d6fae8ebbfdea2eb86f1b5e);
#
#
#         var popup_0e19ebc4c60903ed937c973c953bf1a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7408056b95432b916a64ef37a136f14d = $(`&lt;div id=&quot;html_7408056b95432b916a64ef37a136f14d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_0e19ebc4c60903ed937c973c953bf1a9.setContent(html_7408056b95432b916a64ef37a136f14d);
#
#
#
#         marker_34d894aad88824f9d2755493c70cff22.bindPopup(popup_0e19ebc4c60903ed937c973c953bf1a9)
#         ;
#
#
#
#
#             var marker_ef49f3bb1187a57a2a17c3727fdeaa5a = L.marker(
#                 [36.33113, -93.42862],
#                 {}
#             ).addTo(map_03630b89ddd2a28798614cb2bb3a1e50);
#
#
#             var icon_5fff543c57bb55d7af60d85c60a5aa00 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef49f3bb1187a57a2a17c3727fdeaa5a.setIcon(icon_5fff543c57bb55d7af60d85c60a5aa00);
#
#
#         var popup_759f01033ee25c4aa2411ad655894beb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f4694dbddc9c5e6b1237bfdbf706308 = $(`&lt;div id=&quot;html_2f4694dbddc9c5e6b1237bfdbf706308&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_759f01033ee25c4aa2411ad655894beb.setContent(html_2f4694dbddc9c5e6b1237bfdbf706308);
#
#
#
#         marker_ef49f3bb1187a57a2a17c3727fdeaa5a.bindPopup(popup_759f01033ee25c4aa2411ad655894beb)
#         ;
#
#
#
#
#             var marker_28c7918d6a92959d453898f7a0d63a6c = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_03630b89ddd2a28798614cb2bb3a1e50);
#
#
#             var icon_0f40bb7d52644edaed9cc0f0f3387860 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&qu

# %%
make_map(df_2001, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bb3a928f121700126038aba5a9c4908 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bb3a928f121700126038aba5a9c4908&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bb3a928f121700126038aba5a9c4908 = L.map(
#                 &quot;map_4bb3a928f121700126038aba5a9c4908&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eada586c3c3e2e6a62d1d48c89d81b36 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4bb3a928f121700126038aba5a9c4908);
#
#
#             var marker_09e3255d40a9dd2e2aa8f0a204839814 = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_4bb3a928f121700126038aba5a9c4908);
#
#
#             var icon_3da1909d7e70e7f85858b89284745ecf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_09e3255d40a9dd2e2aa8f0a204839814.setIcon(icon_3da1909d7e70e7f85858b89284745ecf);
#
#
#         var popup_43aadec94107d162c8534567abfc2500 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62444fa603e6fde5edbfc44620effbf8 = $(`&lt;div id=&quot;html_62444fa603e6fde5edbfc44620effbf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_43aadec94107d162c8534567abfc2500.setContent(html_62444fa603e6fde5edbfc44620effbf8);
#
#
#
#         marker_09e3255d40a9dd2e2aa8f0a204839814.bindPopup(popup_43aadec94107d162c8534567abfc2500)
#         ;
#
#
#
#
#             var marker_20dcbd005f8a5accb580242c44a91eeb = L.marker(
#                 [35.771495, -91.649756],
#                 {}
#             ).addTo(map_4bb3a928f121700126038aba5a9c4908);
#
#
#             var icon_8fbd287587b9af1f6d6e3834c4518766 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_20dcbd005f8a5accb580242c44a91eeb.setIcon(icon_8fbd287587b9af1f6d6e3834c4518766);
#
#
#         var popup_3bd5ef3c3e5c4fd7057500547bdaa3b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8eaeb6b5c0bf58035ed3e1ce9cafcc42 = $(`&lt;div id=&quot;html_8eaeb6b5c0bf58035ed3e1ce9cafcc42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_3bd5ef3c3e5c4fd7057500547bdaa3b2.setContent(html_8eaeb6b5c0bf58035ed3e1ce9cafcc42);
#
#
#
#         marker_20dcbd005f8a5accb580242c44a91eeb.bindPopup(popup_3bd5ef3c3e5c4fd7057500547bdaa3b2)
#         ;
#
#
#
#
#             var marker_6fe21c62f30838a496355a7cb4bff48a = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_4bb3a928f121700126038aba5a9c4908);
#
#
#             var icon_adf39b4bb7330414e29a429982c246f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6fe21c62f30838a496355a7cb4bff48a.setIcon(icon_adf39b4bb7330414e29a429982c246f8);
#
#
#         var popup_a13c07b9202246643f9ff536102cc73b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a825a2d5fbdfb6b8f68227130858495 = $(`&lt;div id=&quot;html_1a825a2d5fbdfb6b8f68227130858495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_a13c07b9202246643f9ff536102cc73b.setContent(html_1a825a2d5fbdfb6b8f68227130858495);
#
#
#
#         marker_6fe21c62f30838a496355a7cb4bff48a.bindPopup(popup_a13c07b9202246643f9ff536102cc73b)
#         ;
#
#
#
#
#             var marker_9c2e6c19251613a4f7a7f23a4a8ee210 = L.marker(
#                 [35.436053, -94.35322],
#                 {}
#             ).addTo(map_4bb3a928f121700126038aba5a9c4908);
#
#
#             var icon_ec869124815205d69625f97f1066d74b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&q

# %%
make_map(df_2002, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c6d3b42283fd796e509d27adc820db2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c6d3b42283fd796e509d27adc820db2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c6d3b42283fd796e509d27adc820db2 = L.map(
#                 &quot;map_7c6d3b42283fd796e509d27adc820db2&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc6b42cf28eda5186cb80bb8db454cbd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7c6d3b42283fd796e509d27adc820db2);
#
#
#             var marker_85c5554f80c9c5c082c5187095448ad2 = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_7c6d3b42283fd796e509d27adc820db2);
#
#
#             var icon_45c9c24af9abb99ce03ec40d16b763b4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_85c5554f80c9c5c082c5187095448ad2.setIcon(icon_45c9c24af9abb99ce03ec40d16b763b4);
#
#
#         var popup_e546917a89f29b31c285847d899bb431 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82dc64ee2970a686de2fd68935612985 = $(`&lt;div id=&quot;html_82dc64ee2970a686de2fd68935612985&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_e546917a89f29b31c285847d899bb431.setContent(html_82dc64ee2970a686de2fd68935612985);
#
#
#
#         marker_85c5554f80c9c5c082c5187095448ad2.bindPopup(popup_e546917a89f29b31c285847d899bb431)
#         ;
#
#
#
#
#             var marker_ddcf61e4c7f7f09e614ab76038c77443 = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_7c6d3b42283fd796e509d27adc820db2);
#
#
#             var icon_b2665d8cc664dad7b8a66bb1a3d2de3e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ddcf61e4c7f7f09e614ab76038c77443.setIcon(icon_b2665d8cc664dad7b8a66bb1a3d2de3e);
#
#
#         var popup_6cc6e5f41fde2e2730923fc2fc180e60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_632d7677e28997ac09df0408a78f0ca9 = $(`&lt;div id=&quot;html_632d7677e28997ac09df0408a78f0ca9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_6cc6e5f41fde2e2730923fc2fc180e60.setContent(html_632d7677e28997ac09df0408a78f0ca9);
#
#
#
#         marker_ddcf61e4c7f7f09e614ab76038c77443.bindPopup(popup_6cc6e5f41fde2e2730923fc2fc180e60)
#         ;
#
#
#
#
#             var marker_95204e7442e0ec7003cbc07911cecb3c = L.marker(
#                 [36.33641, -94.12464],
#                 {}
#             ).addTo(map_7c6d3b42283fd796e509d27adc820db2);
#
#
#             var icon_b27f27419f57fd5bc3915cc1620204a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_95204e7442e0ec7003cbc07911cecb3c.setIcon(icon_b27f27419f57fd5bc3915cc1620204a2);
#
#
#         var popup_1d2db931ef4235c8605b939587cce7f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0edcce7d814606ea47432579685c2bd = $(`&lt;div id=&quot;html_d0edcce7d814606ea47432579685c2bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_1d2db931ef4235c8605b939587cce7f0.setContent(html_d0edcce7d814606ea47432579685c2bd);
#
#
#
#         marker_95204e7442e0ec7003cbc07911cecb3c.bindPopup(popup_1d2db931ef4235c8605b939587cce7f0)
#         ;
#
#
#
#
#             var marker_da8f9d7df8d53c451697f40156495674 = L.marker(
#                 [35.436053, -94.35322],
#                 {}
#             ).addTo(map_7c6d3b42283fd796e509d27adc820db2);
#
#
#             var icon_84f66bfcca9a6b04d7bd4f685f8d728b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-s

# %%
make_map(df_2003, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d7f5d758b57389fe27e521ef79d65fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d7f5d758b57389fe27e521ef79d65fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d7f5d758b57389fe27e521ef79d65fb = L.map(
#                 &quot;map_9d7f5d758b57389fe27e521ef79d65fb&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47e9d18c1c1bb5d8fbb3ae4204a691ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d7f5d758b57389fe27e521ef79d65fb);
#
#
#             var marker_2c016d17d639fa712377cc24b8785462 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_9d7f5d758b57389fe27e521ef79d65fb);
#
#
#             var icon_5241516dea7776a35b1084742bee3a65 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2c016d17d639fa712377cc24b8785462.setIcon(icon_5241516dea7776a35b1084742bee3a65);
#
#
#         var popup_8fc0719c311829a00827d0d85ea2d4a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ca101d195fde7163a16d6d65bab1f47 = $(`&lt;div id=&quot;html_0ca101d195fde7163a16d6d65bab1f47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_8fc0719c311829a00827d0d85ea2d4a4.setContent(html_0ca101d195fde7163a16d6d65bab1f47);
#
#
#
#         marker_2c016d17d639fa712377cc24b8785462.bindPopup(popup_8fc0719c311829a00827d0d85ea2d4a4)
#         ;
#
#
#
#
#             var marker_8e6f658625fe63ef9401dd683684af34 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_9d7f5d758b57389fe27e521ef79d65fb);
#
#
#             var icon_54054c98ee9818d1d306e45ff5e24fb0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8e6f658625fe63ef9401dd683684af34.setIcon(icon_54054c98ee9818d1d306e45ff5e24fb0);
#
#
#         var popup_11e9200cc3a7da2aa7d9ca008b65c470 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4639375bbec7f27a69a8a4ed2a6249c = $(`&lt;div id=&quot;html_d4639375bbec7f27a69a8a4ed2a6249c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_11e9200cc3a7da2aa7d9ca008b65c470.setContent(html_d4639375bbec7f27a69a8a4ed2a6249c);
#
#
#
#         marker_8e6f658625fe63ef9401dd683684af34.bindPopup(popup_11e9200cc3a7da2aa7d9ca008b65c470)
#         ;
#
#
#
#
#             var marker_705ddcfc583320af9aaf7d1d00be2a98 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_9d7f5d758b57389fe27e521ef79d65fb);
#
#
#             var icon_a15a40b1e94a4879d67ba776f05b3f98 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_705ddcfc583320af9aaf7d1d00be2a98.setIcon(icon_a15a40b1e94a4879d67ba776f05b3f98);
#
#
#         var popup_cefb651f4e06fc20f6c58de3c99a1475 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_729da4201efcc5a8e898a6af8c92fc9a = $(`&lt;div id=&quot;html_729da4201efcc5a8e898a6af8c92fc9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_cefb651f4e06fc20f6c58de3c99a1475.setContent(html_729da4201efcc5a8e898a6af8c92fc9a);
#
#
#
#         marker_705ddcfc583320af9aaf7d1d00be2a98.bindPopup(popup_cefb651f4e06fc20f6c58de3c99a1475)
#         ;
#
#
#
#
#             var marker_d15941acb3fd180b694cd400179f3b91 = L.marker(
#                 [36.31803, -94.12137],
#                 {}
#             ).addTo(map_9d7f5d758b57389fe27e521ef79d65fb);
#
#
#             var icon_8a7504689abc3da324e9ea97a749e708 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,

# %%
make_map(df_2004, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_163ae7bd6460233e1a8986394c1c880d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_163ae7bd6460233e1a8986394c1c880d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_163ae7bd6460233e1a8986394c1c880d = L.map(
#                 &quot;map_163ae7bd6460233e1a8986394c1c880d&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b58866c2cecf2805befd352d57434b8b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_163ae7bd6460233e1a8986394c1c880d);
#
#
#             var marker_3162b49ea0d9ab02eaf9c8b1b496a423 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_163ae7bd6460233e1a8986394c1c880d);
#
#
#             var icon_a2f9774d7bc639ec32d1443e136f9f4a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3162b49ea0d9ab02eaf9c8b1b496a423.setIcon(icon_a2f9774d7bc639ec32d1443e136f9f4a);
#
#
#         var popup_e737b2dea90b8c1e267ffdfc74e2c017 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3eeeca9ed42b706266918991dede7dac = $(`&lt;div id=&quot;html_3eeeca9ed42b706266918991dede7dac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_e737b2dea90b8c1e267ffdfc74e2c017.setContent(html_3eeeca9ed42b706266918991dede7dac);
#
#
#
#         marker_3162b49ea0d9ab02eaf9c8b1b496a423.bindPopup(popup_e737b2dea90b8c1e267ffdfc74e2c017)
#         ;
#
#
#
#
#             var marker_5a3c72de8b907f39289b537adc9fc1be = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_163ae7bd6460233e1a8986394c1c880d);
#
#
#             var icon_aabc60647a1284e7da66dafd610241ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5a3c72de8b907f39289b537adc9fc1be.setIcon(icon_aabc60647a1284e7da66dafd610241ea);
#
#
#         var popup_a2d5a2af62e29b655f9424786636b4a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_531e1cdc1a479d8f98de1c1cb50b267e = $(`&lt;div id=&quot;html_531e1cdc1a479d8f98de1c1cb50b267e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_a2d5a2af62e29b655f9424786636b4a1.setContent(html_531e1cdc1a479d8f98de1c1cb50b267e);
#
#
#
#         marker_5a3c72de8b907f39289b537adc9fc1be.bindPopup(popup_a2d5a2af62e29b655f9424786636b4a1)
#         ;
#
#
#
#
#             var marker_2f7d43c60d9a9db9b2cabe829717b1bd = L.marker(
#                 [36.33187, -93.44364],
#                 {}
#             ).addTo(map_163ae7bd6460233e1a8986394c1c880d);
#
#
#             var icon_52d36833eb6b688ac99fc7d6244d42e9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2f7d43c60d9a9db9b2cabe829717b1bd.setIcon(icon_52d36833eb6b688ac99fc7d6244d42e9);
#
#
#         var popup_b81645710dd23469cd187a409a73b5bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d065c57f588774df6342339dbc58e6d6 = $(`&lt;div id=&quot;html_d065c57f588774df6342339dbc58e6d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_b81645710dd23469cd187a409a73b5bc.setContent(html_d065c57f588774df6342339dbc58e6d6);
#
#
#
#         marker_2f7d43c60d9a9db9b2cabe829717b1bd.bindPopup(popup_b81645710dd23469cd187a409a73b5bc)
#         ;
#
#
#
#
#             var marker_050f1788fb1af034135bf6540090c70d = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_163ae7bd6460233e1a8986394c1c880d);
#
#
#             var icon_f9033d8f9407011061c4d33e384234f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,

# %%
make_map(df_2005, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da723c4f325a68d16f5ed68df709fe0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da723c4f325a68d16f5ed68df709fe0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da723c4f325a68d16f5ed68df709fe0d = L.map(
#                 &quot;map_da723c4f325a68d16f5ed68df709fe0d&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1b5c00f8c89030944d586bebf65423e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_da723c4f325a68d16f5ed68df709fe0d);
#
#
#             var marker_0171bf42fbfe4cbba40b43867775a411 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_da723c4f325a68d16f5ed68df709fe0d);
#
#
#             var icon_8f8146af388090ffc0103fd60a955257 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0171bf42fbfe4cbba40b43867775a411.setIcon(icon_8f8146af388090ffc0103fd60a955257);
#
#
#         var popup_9e0e2169ba25bdbc1f77f9c178ba36ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53d362c4708f70c67f385e1a970773ef = $(`&lt;div id=&quot;html_53d362c4708f70c67f385e1a970773ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_9e0e2169ba25bdbc1f77f9c178ba36ad.setContent(html_53d362c4708f70c67f385e1a970773ef);
#
#
#
#         marker_0171bf42fbfe4cbba40b43867775a411.bindPopup(popup_9e0e2169ba25bdbc1f77f9c178ba36ad)
#         ;
#
#
#
#
#             var marker_f7c3833604047a9821c12985d456a544 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_da723c4f325a68d16f5ed68df709fe0d);
#
#
#             var icon_51e1e5e5723ca0dcc4c8ec4932ea886a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f7c3833604047a9821c12985d456a544.setIcon(icon_51e1e5e5723ca0dcc4c8ec4932ea886a);
#
#
#         var popup_82a63a9e779ea6f142010926724f5730 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a19e5db1fb43894e448df7252e85baa4 = $(`&lt;div id=&quot;html_a19e5db1fb43894e448df7252e85baa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_82a63a9e779ea6f142010926724f5730.setContent(html_a19e5db1fb43894e448df7252e85baa4);
#
#
#
#         marker_f7c3833604047a9821c12985d456a544.bindPopup(popup_82a63a9e779ea6f142010926724f5730)
#         ;
#
#
#
#
#             var marker_22b29ac67d08acacb08fccd59742991a = L.marker(
#                 [36.33187, -93.44364],
#                 {}
#             ).addTo(map_da723c4f325a68d16f5ed68df709fe0d);
#
#
#             var icon_6ee782d47b42729458c528478403b6d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_22b29ac67d08acacb08fccd59742991a.setIcon(icon_6ee782d47b42729458c528478403b6d5);
#
#
#         var popup_affb460d3f6ee8d4de58e86064aae5cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32fb1da6273cc3d6cc6aeb64f2a6f95f = $(`&lt;div id=&quot;html_32fb1da6273cc3d6cc6aeb64f2a6f95f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_affb460d3f6ee8d4de58e86064aae5cb.setContent(html_32fb1da6273cc3d6cc6aeb64f2a6f95f);
#
#
#
#         marker_22b29ac67d08acacb08fccd59742991a.bindPopup(popup_affb460d3f6ee8d4de58e86064aae5cb)
#         ;
#
#
#
#
#             var marker_73002fea25ff3b789c6352f88a1182db = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_da723c4f325a68d16f5ed68df709fe0d);
#
#
#             var icon_19752de5f72ccecd686d1fdecc0a1599 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,

# %%
make_map(df_2006, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3c38f13947496f58733ded73adc2ba3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3c38f13947496f58733ded73adc2ba3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3c38f13947496f58733ded73adc2ba3 = L.map(
#                 &quot;map_a3c38f13947496f58733ded73adc2ba3&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_050e141041990c74bd987dd4a4089a52 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a3c38f13947496f58733ded73adc2ba3);
#
#
#             var marker_9b14bb63c3d486fa524cde7883dc8d24 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_a3c38f13947496f58733ded73adc2ba3);
#
#
#             var icon_8565d7cb2bb48459641231ca06becfd2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b14bb63c3d486fa524cde7883dc8d24.setIcon(icon_8565d7cb2bb48459641231ca06becfd2);
#
#
#         var popup_82d8a7a6586af8ab99d5c188d3dbe4da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c798fdaaf251234823b74bf2b320244 = $(`&lt;div id=&quot;html_3c798fdaaf251234823b74bf2b320244&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_82d8a7a6586af8ab99d5c188d3dbe4da.setContent(html_3c798fdaaf251234823b74bf2b320244);
#
#
#
#         marker_9b14bb63c3d486fa524cde7883dc8d24.bindPopup(popup_82d8a7a6586af8ab99d5c188d3dbe4da)
#         ;
#
#
#
#
#             var marker_e076925c54a5c210a89898b357c945f4 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_a3c38f13947496f58733ded73adc2ba3);
#
#
#             var icon_d10ec385dadfef3674e4f8d7f1fe30aa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e076925c54a5c210a89898b357c945f4.setIcon(icon_d10ec385dadfef3674e4f8d7f1fe30aa);
#
#
#         var popup_600874e594f9407523b35c79954fd90d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1850f86d4cef4a5cb1bd0d8bffdc4bcf = $(`&lt;div id=&quot;html_1850f86d4cef4a5cb1bd0d8bffdc4bcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_600874e594f9407523b35c79954fd90d.setContent(html_1850f86d4cef4a5cb1bd0d8bffdc4bcf);
#
#
#
#         marker_e076925c54a5c210a89898b357c945f4.bindPopup(popup_600874e594f9407523b35c79954fd90d)
#         ;
#
#
#
#
#             var marker_c3970edf8988b4f4b1ec6df96f8547c1 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_a3c38f13947496f58733ded73adc2ba3);
#
#
#             var icon_38c0ebade81c49ed0d9d0b21777cddcf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3970edf8988b4f4b1ec6df96f8547c1.setIcon(icon_38c0ebade81c49ed0d9d0b21777cddcf);
#
#
#         var popup_22511dc4006804f659b57d7e24169b06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0dbd24c0482b8769b6ec4abd91aed64 = $(`&lt;div id=&quot;html_a0dbd24c0482b8769b6ec4abd91aed64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_22511dc4006804f659b57d7e24169b06.setContent(html_a0dbd24c0482b8769b6ec4abd91aed64);
#
#
#
#         marker_c3970edf8988b4f4b1ec6df96f8547c1.bindPopup(popup_22511dc4006804f659b57d7e24169b06)
#         ;
#
#
#
#
#             var marker_862ef4b938e44f6c10930f73174a0004 = L.marker(
#                 [36.312737, -93.009443],
#                 {}
#             ).addTo(map_a3c38f13947496f58733ded73adc2ba3);
#
#
#             var icon_2b3b0546665ef947cbb2ec2c51a0be87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign

# %%
make_map(df_2007, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86e1d3e3491816c0a60c9f5d7a8281b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86e1d3e3491816c0a60c9f5d7a8281b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86e1d3e3491816c0a60c9f5d7a8281b1 = L.map(
#                 &quot;map_86e1d3e3491816c0a60c9f5d7a8281b1&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1028deee04c82d4a291b20281f1b7d9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86e1d3e3491816c0a60c9f5d7a8281b1);
#
#
#             var marker_8bf1d0d79bde9b5d6b4dba9b31d39b8a = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_86e1d3e3491816c0a60c9f5d7a8281b1);
#
#
#             var icon_c1f3928b8db0551246be703bea0ecd7f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8bf1d0d79bde9b5d6b4dba9b31d39b8a.setIcon(icon_c1f3928b8db0551246be703bea0ecd7f);
#
#
#         var popup_17e03cc8ae48f9d2bec80629482c0ce4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94f468454ca34cff539d572fadf879bb = $(`&lt;div id=&quot;html_94f468454ca34cff539d572fadf879bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_17e03cc8ae48f9d2bec80629482c0ce4.setContent(html_94f468454ca34cff539d572fadf879bb);
#
#
#
#         marker_8bf1d0d79bde9b5d6b4dba9b31d39b8a.bindPopup(popup_17e03cc8ae48f9d2bec80629482c0ce4)
#         ;
#
#
#
#
#             var marker_c56dfa677a3a677ad7bec66851a09e4f = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_86e1d3e3491816c0a60c9f5d7a8281b1);
#
#
#             var icon_01a946aa539ab40200daa8290730cc82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c56dfa677a3a677ad7bec66851a09e4f.setIcon(icon_01a946aa539ab40200daa8290730cc82);
#
#
#         var popup_2072638e3adf19bd9376a1a2e89e6d1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8668d6f1a1c7475f7b7c0ca71f15edee = $(`&lt;div id=&quot;html_8668d6f1a1c7475f7b7c0ca71f15edee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_2072638e3adf19bd9376a1a2e89e6d1c.setContent(html_8668d6f1a1c7475f7b7c0ca71f15edee);
#
#
#
#         marker_c56dfa677a3a677ad7bec66851a09e4f.bindPopup(popup_2072638e3adf19bd9376a1a2e89e6d1c)
#         ;
#
#
#
#
#             var marker_ee1701230d1e6a935b3e2fb03f6b2bd1 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_86e1d3e3491816c0a60c9f5d7a8281b1);
#
#
#             var icon_5814136d81eb9d66b3fd79376f1ca49c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ee1701230d1e6a935b3e2fb03f6b2bd1.setIcon(icon_5814136d81eb9d66b3fd79376f1ca49c);
#
#
#         var popup_c493360566e2eced52733415fb9f816f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb6fd103c3ff5bad40dadf2f892b3e98 = $(`&lt;div id=&quot;html_fb6fd103c3ff5bad40dadf2f892b3e98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_c493360566e2eced52733415fb9f816f.setContent(html_fb6fd103c3ff5bad40dadf2f892b3e98);
#
#
#
#         marker_ee1701230d1e6a935b3e2fb03f6b2bd1.bindPopup(popup_c493360566e2eced52733415fb9f816f)
#         ;
#
#
#
#
#             var marker_e71759eb6530dde83877403b883b2eee = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_86e1d3e3491816c0a60c9f5d7a8281b1);
#
#
#             var icon_4dd0a25f0068bd936a0ea4bd80542c73 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;i

# %%
make_map(df_2008, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcc63bf73eac1749529b5b0a18dd0992 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcc63bf73eac1749529b5b0a18dd0992&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcc63bf73eac1749529b5b0a18dd0992 = L.map(
#                 &quot;map_dcc63bf73eac1749529b5b0a18dd0992&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c137cbd76b516e84c451f599c2206962 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dcc63bf73eac1749529b5b0a18dd0992);
#
#
#             var marker_584a7d8f5ba6d07e7290efa515daf224 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_dcc63bf73eac1749529b5b0a18dd0992);
#
#
#             var icon_391935db184f0d01aacbe470950f5932 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_584a7d8f5ba6d07e7290efa515daf224.setIcon(icon_391935db184f0d01aacbe470950f5932);
#
#
#         var popup_9f2c3bbd6d9946ceae5e98236c8129cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_578f1fc2e46d50c05590c93d1b9c6a37 = $(`&lt;div id=&quot;html_578f1fc2e46d50c05590c93d1b9c6a37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_9f2c3bbd6d9946ceae5e98236c8129cc.setContent(html_578f1fc2e46d50c05590c93d1b9c6a37);
#
#
#
#         marker_584a7d8f5ba6d07e7290efa515daf224.bindPopup(popup_9f2c3bbd6d9946ceae5e98236c8129cc)
#         ;
#
#
#
#
#             var marker_129fb955b2066196718f7ee9139c23e9 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_dcc63bf73eac1749529b5b0a18dd0992);
#
#
#             var icon_ef0c47b8911063e36e4e2d89f4e57420 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_129fb955b2066196718f7ee9139c23e9.setIcon(icon_ef0c47b8911063e36e4e2d89f4e57420);
#
#
#         var popup_16036b5688d69efbc1f748681de3b179 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79bee2c97203346d0ee0c94ec4694ba0 = $(`&lt;div id=&quot;html_79bee2c97203346d0ee0c94ec4694ba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_16036b5688d69efbc1f748681de3b179.setContent(html_79bee2c97203346d0ee0c94ec4694ba0);
#
#
#
#         marker_129fb955b2066196718f7ee9139c23e9.bindPopup(popup_16036b5688d69efbc1f748681de3b179)
#         ;
#
#
#
#
#             var marker_447495bd2fab4e61aacc98f308f85960 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_dcc63bf73eac1749529b5b0a18dd0992);
#
#
#             var icon_f1777de1d8feb95443515643f611999d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_447495bd2fab4e61aacc98f308f85960.setIcon(icon_f1777de1d8feb95443515643f611999d);
#
#
#         var popup_9e425fcf551adbc446d10dbc44ef098b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_561c9f158cf4c1b7a006c93721d98336 = $(`&lt;div id=&quot;html_561c9f158cf4c1b7a006c93721d98336&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_9e425fcf551adbc446d10dbc44ef098b.setContent(html_561c9f158cf4c1b7a006c93721d98336);
#
#
#
#         marker_447495bd2fab4e61aacc98f308f85960.bindPopup(popup_9e425fcf551adbc446d10dbc44ef098b)
#         ;
#
#
#
#
#             var marker_d5556778c9717c7c04f5a55e34ef4e1e = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_dcc63bf73eac1749529b5b0a18dd0992);
#
#
#             var icon_05878a8fba312d1d366b6c8fe66e4ed0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,

# %%
make_map(df_2009, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3903895b9554890a079d36b89e7c8fb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3903895b9554890a079d36b89e7c8fb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3903895b9554890a079d36b89e7c8fb6 = L.map(
#                 &quot;map_3903895b9554890a079d36b89e7c8fb6&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0662278b95ed72ef9185196e383c78f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3903895b9554890a079d36b89e7c8fb6);
#
#
#             var marker_4c82040dff2bf0a3e48402f52a183b74 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_3903895b9554890a079d36b89e7c8fb6);
#
#
#             var icon_6a234e74fc1521d1332c771878f8d3ff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4c82040dff2bf0a3e48402f52a183b74.setIcon(icon_6a234e74fc1521d1332c771878f8d3ff);
#
#
#         var popup_f5dc384eaa01169ec5cc9ededb4dfb95 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9c15bd78e2a9a2c7c136e4c33aa6617 = $(`&lt;div id=&quot;html_f9c15bd78e2a9a2c7c136e4c33aa6617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_f5dc384eaa01169ec5cc9ededb4dfb95.setContent(html_f9c15bd78e2a9a2c7c136e4c33aa6617);
#
#
#
#         marker_4c82040dff2bf0a3e48402f52a183b74.bindPopup(popup_f5dc384eaa01169ec5cc9ededb4dfb95)
#         ;
#
#
#
#
#             var marker_edbe4a8c50286686fc2d388e843a9f28 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_3903895b9554890a079d36b89e7c8fb6);
#
#
#             var icon_2ac36d901fd3c0f9725c4cf7ea14df44 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_edbe4a8c50286686fc2d388e843a9f28.setIcon(icon_2ac36d901fd3c0f9725c4cf7ea14df44);
#
#
#         var popup_01b0418a5e7e7e62a0bd62fc367c40be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_248200c703c246b9a436d343c811bf6a = $(`&lt;div id=&quot;html_248200c703c246b9a436d343c811bf6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_01b0418a5e7e7e62a0bd62fc367c40be.setContent(html_248200c703c246b9a436d343c811bf6a);
#
#
#
#         marker_edbe4a8c50286686fc2d388e843a9f28.bindPopup(popup_01b0418a5e7e7e62a0bd62fc367c40be)
#         ;
#
#
#
#
#             var marker_47948e7a7e30cc145105d86d82b95029 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_3903895b9554890a079d36b89e7c8fb6);
#
#
#             var icon_9ea0e083eed89ae01fec51b5c8cbd33b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_47948e7a7e30cc145105d86d82b95029.setIcon(icon_9ea0e083eed89ae01fec51b5c8cbd33b);
#
#
#         var popup_83cd1bfef9094e873c8e12610d010a2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_222918057aede807becebb38060a8d49 = $(`&lt;div id=&quot;html_222918057aede807becebb38060a8d49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_83cd1bfef9094e873c8e12610d010a2d.setContent(html_222918057aede807becebb38060a8d49);
#
#
#
#         marker_47948e7a7e30cc145105d86d82b95029.bindPopup(popup_83cd1bfef9094e873c8e12610d010a2d)
#         ;
#
#
#
#
#             var marker_eb5ac689bc4001596a1f7d28cbec7e18 = L.marker(
#                 [35.26134, -93.12126],
#                 {}
#             ).addTo(map_3903895b9554890a079d36b89e7c8fb6);
#
#
#             var icon_9a3d4fd1a6597ef78e813d23a675c8c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,

# %%
make_map(df_2010, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fcb885bdf8c114ae8250bd0b441eb68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fcb885bdf8c114ae8250bd0b441eb68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fcb885bdf8c114ae8250bd0b441eb68 = L.map(
#                 &quot;map_2fcb885bdf8c114ae8250bd0b441eb68&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3909d2215c7b5381116226e4a2b7043 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2fcb885bdf8c114ae8250bd0b441eb68);
#
#
#             var marker_676b60263236406dfbc45cc635a1b505 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_2fcb885bdf8c114ae8250bd0b441eb68);
#
#
#             var icon_af470b63b6d95508b4977ab301ad84ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_676b60263236406dfbc45cc635a1b505.setIcon(icon_af470b63b6d95508b4977ab301ad84ec);
#
#
#         var popup_e957221ef55f21c6aed9ac737b808c32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_762c2e78596a7208d0831cfa9bb6a113 = $(`&lt;div id=&quot;html_762c2e78596a7208d0831cfa9bb6a113&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_e957221ef55f21c6aed9ac737b808c32.setContent(html_762c2e78596a7208d0831cfa9bb6a113);
#
#
#
#         marker_676b60263236406dfbc45cc635a1b505.bindPopup(popup_e957221ef55f21c6aed9ac737b808c32)
#         ;
#
#
#
#
#             var marker_b41d96c89e5ed23698fb76972b6fecc9 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_2fcb885bdf8c114ae8250bd0b441eb68);
#
#
#             var icon_2156fdcb31e8efa5fa5913e44ea094dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b41d96c89e5ed23698fb76972b6fecc9.setIcon(icon_2156fdcb31e8efa5fa5913e44ea094dc);
#
#
#         var popup_56f4d8fd8cc69c2fa6bc48e328501f35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be67c5143a5e10209bfec5bea8aff144 = $(`&lt;div id=&quot;html_be67c5143a5e10209bfec5bea8aff144&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_56f4d8fd8cc69c2fa6bc48e328501f35.setContent(html_be67c5143a5e10209bfec5bea8aff144);
#
#
#
#         marker_b41d96c89e5ed23698fb76972b6fecc9.bindPopup(popup_56f4d8fd8cc69c2fa6bc48e328501f35)
#         ;
#
#
#
#
#             var marker_707a81009137d8db5f6fb1021f70c150 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_2fcb885bdf8c114ae8250bd0b441eb68);
#
#
#             var icon_79df6230e81bd4e72b905b531e8fbff5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_707a81009137d8db5f6fb1021f70c150.setIcon(icon_79df6230e81bd4e72b905b531e8fbff5);
#
#
#         var popup_6e0a4a46e3b70a19f257de8bd4f4d9b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1aaf2bee9dd0f4c1adc4321a684f18b0 = $(`&lt;div id=&quot;html_1aaf2bee9dd0f4c1adc4321a684f18b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_6e0a4a46e3b70a19f257de8bd4f4d9b4.setContent(html_1aaf2bee9dd0f4c1adc4321a684f18b0);
#
#
#
#         marker_707a81009137d8db5f6fb1021f70c150.bindPopup(popup_6e0a4a46e3b70a19f257de8bd4f4d9b4)
#         ;
#
#
#
#
#             var marker_3a0e78a390b059c6882a1f257d9ca095 = L.marker(
#                 [35.26134, -93.12126],
#                 {}
#             ).addTo(map_2fcb885bdf8c114ae8250bd0b441eb68);
#
#
#             var icon_38093e27ac16ff1e0e2913903e9a0133 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&

# %%
make_map(df_2011, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_358dc643a785772f7ac18e8f3516b008 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_358dc643a785772f7ac18e8f3516b008&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_358dc643a785772f7ac18e8f3516b008 = L.map(
#                 &quot;map_358dc643a785772f7ac18e8f3516b008&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62afbd06d25985fbf7c638ec5e7cc762 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_358dc643a785772f7ac18e8f3516b008);
#
#
#             var marker_f776e1cb055116c81d149d40d3f3ba91 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_358dc643a785772f7ac18e8f3516b008);
#
#
#             var icon_2ba4cbbfd09b60a7384a39c5ed76ecb1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f776e1cb055116c81d149d40d3f3ba91.setIcon(icon_2ba4cbbfd09b60a7384a39c5ed76ecb1);
#
#
#         var popup_216188c9b4d9db7e178e54e857360e69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d95e8ffde1e8dc9bbe237bed8f47903 = $(`&lt;div id=&quot;html_0d95e8ffde1e8dc9bbe237bed8f47903&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_216188c9b4d9db7e178e54e857360e69.setContent(html_0d95e8ffde1e8dc9bbe237bed8f47903);
#
#
#
#         marker_f776e1cb055116c81d149d40d3f3ba91.bindPopup(popup_216188c9b4d9db7e178e54e857360e69)
#         ;
#
#
#
#
#             var marker_fab8806518f6aa28ca32a919bb9eb296 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_358dc643a785772f7ac18e8f3516b008);
#
#
#             var icon_ca5fcf395da9f6b2f8dbb70202f01146 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fab8806518f6aa28ca32a919bb9eb296.setIcon(icon_ca5fcf395da9f6b2f8dbb70202f01146);
#
#
#         var popup_9e621ce0ec25d9b77277c51142b93ace = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25e505054d24678ba216041f06a4a069 = $(`&lt;div id=&quot;html_25e505054d24678ba216041f06a4a069&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_9e621ce0ec25d9b77277c51142b93ace.setContent(html_25e505054d24678ba216041f06a4a069);
#
#
#
#         marker_fab8806518f6aa28ca32a919bb9eb296.bindPopup(popup_9e621ce0ec25d9b77277c51142b93ace)
#         ;
#
#
#
#
#             var marker_f5737c4ad293f2264e74d8db27eb233f = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_358dc643a785772f7ac18e8f3516b008);
#
#
#             var icon_f96c1ec7a25bcb5d4b9d8b7f8d7309af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f5737c4ad293f2264e74d8db27eb233f.setIcon(icon_f96c1ec7a25bcb5d4b9d8b7f8d7309af);
#
#
#         var popup_bcb6d512083ef9a66a4f1851136b4552 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8eceb99bf4a615a38ddd6191525ee0f6 = $(`&lt;div id=&quot;html_8eceb99bf4a615a38ddd6191525ee0f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_bcb6d512083ef9a66a4f1851136b4552.setContent(html_8eceb99bf4a615a38ddd6191525ee0f6);
#
#
#
#         marker_f5737c4ad293f2264e74d8db27eb233f.bindPopup(popup_bcb6d512083ef9a66a4f1851136b4552)
#         ;
#
#
#
#
#             var marker_31b284e4c0197ba2c87e7153d4d0c110 = L.marker(
#                 [35.26134, -93.12126],
#                 {}
#             ).addTo(map_358dc643a785772f7ac18e8f3516b008);
#
#
#             var icon_989a6d47c96a81a0a28ea5de69b6d978 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:

# %%
make_map(df_2012, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_597f43d9fc9bc56b97b004f5646ec9d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_597f43d9fc9bc56b97b004f5646ec9d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_597f43d9fc9bc56b97b004f5646ec9d3 = L.map(
#                 &quot;map_597f43d9fc9bc56b97b004f5646ec9d3&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4ed49d16cbbb922cd3e87136af77029 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_597f43d9fc9bc56b97b004f5646ec9d3);
#
#
#             var marker_86f55d69218027bb377dd3c5ce849a13 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_597f43d9fc9bc56b97b004f5646ec9d3);
#
#
#             var icon_616e005719907997f4b69e085fff0c5e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_86f55d69218027bb377dd3c5ce849a13.setIcon(icon_616e005719907997f4b69e085fff0c5e);
#
#
#         var popup_1ff0dc1349018fd63bedc189e422d915 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7aa230679a7a8686393b27227df47b7d = $(`&lt;div id=&quot;html_7aa230679a7a8686393b27227df47b7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_1ff0dc1349018fd63bedc189e422d915.setContent(html_7aa230679a7a8686393b27227df47b7d);
#
#
#
#         marker_86f55d69218027bb377dd3c5ce849a13.bindPopup(popup_1ff0dc1349018fd63bedc189e422d915)
#         ;
#
#
#
#
#             var marker_66241a14d7532bb430e8826d11d132c0 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_597f43d9fc9bc56b97b004f5646ec9d3);
#
#
#             var icon_480688fdda9c2d2ad53192ab14197bb4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_66241a14d7532bb430e8826d11d132c0.setIcon(icon_480688fdda9c2d2ad53192ab14197bb4);
#
#
#         var popup_f15c95c471bf757d08841fb8f1053d6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f3cd90fd8f2af01044ecac016fbed1e = $(`&lt;div id=&quot;html_8f3cd90fd8f2af01044ecac016fbed1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_f15c95c471bf757d08841fb8f1053d6a.setContent(html_8f3cd90fd8f2af01044ecac016fbed1e);
#
#
#
#         marker_66241a14d7532bb430e8826d11d132c0.bindPopup(popup_f15c95c471bf757d08841fb8f1053d6a)
#         ;
#
#
#
#
#             var marker_449d86be043448e50eb5ad54e5b037ff = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_597f43d9fc9bc56b97b004f5646ec9d3);
#
#
#             var icon_b4bc70b0c16ad3e05e390ecc5b983e52 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_449d86be043448e50eb5ad54e5b037ff.setIcon(icon_b4bc70b0c16ad3e05e390ecc5b983e52);
#
#
#         var popup_7f738f84698c1f19b8750952f85baaa5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7b222933ded718d3bb2ae2d75ee72fd = $(`&lt;div id=&quot;html_d7b222933ded718d3bb2ae2d75ee72fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_7f738f84698c1f19b8750952f85baaa5.setContent(html_d7b222933ded718d3bb2ae2d75ee72fd);
#
#
#
#         marker_449d86be043448e50eb5ad54e5b037ff.bindPopup(popup_7f738f84698c1f19b8750952f85baaa5)
#         ;
#
#
#
#
#             var marker_f52d882de50ecf9aaa446c33a774955c = L.marker(
#                 [35.26134, -93.12126],
#                 {}
#             ).addTo(map_597f43d9fc9bc56b97b004f5646ec9d3);
#
#
#             var icon_ccd22d96f9b5d73bdcc2897c50f09ea8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&qu

# %%
make_map(df_2013, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d3893965b9d1b96c484824454d508de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d3893965b9d1b96c484824454d508de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d3893965b9d1b96c484824454d508de = L.map(
#                 &quot;map_4d3893965b9d1b96c484824454d508de&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35cdb5ddaa7557fa3a1f6c5253d25a5e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4d3893965b9d1b96c484824454d508de);
#
#
#             var marker_63bc331876d2b5f60334bfc72723d44d = L.marker(
#                 [35.763903, -91.64909],
#                 {}
#             ).addTo(map_4d3893965b9d1b96c484824454d508de);
#
#
#             var icon_bef664fbe568714b80c3416db1c1f89d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_63bc331876d2b5f60334bfc72723d44d.setIcon(icon_bef664fbe568714b80c3416db1c1f89d);
#
#
#         var popup_76ab5fbea0cb808743e70904a6ce3b2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bbc919ec6b557b22f9449a1ca4c262b = $(`&lt;div id=&quot;html_0bbc919ec6b557b22f9449a1ca4c262b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_76ab5fbea0cb808743e70904a6ce3b2d.setContent(html_0bbc919ec6b557b22f9449a1ca4c262b);
#
#
#
#         marker_63bc331876d2b5f60334bfc72723d44d.bindPopup(popup_76ab5fbea0cb808743e70904a6ce3b2d)
#         ;
#
#
#
#
#             var marker_85d54926ef4347d6fb6f27f42d4bb001 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_4d3893965b9d1b96c484824454d508de);
#
#
#             var icon_1644e8bd8cdb8a8b7a9756726bfd401a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_85d54926ef4347d6fb6f27f42d4bb001.setIcon(icon_1644e8bd8cdb8a8b7a9756726bfd401a);
#
#
#         var popup_4957a6f00baa549180673f85ddfb9bcf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c9e8e5037e7fa2a356f3cc8761cf9ae0 = $(`&lt;div id=&quot;html_c9e8e5037e7fa2a356f3cc8761cf9ae0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_4957a6f00baa549180673f85ddfb9bcf.setContent(html_c9e8e5037e7fa2a356f3cc8761cf9ae0);
#
#
#
#         marker_85d54926ef4347d6fb6f27f42d4bb001.bindPopup(popup_4957a6f00baa549180673f85ddfb9bcf)
#         ;
#
#
#
#
#             var marker_73dbe2bfb1b5a6db72ba831da3f88e1a = L.marker(
#                 [36.154423, -94.15444],
#                 {}
#             ).addTo(map_4d3893965b9d1b96c484824454d508de);
#
#
#             var icon_6d6c1fc81dadd6161f811b5abec427bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_73dbe2bfb1b5a6db72ba831da3f88e1a.setIcon(icon_6d6c1fc81dadd6161f811b5abec427bc);
#
#
#         var popup_5b670c18d0e2931040f7661f8dfc2e15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9943339e81d987aab6cc8896481eb12a = $(`&lt;div id=&quot;html_9943339e81d987aab6cc8896481eb12a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_5b670c18d0e2931040f7661f8dfc2e15.setContent(html_9943339e81d987aab6cc8896481eb12a);
#
#
#
#         marker_73dbe2bfb1b5a6db72ba831da3f88e1a.bindPopup(popup_5b670c18d0e2931040f7661f8dfc2e15)
#         ;
#
#
#
#
#             var marker_c7d41802837e73557ff919b84f03a3f3 = L.marker(
#                 [35.261343, -93.121268],
#                 {}
#             ).addTo(map_4d3893965b9d1b96c484824454d508de);
#
#
#             var icon_b14c66a9bcbddc15ae079da2c9d9e93c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;ico

# %%
make_map(df_2014, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31f3594b035b1e303606ebeec3333f8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31f3594b035b1e303606ebeec3333f8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31f3594b035b1e303606ebeec3333f8e = L.map(
#                 &quot;map_31f3594b035b1e303606ebeec3333f8e&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2149fed5d6b9b7f243e1cfa0cfbd840f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_31f3594b035b1e303606ebeec3333f8e);
#
#
#             var marker_bbe348ebb9b23ccb3d052d90db46084c = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_31f3594b035b1e303606ebeec3333f8e);
#
#
#             var icon_605644828904ef5e2ebaa4c8e1b54f1d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bbe348ebb9b23ccb3d052d90db46084c.setIcon(icon_605644828904ef5e2ebaa4c8e1b54f1d);
#
#
#         var popup_24c70989109e7ab0d8c50ea52266fb83 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a83d49ffe0f76926fd6aceb4565e2353 = $(`&lt;div id=&quot;html_a83d49ffe0f76926fd6aceb4565e2353&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_24c70989109e7ab0d8c50ea52266fb83.setContent(html_a83d49ffe0f76926fd6aceb4565e2353);
#
#
#
#         marker_bbe348ebb9b23ccb3d052d90db46084c.bindPopup(popup_24c70989109e7ab0d8c50ea52266fb83)
#         ;
#
#
#
#
#             var marker_69feed010fc70c798dd03dbaae2ef26f = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_31f3594b035b1e303606ebeec3333f8e);
#
#
#             var icon_2043930142f7ce8b60d92e92bb16b05a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_69feed010fc70c798dd03dbaae2ef26f.setIcon(icon_2043930142f7ce8b60d92e92bb16b05a);
#
#
#         var popup_5d31d273f9c7d550122ad1497b18ce5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f63a2f08ca8ec3ebe86386c73b3d4e6 = $(`&lt;div id=&quot;html_3f63a2f08ca8ec3ebe86386c73b3d4e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_5d31d273f9c7d550122ad1497b18ce5a.setContent(html_3f63a2f08ca8ec3ebe86386c73b3d4e6);
#
#
#
#         marker_69feed010fc70c798dd03dbaae2ef26f.bindPopup(popup_5d31d273f9c7d550122ad1497b18ce5a)
#         ;
#
#
#
#
#             var marker_f795869ceb127e1836f06b20a5d20464 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_31f3594b035b1e303606ebeec3333f8e);
#
#
#             var icon_3e9a9ff6dfc555f282eaf3413ee2fac6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f795869ceb127e1836f06b20a5d20464.setIcon(icon_3e9a9ff6dfc555f282eaf3413ee2fac6);
#
#
#         var popup_5bf000816377bb8e39d2a5f2e80b6107 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5901002f7266aa3c587b4987cf16904 = $(`&lt;div id=&quot;html_a5901002f7266aa3c587b4987cf16904&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_5bf000816377bb8e39d2a5f2e80b6107.setContent(html_a5901002f7266aa3c587b4987cf16904);
#
#
#
#         marker_f795869ceb127e1836f06b20a5d20464.bindPopup(popup_5bf000816377bb8e39d2a5f2e80b6107)
#         ;
#
#
#
#
#             var marker_6e8b5611fedefeffe14f49524cdca932 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_31f3594b035b1e303606ebeec3333f8e);
#
#
#             var icon_c56db03674ddeadbbf241763c8f124bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon

# %%
make_map(df_2015, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_259d338d09a787ea64ce870b150f5f2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_259d338d09a787ea64ce870b150f5f2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_259d338d09a787ea64ce870b150f5f2d = L.map(
#                 &quot;map_259d338d09a787ea64ce870b150f5f2d&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57bd45851f371fdd35f3242fc9ffb244 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_259d338d09a787ea64ce870b150f5f2d);
#
#
#             var marker_68ffe0d6bf170d1577b02b60070fbb37 = L.marker(
#                 [35.428048, -94.33674],
#                 {}
#             ).addTo(map_259d338d09a787ea64ce870b150f5f2d);
#
#
#             var icon_f4fc7905922b215a7d67e4c615880145 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_68ffe0d6bf170d1577b02b60070fbb37.setIcon(icon_f4fc7905922b215a7d67e4c615880145);
#
#
#         var popup_dfb7ff67dbfe70e694e74c9bf244b178 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7c8634ee2cfc78a2745df5e315dac6d = $(`&lt;div id=&quot;html_a7c8634ee2cfc78a2745df5e315dac6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_dfb7ff67dbfe70e694e74c9bf244b178.setContent(html_a7c8634ee2cfc78a2745df5e315dac6d);
#
#
#
#         marker_68ffe0d6bf170d1577b02b60070fbb37.bindPopup(popup_dfb7ff67dbfe70e694e74c9bf244b178)
#         ;
#
#
#
#
#             var marker_748f1301f95d9c9392a9b1d5ef8e7bf6 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_259d338d09a787ea64ce870b150f5f2d);
#
#
#             var icon_ea0616ea08362d4294b86e9c95583e75 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_748f1301f95d9c9392a9b1d5ef8e7bf6.setIcon(icon_ea0616ea08362d4294b86e9c95583e75);
#
#
#         var popup_275dc54b3c490c4b019b0d2557084b67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd12a02a95351d44f7c13e5f299b0dbd = $(`&lt;div id=&quot;html_fd12a02a95351d44f7c13e5f299b0dbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_275dc54b3c490c4b019b0d2557084b67.setContent(html_fd12a02a95351d44f7c13e5f299b0dbd);
#
#
#
#         marker_748f1301f95d9c9392a9b1d5ef8e7bf6.bindPopup(popup_275dc54b3c490c4b019b0d2557084b67)
#         ;
#
#
#
#
#             var marker_3cae3b77789920e8a6b89cc674b6e4d1 = L.marker(
#                 [35.062086, -93.351198],
#                 {}
#             ).addTo(map_259d338d09a787ea64ce870b150f5f2d);
#
#
#             var icon_767a3ff3edb682a5181e4b0508c0288e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3cae3b77789920e8a6b89cc674b6e4d1.setIcon(icon_767a3ff3edb682a5181e4b0508c0288e);
#
#
#         var popup_fc81fc83d90ce8c381d79a9e68546bd0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3248f99a4884e266ed0cdb733243694 = $(`&lt;div id=&quot;html_f3248f99a4884e266ed0cdb733243694&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_fc81fc83d90ce8c381d79a9e68546bd0.setContent(html_f3248f99a4884e266ed0cdb733243694);
#
#
#
#         marker_3cae3b77789920e8a6b89cc674b6e4d1.bindPopup(popup_fc81fc83d90ce8c381d79a9e68546bd0)
#         ;
#
#
#
#
#             var marker_9155cb312353b60bca3b8c5dca376554 = L.marker(
#                 [36.15404, -94.15428],
#                 {}
#             ).addTo(map_259d338d09a787ea64ce870b150f5f2d);
#
#
#             var icon_af7b85f64873197cc89a9357635c1b88 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;ic

# %%
make_map(df_2016, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_723cd140edafd66b94289d634a67d64d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_723cd140edafd66b94289d634a67d64d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_723cd140edafd66b94289d634a67d64d = L.map(
#                 &quot;map_723cd140edafd66b94289d634a67d64d&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd367e87b8c1f3903e60cd6ddc4895d9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_723cd140edafd66b94289d634a67d64d);
#
#
#             var marker_8b7b1d1d8d813372966354abdf2407a5 = L.marker(
#                 [35.428048, -94.33674],
#                 {}
#             ).addTo(map_723cd140edafd66b94289d634a67d64d);
#
#
#             var icon_6a00271e102513c1d24b215001afe8af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8b7b1d1d8d813372966354abdf2407a5.setIcon(icon_6a00271e102513c1d24b215001afe8af);
#
#
#         var popup_3a4dedf1ff7aff099f888c99c6481418 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02ecf644bb6c5b6c4fbd462004955019 = $(`&lt;div id=&quot;html_02ecf644bb6c5b6c4fbd462004955019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_3a4dedf1ff7aff099f888c99c6481418.setContent(html_02ecf644bb6c5b6c4fbd462004955019);
#
#
#
#         marker_8b7b1d1d8d813372966354abdf2407a5.bindPopup(popup_3a4dedf1ff7aff099f888c99c6481418)
#         ;
#
#
#
#
#             var marker_f08b07945781440970e1911fa8785751 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_723cd140edafd66b94289d634a67d64d);
#
#
#             var icon_d0f05bba83088e93185181f2fe6123dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f08b07945781440970e1911fa8785751.setIcon(icon_d0f05bba83088e93185181f2fe6123dc);
#
#
#         var popup_376164fc09553329ae6d4cfee7c6ee0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8e4e333f6e4cb9c3d8e614f255d8733 = $(`&lt;div id=&quot;html_d8e4e333f6e4cb9c3d8e614f255d8733&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_376164fc09553329ae6d4cfee7c6ee0b.setContent(html_d8e4e333f6e4cb9c3d8e614f255d8733);
#
#
#
#         marker_f08b07945781440970e1911fa8785751.bindPopup(popup_376164fc09553329ae6d4cfee7c6ee0b)
#         ;
#
#
#
#
#             var marker_4af3671fd86831410bb4d8a5c8b06a26 = L.marker(
#                 [35.703198, -91.475651],
#                 {}
#             ).addTo(map_723cd140edafd66b94289d634a67d64d);
#
#
#             var icon_1e606b8058b504c9c3020a55e8cdc1ef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4af3671fd86831410bb4d8a5c8b06a26.setIcon(icon_1e606b8058b504c9c3020a55e8cdc1ef);
#
#
#         var popup_dba7da8fb1a9c59427465d7750dcdccb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8bed1c34477064b161e6a048b1129ad = $(`&lt;div id=&quot;html_c8bed1c34477064b161e6a048b1129ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_dba7da8fb1a9c59427465d7750dcdccb.setContent(html_c8bed1c34477064b161e6a048b1129ad);
#
#
#
#         marker_4af3671fd86831410bb4d8a5c8b06a26.bindPopup(popup_dba7da8fb1a9c59427465d7750dcdccb)
#         ;
#
#
#
#
#             var marker_2a72fe8958191a48318c188e8a859bc0 = L.marker(
#                 [35.0553, -93.3685],
#                 {}
#             ).addTo(map_723cd140edafd66b94289d634a67d64d);
#
#
#             var icon_8d7e7e2f8a196e72a6337689bc4b2b5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;in

# %%
make_map(df_2017, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4e61dd708d61794a0da6e344b98ae09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4e61dd708d61794a0da6e344b98ae09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4e61dd708d61794a0da6e344b98ae09 = L.map(
#                 &quot;map_b4e61dd708d61794a0da6e344b98ae09&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90fa79624e3d6cc7565499f297d03bdb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b4e61dd708d61794a0da6e344b98ae09);
#
#
#             var marker_dcc873d6102906c55b14b1df2133716b = L.marker(
#                 [35.428048, -94.33674],
#                 {}
#             ).addTo(map_b4e61dd708d61794a0da6e344b98ae09);
#
#
#             var icon_5d2696e48f24b6a023d973342e6e65a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dcc873d6102906c55b14b1df2133716b.setIcon(icon_5d2696e48f24b6a023d973342e6e65a2);
#
#
#         var popup_aa74c632b25ab8ea6e2a9d87f47f6ddc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13b22c3a337645d342020884768926da = $(`&lt;div id=&quot;html_13b22c3a337645d342020884768926da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_aa74c632b25ab8ea6e2a9d87f47f6ddc.setContent(html_13b22c3a337645d342020884768926da);
#
#
#
#         marker_dcc873d6102906c55b14b1df2133716b.bindPopup(popup_aa74c632b25ab8ea6e2a9d87f47f6ddc)
#         ;
#
#
#
#
#             var marker_188117933a33c8c21624c5034d671b9b = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_b4e61dd708d61794a0da6e344b98ae09);
#
#
#             var icon_7af78c71ebfe42ce7685dd6c17689e48 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_188117933a33c8c21624c5034d671b9b.setIcon(icon_7af78c71ebfe42ce7685dd6c17689e48);
#
#
#         var popup_56d0e303ea786e7b93523668325f3bb3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef09eb488c6749af78c92fcdbbf3e4de = $(`&lt;div id=&quot;html_ef09eb488c6749af78c92fcdbbf3e4de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_56d0e303ea786e7b93523668325f3bb3.setContent(html_ef09eb488c6749af78c92fcdbbf3e4de);
#
#
#
#         marker_188117933a33c8c21624c5034d671b9b.bindPopup(popup_56d0e303ea786e7b93523668325f3bb3)
#         ;
#
#
#
#
#             var marker_5eda3d16079dde025de21899f01ef28b = L.marker(
#                 [35.703198, -91.475651],
#                 {}
#             ).addTo(map_b4e61dd708d61794a0da6e344b98ae09);
#
#
#             var icon_6b0c0830651f7fa23a42978ef66304f4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5eda3d16079dde025de21899f01ef28b.setIcon(icon_6b0c0830651f7fa23a42978ef66304f4);
#
#
#         var popup_f895034b0abbc33785b08508bbe11729 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7304bae88303a5b8bff483683d0c63f = $(`&lt;div id=&quot;html_a7304bae88303a5b8bff483683d0c63f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_f895034b0abbc33785b08508bbe11729.setContent(html_a7304bae88303a5b8bff483683d0c63f);
#
#
#
#         marker_5eda3d16079dde025de21899f01ef28b.bindPopup(popup_f895034b0abbc33785b08508bbe11729)
#         ;
#
#
#
#
#             var marker_f26615511698773affff8db6d97cccc9 = L.marker(
#                 [35.05528, -93.36897],
#                 {}
#             ).addTo(map_b4e61dd708d61794a0da6e344b98ae09);
#
#
#             var icon_2403d76bde07f0bf6c486c21a9ad3d88 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %%
make_map(df_2018, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e360b6c483982da9aadb0b0487d08584 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e360b6c483982da9aadb0b0487d08584&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e360b6c483982da9aadb0b0487d08584 = L.map(
#                 &quot;map_e360b6c483982da9aadb0b0487d08584&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66c9d61be72d002b2267f83c09192bee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e360b6c483982da9aadb0b0487d08584);
#
#
#             var marker_0bcafe29d9237c412473a98560938ac4 = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_e360b6c483982da9aadb0b0487d08584);
#
#
#             var icon_fe9b316e6daeba876749e07056e33758 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0bcafe29d9237c412473a98560938ac4.setIcon(icon_fe9b316e6daeba876749e07056e33758);
#
#
#         var popup_9f0b586ee99ddaae035f146eff9a2350 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b96460918819197a583c5cdd8a765d2 = $(`&lt;div id=&quot;html_5b96460918819197a583c5cdd8a765d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_9f0b586ee99ddaae035f146eff9a2350.setContent(html_5b96460918819197a583c5cdd8a765d2);
#
#
#
#         marker_0bcafe29d9237c412473a98560938ac4.bindPopup(popup_9f0b586ee99ddaae035f146eff9a2350)
#         ;
#
#
#
#
#             var marker_cea10901c0f4d1fd3ac4993ea0bcca0d = L.marker(
#                 [35.269776, -93.085968],
#                 {}
#             ).addTo(map_e360b6c483982da9aadb0b0487d08584);
#
#
#             var icon_316d750bccf19451351971227763771a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cea10901c0f4d1fd3ac4993ea0bcca0d.setIcon(icon_316d750bccf19451351971227763771a);
#
#
#         var popup_32a40520336a811ac59f0132dbbf2536 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8683d260ff70d880b3bed3fdd7b1bf99 = $(`&lt;div id=&quot;html_8683d260ff70d880b3bed3fdd7b1bf99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_32a40520336a811ac59f0132dbbf2536.setContent(html_8683d260ff70d880b3bed3fdd7b1bf99);
#
#
#
#         marker_cea10901c0f4d1fd3ac4993ea0bcca0d.bindPopup(popup_32a40520336a811ac59f0132dbbf2536)
#         ;
#
#
#
#
#             var marker_ef7ef60d60ad352e0a7e5b5da1e4d07e = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_e360b6c483982da9aadb0b0487d08584);
#
#
#             var icon_121f0ef37c4b9f9668197546a6806d76 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ef7ef60d60ad352e0a7e5b5da1e4d07e.setIcon(icon_121f0ef37c4b9f9668197546a6806d76);
#
#
#         var popup_9e4161b73cc6a4ee26d57e552a4d2702 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6eeef435ba393abe434fc4189e51734a = $(`&lt;div id=&quot;html_6eeef435ba393abe434fc4189e51734a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_9e4161b73cc6a4ee26d57e552a4d2702.setContent(html_6eeef435ba393abe434fc4189e51734a);
#
#
#
#         marker_ef7ef60d60ad352e0a7e5b5da1e4d07e.bindPopup(popup_9e4161b73cc6a4ee26d57e552a4d2702)
#         ;
#
#
#
#
#             var marker_5f8e668807b6a8066d3274517349c988 = L.marker(
#                 [36.331155, -93.429488],
#                 {}
#             ).addTo(map_e360b6c483982da9aadb0b0487d08584);
#
#
#             var icon_b563ee875c7b0bb2c60311b82e026196 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %%
make_map(df_2019, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_563006a33996c584dc8e1f3259276842 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_563006a33996c584dc8e1f3259276842&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_563006a33996c584dc8e1f3259276842 = L.map(
#                 &quot;map_563006a33996c584dc8e1f3259276842&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa8328a8edfbfea519b0626500140bd5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_563006a33996c584dc8e1f3259276842);
#
#
#             var marker_9913bbbc3a06c148dc89255f428603c1 = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_563006a33996c584dc8e1f3259276842);
#
#
#             var icon_71a1898e7f391a320da76acf31dd5041 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9913bbbc3a06c148dc89255f428603c1.setIcon(icon_71a1898e7f391a320da76acf31dd5041);
#
#
#         var popup_65dccf34dbc898f26562da5be228be69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6043aaee201513045c0a3c310f323000 = $(`&lt;div id=&quot;html_6043aaee201513045c0a3c310f323000&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_65dccf34dbc898f26562da5be228be69.setContent(html_6043aaee201513045c0a3c310f323000);
#
#
#
#         marker_9913bbbc3a06c148dc89255f428603c1.bindPopup(popup_65dccf34dbc898f26562da5be228be69)
#         ;
#
#
#
#
#             var marker_60109969ebe2720d3a420e8ad16ad13c = L.marker(
#                 [35.269776, -93.085968],
#                 {}
#             ).addTo(map_563006a33996c584dc8e1f3259276842);
#
#
#             var icon_8eb456db01ef59a3f75ace4468f8d636 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_60109969ebe2720d3a420e8ad16ad13c.setIcon(icon_8eb456db01ef59a3f75ace4468f8d636);
#
#
#         var popup_453e0b2e0e3f2da45bb61170d0a7f895 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d1bf927e5107a9e1ccd14cdddc54739 = $(`&lt;div id=&quot;html_7d1bf927e5107a9e1ccd14cdddc54739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_453e0b2e0e3f2da45bb61170d0a7f895.setContent(html_7d1bf927e5107a9e1ccd14cdddc54739);
#
#
#
#         marker_60109969ebe2720d3a420e8ad16ad13c.bindPopup(popup_453e0b2e0e3f2da45bb61170d0a7f895)
#         ;
#
#
#
#
#             var marker_c0fab49d8a679c1c9264b7506f841179 = L.marker(
#                 [35.764666, -91.648842],
#                 {}
#             ).addTo(map_563006a33996c584dc8e1f3259276842);
#
#
#             var icon_f42113ee4d021bbda26c812aa75f72e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0fab49d8a679c1c9264b7506f841179.setIcon(icon_f42113ee4d021bbda26c812aa75f72e1);
#
#
#         var popup_1373396b19553caa528bc85fd6e74586 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a8fe792466e9e2ea6ac6eb9254717da = $(`&lt;div id=&quot;html_3a8fe792466e9e2ea6ac6eb9254717da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_1373396b19553caa528bc85fd6e74586.setContent(html_3a8fe792466e9e2ea6ac6eb9254717da);
#
#
#
#         marker_c0fab49d8a679c1c9264b7506f841179.bindPopup(popup_1373396b19553caa528bc85fd6e74586)
#         ;
#
#
#
#
#             var marker_76c6bd8f3a06a89ce4b14f3ea7b8fef2 = L.marker(
#                 [36.33113, -93.42862],
#                 {}
#             ).addTo(map_563006a33996c584dc8e1f3259276842);
#
#
#             var icon_15b21a33233885571efda2e37dcb08bb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %%
make_map(df_2020, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df585f774d8af3298788cb3547aafb16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df585f774d8af3298788cb3547aafb16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df585f774d8af3298788cb3547aafb16 = L.map(
#                 &quot;map_df585f774d8af3298788cb3547aafb16&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68e33e5057675bcec17ce3ab2acf9a5a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_df585f774d8af3298788cb3547aafb16);
#
#
#             var marker_df60aadb2d16427b26ebd2a469431c78 = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_df585f774d8af3298788cb3547aafb16);
#
#
#             var icon_6e226a85f587ca70f3f546f48cedfcb7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_df60aadb2d16427b26ebd2a469431c78.setIcon(icon_6e226a85f587ca70f3f546f48cedfcb7);
#
#
#         var popup_dd7c7c5523d186398ee578674a63a4b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ab725614cd78ea603f08a66a672f14c = $(`&lt;div id=&quot;html_7ab725614cd78ea603f08a66a672f14c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_dd7c7c5523d186398ee578674a63a4b8.setContent(html_7ab725614cd78ea603f08a66a672f14c);
#
#
#
#         marker_df60aadb2d16427b26ebd2a469431c78.bindPopup(popup_dd7c7c5523d186398ee578674a63a4b8)
#         ;
#
#
#
#
#             var marker_0d8dc12fc17ba4a52293734a9e0a3085 = L.marker(
#                 [35.269775, -93.085968],
#                 {}
#             ).addTo(map_df585f774d8af3298788cb3547aafb16);
#
#
#             var icon_0f1e672d893bf695f2e089bb1a6ff557 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d8dc12fc17ba4a52293734a9e0a3085.setIcon(icon_0f1e672d893bf695f2e089bb1a6ff557);
#
#
#         var popup_b9411986b2a54a80595ec819059c3bbb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd95dc96a2da5fc28a897cbbe6807fdd = $(`&lt;div id=&quot;html_bd95dc96a2da5fc28a897cbbe6807fdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_b9411986b2a54a80595ec819059c3bbb.setContent(html_bd95dc96a2da5fc28a897cbbe6807fdd);
#
#
#
#         marker_0d8dc12fc17ba4a52293734a9e0a3085.bindPopup(popup_b9411986b2a54a80595ec819059c3bbb)
#         ;
#
#
#
#
#             var marker_eb6f4ff3359aaed2ef3c610331b454e5 = L.marker(
#                 [36.177236, -94.537565],
#                 {}
#             ).addTo(map_df585f774d8af3298788cb3547aafb16);
#
#
#             var icon_a2a277063dbbe7afe1bddc09917d7c1d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eb6f4ff3359aaed2ef3c610331b454e5.setIcon(icon_a2a277063dbbe7afe1bddc09917d7c1d);
#
#
#         var popup_496d98554ac60967c95c0145f9bdb333 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93ebb524b516ddf1783ec8498af9d421 = $(`&lt;div id=&quot;html_93ebb524b516ddf1783ec8498af9d421&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_496d98554ac60967c95c0145f9bdb333.setContent(html_93ebb524b516ddf1783ec8498af9d421);
#
#
#
#         marker_eb6f4ff3359aaed2ef3c610331b454e5.bindPopup(popup_496d98554ac60967c95c0145f9bdb333)
#         ;
#
#
#
#
#             var marker_843ca9346a506e6af24019d7a7359f6b = L.marker(
#                 [35.764666, -91.648842],
#                 {}
#             ).addTo(map_df585f774d8af3298788cb3547aafb16);
#
#
#             var icon_d1918328bdbe6b3e8686988495d63473 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&q

# %%
make_map(df_2021, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21fc15d7a97cb41fe46d04f5e7deb484 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21fc15d7a97cb41fe46d04f5e7deb484&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21fc15d7a97cb41fe46d04f5e7deb484 = L.map(
#                 &quot;map_21fc15d7a97cb41fe46d04f5e7deb484&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53f9e7f985f2444a37408d4fb519da66 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_21fc15d7a97cb41fe46d04f5e7deb484);
#
#
#             var marker_90767c7d6e9d7914572d8466e1161fab = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_21fc15d7a97cb41fe46d04f5e7deb484);
#
#
#             var icon_a692eb7e7bc91057520898e78d8442b4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_90767c7d6e9d7914572d8466e1161fab.setIcon(icon_a692eb7e7bc91057520898e78d8442b4);
#
#
#         var popup_9508220bcac17b93b6a76492d279ad84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c13d82bfccd138606312e7d801bc89f = $(`&lt;div id=&quot;html_7c13d82bfccd138606312e7d801bc89f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_9508220bcac17b93b6a76492d279ad84.setContent(html_7c13d82bfccd138606312e7d801bc89f);
#
#
#
#         marker_90767c7d6e9d7914572d8466e1161fab.bindPopup(popup_9508220bcac17b93b6a76492d279ad84)
#         ;
#
#
#
#
#             var marker_7f2a2ad996bc242ee37af1fde82886fe = L.marker(
#                 [35.269775, -93.085968],
#                 {}
#             ).addTo(map_21fc15d7a97cb41fe46d04f5e7deb484);
#
#
#             var icon_34a49eeead4a0c6fda3841f9949649b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f2a2ad996bc242ee37af1fde82886fe.setIcon(icon_34a49eeead4a0c6fda3841f9949649b6);
#
#
#         var popup_343d494598d2196876bd47ceca8a9d45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_690c4e014bcb96b1b0367da41764e2c7 = $(`&lt;div id=&quot;html_690c4e014bcb96b1b0367da41764e2c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_343d494598d2196876bd47ceca8a9d45.setContent(html_690c4e014bcb96b1b0367da41764e2c7);
#
#
#
#         marker_7f2a2ad996bc242ee37af1fde82886fe.bindPopup(popup_343d494598d2196876bd47ceca8a9d45)
#         ;
#
#
#
#
#             var marker_99e9cc25e64a635e6e475df4ff359d4b = L.marker(
#                 [36.177236, -94.537565],
#                 {}
#             ).addTo(map_21fc15d7a97cb41fe46d04f5e7deb484);
#
#
#             var icon_b095c67c97a2bc4fa4cd3b2facc72722 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_99e9cc25e64a635e6e475df4ff359d4b.setIcon(icon_b095c67c97a2bc4fa4cd3b2facc72722);
#
#
#         var popup_20c758cec0e83e4a36b006762e0bb7a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f6a7035a16ba5bc444f02dbf054305e = $(`&lt;div id=&quot;html_3f6a7035a16ba5bc444f02dbf054305e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_20c758cec0e83e4a36b006762e0bb7a9.setContent(html_3f6a7035a16ba5bc444f02dbf054305e);
#
#
#
#         marker_99e9cc25e64a635e6e475df4ff359d4b.bindPopup(popup_20c758cec0e83e4a36b006762e0bb7a9)
#         ;
#
#
#
#
#             var marker_988ead72f6293d052a589e65d2768674 = L.marker(
#                 [35.764666, -91.648842],
#                 {}
#             ).addTo(map_21fc15d7a97cb41fe46d04f5e7deb484);
#
#
#             var icon_e01ec905f17e6681aedba554609f80c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&q

# %%
make_map(df_2022, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8de186ae379bc73a4829f07d6b0d4e68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8de186ae379bc73a4829f07d6b0d4e68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8de186ae379bc73a4829f07d6b0d4e68 = L.map(
#                 &quot;map_8de186ae379bc73a4829f07d6b0d4e68&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_167c3888e953176f303e3abd8973cd04 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8de186ae379bc73a4829f07d6b0d4e68);
#
#
#             var marker_3df7582625c7e4b18e13b5cc26adb2f3 = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_8de186ae379bc73a4829f07d6b0d4e68);
#
#
#             var icon_11e376b65044fdb38ed3e2981ee2e234 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3df7582625c7e4b18e13b5cc26adb2f3.setIcon(icon_11e376b65044fdb38ed3e2981ee2e234);
#
#
#         var popup_1e30d2040da17e28395981fe0fd64a74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11ce8404107a1bd707480f7f8af03ab1 = $(`&lt;div id=&quot;html_11ce8404107a1bd707480f7f8af03ab1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_1e30d2040da17e28395981fe0fd64a74.setContent(html_11ce8404107a1bd707480f7f8af03ab1);
#
#
#
#         marker_3df7582625c7e4b18e13b5cc26adb2f3.bindPopup(popup_1e30d2040da17e28395981fe0fd64a74)
#         ;
#
#
#
#
#             var marker_bbd2a7da7ce26f7427aa90dae99ed6cd = L.marker(
#                 [35.269775, -93.085968],
#                 {}
#             ).addTo(map_8de186ae379bc73a4829f07d6b0d4e68);
#
#
#             var icon_51a8531c075c88cbd6d959cd40f886cd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bbd2a7da7ce26f7427aa90dae99ed6cd.setIcon(icon_51a8531c075c88cbd6d959cd40f886cd);
#
#
#         var popup_c663ae09b5a6886e2fd96d13840a3771 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de97c0fb145b003942684c1264641b2b = $(`&lt;div id=&quot;html_de97c0fb145b003942684c1264641b2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_c663ae09b5a6886e2fd96d13840a3771.setContent(html_de97c0fb145b003942684c1264641b2b);
#
#
#
#         marker_bbd2a7da7ce26f7427aa90dae99ed6cd.bindPopup(popup_c663ae09b5a6886e2fd96d13840a3771)
#         ;
#
#
#
#
#             var marker_b399a0fe93c496a9b11fe8d2446b9a27 = L.marker(
#                 [36.177236, -94.537565],
#                 {}
#             ).addTo(map_8de186ae379bc73a4829f07d6b0d4e68);
#
#
#             var icon_ce577949ceb653ffa3ccfc2c43190179 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b399a0fe93c496a9b11fe8d2446b9a27.setIcon(icon_ce577949ceb653ffa3ccfc2c43190179);
#
#
#         var popup_557bd1df1fdf77963fb0f2ece31a5c20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e8b7504d40ebfc1b8eee2c9d70e0855 = $(`&lt;div id=&quot;html_6e8b7504d40ebfc1b8eee2c9d70e0855&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_557bd1df1fdf77963fb0f2ece31a5c20.setContent(html_6e8b7504d40ebfc1b8eee2c9d70e0855);
#
#
#
#         marker_b399a0fe93c496a9b11fe8d2446b9a27.bindPopup(popup_557bd1df1fdf77963fb0f2ece31a5c20)
#         ;
#
#
#
#
#             var marker_5464a435ca5741af1aaee1429b327316 = L.marker(
#                 [35.764666, -91.648842],
#                 {}
#             ).addTo(map_8de186ae379bc73a4829f07d6b0d4e68);
#
#
#             var icon_eaa2afe3df14f0429850056d89385269 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&q
