# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Input Data and Cleaning

# %%
fsis_df = pd.read_csv("data/FSIS.csv")
fsis_df.head(2)
# Out:
#    Unnamed: 0 EstNumber  Establishment ID  \
# 0           0     G1028               195
# 1           1     G1105            126734
#
#                                Company           Phone   GrantDate  \
# 0  Papetti's Hygrade Egg Products Inc.  (908) 282-7900  12/05/2019
# 1           American Egg Products, LLC  (912) 449-5700  09/22/2021
#
#     Activities DBAs LatestMPIActiveDate   Size Chicken\nSlaughter  \
# 0  Egg Product  NaN          2023-09-18  Small                NaN
# 1  Egg Product  NaN          2023-09-18  Small                NaN
#
#                   Full Address
# 0            One Papetti Plaza
# 1  375 Pierce Industrial Blvd.

# %%
fsis_df[fsis_df["Chicken\nSlaughter"].notnull()]
# Out:
#       Unnamed: 0                 EstNumber  Establishment ID  \
# 270          270  M10038 + P10038 + V10038              7125
# 274          274           M10053 + P10053              7130
# 297          297             M1015 + P1015              6413
# 422          422               M112 + P112              3847
# 474          474             M1234 + P1234           6163896
# ...          ...                       ...               ...
# 6182        6182                      P912              4493
# 6184        6184                     P9197               696
# 6187        6187                      P935              2260
# 6188        6188             P9378 + V9378            124559
# 6190        6190                     P9897              5413
#
#                                                Company           Phone  \
# 270                         Scotts Hook & Cleaver Inc.  (269) 626-8891
# 274   Michigan State University Dept of Animal Science  (517) 355-8452
# 297                            Table Trust Brands, LLC  (717) 436-5921
# 422                                   Tyson Foods, Inc  (870) 438-5211
# 474                               Mountaire Farms Inc.             NaN
# ...                                                ...             ...
# 6182                                   Wayne Farms LLC  (334) 738-2148
# 6184                                Perdue Foods, LLC.  (252) 348-4200
# 6187                                   Allen Harim LLC  (302) 684-1640
# 6188                       Baffoni's Poultry Farm Inc.             NaN
# 6190                              New Stockton Poultry  (209) 466-9503
#
#        GrantDate                                         Activities  \
# 270   08/11/2021  Meat Slaughter, Meat Processing, Poultry Slaug...
# 274   09/09/2014  Meat Slaughter, Meat Processing, Poultry Slaug...
# 297   10/28/2021  Meat Processing, Poultry Slaughter, Poultry Pr...
# 422   12/20/2019              Poultry Slaughter, Poultry Processing
# 474   09/14/2020  Meat Processing, Poultry Slaughter, Poultry Pr...
# ...          ...                                                ...
# 6182  04/05/2019              Poultry Slaughter, Poultry Processing
# 6184  02/04/2021              Poultry Slaughter, Poultry Processing
# 6187  03/30/2021              Poultry Slaughter, Poultry Processing
# 6188  02/07/2020  Poultry Slaughter, Poultry Processing, Volunta...
# 6190  07/30/2021                                  Poultry Slaughter
#
#                                                    DBAs LatestMPIActiveDate  \
# 270                           Pease Packing Corporation          2023-09-18
# 274                                        MSU Meat lab          2023-09-18
# 297           Alle; Empire Kosher; Galil; Kosher Valley          2023-09-18
# 422                        Tyson Foods , Inc. M112/P112          2023-09-18
# 474             Mountaire Farms of North Carolina Corp.          2023-09-18
# ...                                                 ...                 ...
# 6182  Covington Farms; Sanderson Farms, Inc.; Sander...          2023-09-18
# 6184  Chef's Choice; Cook 'n Good; Country Corner; H...          2023-09-18
# 6187                                                NaN          2023-09-18
# 6188                                                NaN          2023-09-18
# 6190                               New Stockton Poultry          2023-09-18
#
#             Size Chicken\nSlaughter              Full Address
# 270   Very Small                Yes    8713 South 38th Street
# 274   Very Small                Yes              Anthony Hall
# 297        Large                Yes          247 Empire Drive
# 422        Large                Yes           601 Tyson Drive
# 474        Large                Yes    1101 East Third Street
# ...          ...                ...                       ...
# 6182       Large                Yes  444 Baskin Street  South
# 6184       Large                Yes      3539 Governor's Road
# 6187       Large                Yes       18752 Harbeson Road
# 6188  Very Small                Yes     324 Greenville Avenue
# 6190       Small                Yes     302 S San Joaquin St.
#
# [259 rows x 12 columns]

# %%
fsis_df.Activities.value_counts()[:10]
# Out:
# Meat Processing, Poultry Processing                                        2823
# Meat Processing                                                             874
# Meat Slaughter, Meat Processing                                             496
# Certification - Export, Identification - Meat, Identification - Poultry     304
# Poultry Slaughter, Poultry Processing                                       206
# Meat Processing, Poultry Processing, Certification - Export                 181
# Imported Product                                                            148
# Poultry Processing                                                          142
# Meat Slaughter, Meat Processing, Poultry Processing                         113
# Meat Processing, Poultry Processing, Voluntary Processing - Meat             93
# Name: Activities, dtype: int64

# %%
fsis_df_cleaned = fsis_df.drop(columns=["DBAs","LatestMPIActiveDate",
                                        "GrantDate"])
fsis_df_cleaned = fsis_df_cleaned[fsis_df_cleaned["Activities"].str.contains("Poultry Processing")].copy()
#fsis_df_cleaned = fsis_df_cleaned[fsis_df_cleaned["Chicken\nSlaughter"].notnull()]

# %%
fsis_df_cleaned.head(2)
# Out:
#      Unnamed: 0          EstNumber  Establishment ID  \
# 260         260         M1 + P1370              2766
# 261         261  M10 + P7212 + V10              4119
#
#                                  Company           Phone  \
# 260                     Vienna Beef Ltd.  (312) 278-7800
# 261  Buckhead Meat & Seafood of Houston.  (281) 405-3200
#
#                                             Activities   Size  \
# 260                Meat Processing, Poultry Processing  Small
# 261  Meat Processing, Poultry Processing, Certifica...  Small
#
#     Chicken\nSlaughter                 Full Address
# 260                NaN      1000 West Pershing Road
# 261                NaN  10310 Greens Crossing Blvd.

# %%
cleaned_nets = pd.read_csv("data/nets/nets_cleaned.csv")
cleaned_nets.head(2)
# Out:
#    Unnamed: 0  DUNSNUMBER                                            COMPANY  \
# 0           0     2344232  WATSONS QULTY TURKEY PDTS INC                 ...
# 1           1     1326545  HENNINGSEN FOODS INC                          ...
#
#                                              ADDRESS  \
# 0  641 STATE RTE 168                             ...
# 1  10025 I ST                                    ...
#
#                              CITY STATE  ZIPCODE  \
# 0  BLACKWOOD                         NJ     8012
# 1  OMAHA                             NE    68127
#
#                                       PARENT COMPANY      SIC8  PARENT DUNS  \
# 0  WATSONS QULTY TURKEY PDTS INC                 ...  20150101      2344232
# 1  POST HOLDINGS INC                             ...  20150000    805730178
#
#     SALESHERE  SALESHEREC  SALESGROWTH  LATITUDE  LONGITUDE
# 0  26654460.0         3.0          2.0   39.7912    75.0597
# 1   6876800.0         3.0          2.0   41.2156    96.0697

# %% [markdown]
# # Fuzzy Matching

# %%
from fuzzywuzzy import fuzz

# %%
# The function takes in the fsis and nets datasets and uses fuzzy matching on address to add in
# parent company and sales information from the nets dataset to the fsis dataset

def find_best_match(df_fsis, df_nets, fuzz_ratio: float=75):
    df_fsis["Parent Company"] = np.NaN
    df_fsis["Sales"] = np.NaN
    df_fsis["latitude"] = np.NaN
    df_fsis["longitude"] = np.NaN
    for i, fsis in df_fsis.iterrows():
        fsis_address = fsis["Full Address"].lower()
        for k, nets in df_nets.iterrows():
            nets_address = nets["ADDRESS"]
            if fuzz.token_sort_ratio(nets_address, fsis_address) > fuzz_ratio:
                df_fsis.loc[i, "Parent Company"] = nets["PARENT COMPANY"]
                df_fsis.loc[i, "Sales"] = nets["SALESHERE"]
                df_fsis.loc[i, "latitude"] = nets["LATITUDE"]
                df_fsis.loc[i, "longitude"] = nets["LONGITUDE"]
                break
                
        # Progress reporting as function is slow
        if i % 50 == 0:
            print("{}%".format(np.round(i / df_fsis.shape[0] * 100,2)))
        # Band-aid fix for infinite looping error
        if i >= df_fsis.shape[0]:
            return df_fsis
    return df_fsis

# %%
df = find_best_match(fsis_df_cleaned, cleaned_nets)
df.head(2)
# Out:
# 7.16%
# 8.36%
# 9.55%
# 10.74%
# 11.94%
# 13.13%
# 15.52%
# 17.9%
# 19.1%
# 20.29%
# 21.48%
# 22.68%
# 23.87%
# 25.07%
# 26.26%
# 27.45%
# 28.65%
# 32.23%
# 33.42%
# 34.61%
# 35.81%
# 37.0%
# 38.2%
# 39.39%
# 40.58%
# 41.78%
# 42.97%
# 45.36%
# 46.55%
# 47.74%
# 50.13%
# 52.52%
# 54.91%
# 56.1%
# 58.49%
# 59.68%
# 64.45%
# 68.04%
# 69.23%
# 70.42%
# 71.62%
# 75.2%
# 76.39%
# 77.58%
# 78.78%
# 81.16%
# 82.36%
# 83.55%
# 85.94%
# 87.13%
# 88.33%
# 93.1%
# 95.49%
# 96.68%
# 97.88%
# 99.07%
#      Unnamed: 0          EstNumber  Establishment ID  \
# 260         260         M1 + P1370              2766
# 261         261  M10 + P7212 + V10              4119
#
#                                  Company           Phone  \
# 260                     Vienna Beef Ltd.  (312) 278-7800
# 261  Buckhead Meat & Seafood of Houston.  (281) 405-3200
#
#                                             Activities   Size  \
# 260                Meat Processing, Poultry Processing  Small
# 261  Meat Processing, Poultry Processing, Certifica...  Small
#
#     Chicken\nSlaughter                 Full Address Parent Company  Sales  \
# 260                NaN      1000 West Pershing Road            NaN    NaN
# 261                NaN  10310 Greens Crossing Blvd.            NaN    NaN
#
#      latitude  longitude
# 260       NaN        NaN
# 261       NaN        NaN

# %%
print(df.isna().sum())
print(df.shape[0])
print(df["Parent Company"].value_counts())
# Out:
# Unnamed: 0               0
# EstNumber                0
# Establishment ID         0
# Company                  0
# Phone                  619
# Activities               0
# Size                    41
# Chicken\nSlaughter    3932
# Full Address             0
# Parent Company        3734
# Sales                 3734
# latitude              3734
# longitude             3734
# dtype: int64
# 4189
# TYSON FOODS INC                                       48
# PERDUE FARMS INCORPORATED                             26
# PERDUE FARMS INC                                      26
# DLISTED                                               17
# JBS USA HOLDINGS INC                                  17
#                                                       ..
# EL JAY POULTRY CORP                                    1
# IDEAL PLTY BREEDING FARMS INC                          1
# CRIDER CLAXTON LLC                                     1
# TALISMAN FOODS INC                                     1
# AMERICAN OSTRICH COMPANY LLC                           1
# Name: Parent Company, Length: 196, dtype: int64

# %%
df_vF = df[df.Sales.notnull()]

# %%
df_vF.to_csv("output/cleaned_matched_plants_v2.csv")
