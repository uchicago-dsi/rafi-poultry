# %% [markdown]
# ## Load-In Data

# %%
import pandas as pd
import numpy as np
import folium
import geopandas as gpd

# %%
master = pd.read_csv("../../data/master-df.csv")
master = master.dropna(subset=['LONGITUDE', 'LATITUDE', 'COMPANY'])
georgia = master.loc[master.STATE == 'GA']
georgia.drop(columns=['Unnamed: 0']).head(3)
# Out:
#                   COMPANY         ADDRESS LINE 1      CITY STATE  ZIPCODE  \
# 109  PILGRIM'S PRIDE CORP  1129 OLD MIDDLETON RD  ELBERTON    GA  30635.0
# 110  PILGRIM'S PRIDE CORP  1129 OLD MIDDLETON RD  ELBERTON    GA  30635.0
# 111  PILGRIM'S PRIDE CORP  1129 OLD MIDDLETON RD  ELBERTON    GA  30635.0
#
#      PRIMARY SIC CODE  ARCHIVE VERSION YEAR  YEAR ESTABLISHED     ABI  \
# 109          201501.0                  2022              1983  457788
# 110          201501.0                  2021              1983  457788
# 111          201501.0                  2020              1983  457788
#
#      COMPANY HOLDING STATUS  PARENT NUMBER   LATITUDE  LONGITUDE  \
# 109                       0      987289857  34.096808 -82.838565
# 110                       0      987289857  34.096808 -82.838565
# 111                       0      987289857  34.096808 -82.838565
#
#      YEAR 1ST APPEARED PARENT NAME           CHANGE_BOOL  CHANGE_NUM
# 109                  0     JBS USA  Pilgrim's Pride Corp         1.0
# 110               1984     JBS USA  Pilgrim's Pride Corp         1.0
# 111                  0     JBS USA  Pilgrim's Pride Corp         1.0

# %%
georgia.isnull().sum()
# Out:
# Unnamed: 0                 0
# COMPANY                    0
# ADDRESS LINE 1             0
# CITY                       0
# STATE                      0
# ZIPCODE                    0
# PRIMARY SIC CODE           0
# ARCHIVE VERSION YEAR       0
# YEAR ESTABLISHED         738
# ABI                        0
# PARENT NUMBER            464
# LATITUDE                   0
# LONGITUDE                  0
# YEAR 1ST APPEARED       1209
# PARENT NAME                0
# CHANGE_BOOL                0
# CHANGE_NUM                 0
# dtype: int64

# %% [markdown]
# ## Separate by Years; Georgia

# %%
df_2022 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2022].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2021 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2021].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2020 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2020].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2019 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2019].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2018 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2018].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2017 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2017].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2016 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2016].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2015 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2015].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2014 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2014].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2013 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2013].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2012 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2012].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2011 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2011].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2010 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2010].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2009 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2009].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2008 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2008].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2007 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2007].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2006 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2006].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2005 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2005].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2004 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2004].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2003 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2003].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2002 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2002].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2001 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2001].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2000 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 2000].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_1999 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 1999].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_1998 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 1998].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_1997 = georgia.loc[georgia['ARCHIVE VERSION YEAR'] == 1997].reset_index(drop=True).drop(columns=['Unnamed: 0'])

# %% [markdown]
# ## Making Georgia Maps

# %%
GA_LAT = 32.157
GA_LNG = -82.907

# %%
georgia['PARENT NAME'].value_counts()
# Out:
# None                          554
# JBS USA                       185
# Tyson Foods Inc               137
# Small Biz                     102
# Koch Foods Inc                 66
# Pilgrim's Pride Corp           53
# Sanderson Farms Inc            39
# Continental Grain Co           33
# UNKNOWN                        31
# Cal-main Foods Inc             19
# House of Raeford Farms Inc     16
# Perdue Farms Inc               13
# Conagra Brands Inc             12
# Cargil Inc                      4
# Hormel Foods Corp               3
# Name: PARENT NAME, dtype: int64

# %%
placeholder = ["None", "Small Biz", "Koch Foods Inc", "Pilgrim's Pride Corp", "Sanderson Farms Inc", "Continental Grain Co", "UNKNOWN",
"Cal-main Foods Inc", "House of Raeford Farms Inc", "Perdue Farms Inc", "Conagra Brands Inc", "Cargil Inc", "Hormel Foods Corp"]
dict_place = dict.fromkeys(placeholder, "lightgray" )

# %%
dict_place2 = dict({"Tyson Foods Inc": 'green', 
                "JBS USA": 'red'})

# %%
col_dict = {**dict_place2, **dict_place}
col_dict
# Out:
# {'Tyson Foods Inc': 'green',
#  'JBS USA': 'red',
#  'None': 'lightgray',
#  'Small Biz': 'lightgray',
#  'Koch Foods Inc': 'lightgray',
#  "Pilgrim's Pride Corp": 'lightgray',
#  'Sanderson Farms Inc': 'lightgray',
#  'Continental Grain Co': 'lightgray',
#  'UNKNOWN': 'lightgray',
#  'Cal-main Foods Inc': 'lightgray',
#  'House of Raeford Farms Inc': 'lightgray',
#  'Perdue Farms Inc': 'lightgray',
#  'Conagra Brands Inc': 'lightgray',
#  'Cargil Inc': 'lightgray',
#  'Hormel Foods Corp': 'lightgray'}

# %%
georgia['COLOR'] = georgia['PARENT NAME'].map(col_dict)
georgia.head(3)
# Out:
# /var/folders/ly/2syhzlz16r73t4fqm0kkkz2h0000gn/T/ipykernel_17398/2763352931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   georgia['COLOR'] = georgia['PARENT NAME'].map(col_dict)
#      Unnamed: 0               COMPANY         ADDRESS LINE 1      CITY STATE  \
# 109         109  PILGRIM'S PRIDE CORP  1129 OLD MIDDLETON RD  ELBERTON    GA
# 110         110  PILGRIM'S PRIDE CORP  1129 OLD MIDDLETON RD  ELBERTON    GA
# 111         111  PILGRIM'S PRIDE CORP  1129 OLD MIDDLETON RD  ELBERTON    GA
#
#      ZIPCODE  PRIMARY SIC CODE  ARCHIVE VERSION YEAR  YEAR ESTABLISHED  \
# 109  30635.0          201501.0                  2022            1983.0
# 110  30635.0          201501.0                  2021            1983.0
# 111  30635.0          201501.0                  2020            1983.0
#
#         ABI  PARENT NUMBER   LATITUDE  LONGITUDE  YEAR 1ST APPEARED  \
# 109  457788    987289857.0  34.096808 -82.838565                NaN
# 110  457788    987289857.0  34.096808 -82.838565             1984.0
# 111  457788    987289857.0  34.096808 -82.838565                NaN
#
#     PARENT NAME           CHANGE_BOOL  CHANGE_NUM COLOR
# 109     JBS USA  Pilgrim's Pride Corp         1.0   red
# 110     JBS USA  Pilgrim's Pride Corp         1.0   red
# 111     JBS USA  Pilgrim's Pride Corp         1.0   red

# %%
georgia['COLOR'].value_counts()
# Out:
# lightgray    945
# red          185
# green        137
# Name: COLOR, dtype: int64

# %%
def make_map(df, map_name):
    map_name = folium.Map(location=[GA_LAT, GA_LNG],zoom_start=6)
    
    df['COLOR'] = df['PARENT NAME'].map(col_dict)

    for index, location_info in df.iterrows():
        folium.Marker([location_info["LATITUDE"], location_info["LONGITUDE"]], popup = location_info['PARENT NAME'],
                icon=folium.Icon(color=location_info['COLOR'])).add_to(map_name)
        
    display(map_name)

# %%
make_map(df_1997, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d761d65adf50049a080b674281f7d9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d761d65adf50049a080b674281f7d9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d761d65adf50049a080b674281f7d9c = L.map(
#                 &quot;map_9d761d65adf50049a080b674281f7d9c&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_147aeae22261802524f226956e9d266c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d761d65adf50049a080b674281f7d9c);
#
#
#             var marker_8e774794a510c5e6d19ca0481397fa05 = L.marker(
#                 [34.096801, -82.838561],
#                 {}
#             ).addTo(map_9d761d65adf50049a080b674281f7d9c);
#
#
#             var icon_d0142ab72a495b64a517dca384520a3d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8e774794a510c5e6d19ca0481397fa05.setIcon(icon_d0142ab72a495b64a517dca384520a3d);
#
#
#         var popup_2cd4f6b9a5ccddd2ea82c0bf71668159 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a611fee4eda9c1a6a822b0b9d71b4a60 = $(`&lt;div id=&quot;html_a611fee4eda9c1a6a822b0b9d71b4a60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_2cd4f6b9a5ccddd2ea82c0bf71668159.setContent(html_a611fee4eda9c1a6a822b0b9d71b4a60);
#
#
#
#         marker_8e774794a510c5e6d19ca0481397fa05.bindPopup(popup_2cd4f6b9a5ccddd2ea82c0bf71668159)
#         ;
#
#
#
#
#             var marker_0dc92f208383dbd5f42fbef2f5e673c1 = L.marker(
#                 [33.959099, -84.515122],
#                 {}
#             ).addTo(map_9d761d65adf50049a080b674281f7d9c);
#
#
#             var icon_644ec59ce8d46924d150f9c6e8fb16b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0dc92f208383dbd5f42fbef2f5e673c1.setIcon(icon_644ec59ce8d46924d150f9c6e8fb16b2);
#
#
#         var popup_1b14024cdcddf4264d75301c5d70df91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c710500e580629b2d6cdd4e998800380 = $(`&lt;div id=&quot;html_c710500e580629b2d6cdd4e998800380&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_1b14024cdcddf4264d75301c5d70df91.setContent(html_c710500e580629b2d6cdd4e998800380);
#
#
#
#         marker_0dc92f208383dbd5f42fbef2f5e673c1.bindPopup(popup_1b14024cdcddf4264d75301c5d70df91)
#         ;
#
#
#
#
#             var marker_ec246c8b2df14999a3e6576315b650c9 = L.marker(
#                 [34.012103, -85.063215],
#                 {}
#             ).addTo(map_9d761d65adf50049a080b674281f7d9c);
#
#
#             var icon_641975f6b1085b4b6409f6523f230988 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ec246c8b2df14999a3e6576315b650c9.setIcon(icon_641975f6b1085b4b6409f6523f230988);
#
#
#         var popup_fc4cabc7b6400f4ce170624add97d7db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5f0aa6108b5afa3cdd0eda5d4937491 = $(`&lt;div id=&quot;html_b5f0aa6108b5afa3cdd0eda5d4937491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_fc4cabc7b6400f4ce170624add97d7db.setContent(html_b5f0aa6108b5afa3cdd0eda5d4937491);
#
#
#
#         marker_ec246c8b2df14999a3e6576315b650c9.bindPopup(popup_fc4cabc7b6400f4ce170624add97d7db)
#         ;
#
#
#
#
#             var marker_c75ad8466eb26fe7de7e16c3468481d8 = L.marker(
#                 [34.193271, -84.50189],
#                 {}
#             ).addTo(map_9d761d65adf50049a080b674281f7d9c);
#
#
#             var icon_7e17045f85ada8e944513ed84018efd7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&qu

# %%
make_map(df_1998, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_449425297aec891f4cc2af76c51abd0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_449425297aec891f4cc2af76c51abd0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_449425297aec891f4cc2af76c51abd0c = L.map(
#                 &quot;map_449425297aec891f4cc2af76c51abd0c&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_707dfa7882111b307987bc5d09c4ab22 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_449425297aec891f4cc2af76c51abd0c);
#
#
#             var marker_fb8b3c8454f2d41d395c3f587a9d8827 = L.marker(
#                 [33.9781, -83.3634],
#                 {}
#             ).addTo(map_449425297aec891f4cc2af76c51abd0c);
#
#
#             var icon_5fcca8fac43cd124a9920fccdc62c3bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fb8b3c8454f2d41d395c3f587a9d8827.setIcon(icon_5fcca8fac43cd124a9920fccdc62c3bc);
#
#
#         var popup_7092c6fdbd9a225608c51ccce045538a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35efbed0733ea098c4b804e9d88f9665 = $(`&lt;div id=&quot;html_35efbed0733ea098c4b804e9d88f9665&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_7092c6fdbd9a225608c51ccce045538a.setContent(html_35efbed0733ea098c4b804e9d88f9665);
#
#
#
#         marker_fb8b3c8454f2d41d395c3f587a9d8827.bindPopup(popup_7092c6fdbd9a225608c51ccce045538a)
#         ;
#
#
#
#
#             var marker_969ee2170fc0bb692ffe53a23c6633dc = L.marker(
#                 [33.571228, -83.152437],
#                 {}
#             ).addTo(map_449425297aec891f4cc2af76c51abd0c);
#
#
#             var icon_7474a02170f48037808f0b7e612e1455 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_969ee2170fc0bb692ffe53a23c6633dc.setIcon(icon_7474a02170f48037808f0b7e612e1455);
#
#
#         var popup_618d02b101e63483431c6098852ff77a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91229a9202e0bd764e3928227e5f3374 = $(`&lt;div id=&quot;html_91229a9202e0bd764e3928227e5f3374&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_618d02b101e63483431c6098852ff77a.setContent(html_91229a9202e0bd764e3928227e5f3374);
#
#
#
#         marker_969ee2170fc0bb692ffe53a23c6633dc.bindPopup(popup_618d02b101e63483431c6098852ff77a)
#         ;
#
#
#
#
#             var marker_c3803f343083ac58220da9333c4be2c1 = L.marker(
#                 [33.755274, -84.390756],
#                 {}
#             ).addTo(map_449425297aec891f4cc2af76c51abd0c);
#
#
#             var icon_0937c84b7d4e3dce4fcabe79a947c552 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3803f343083ac58220da9333c4be2c1.setIcon(icon_0937c84b7d4e3dce4fcabe79a947c552);
#
#
#         var popup_831156c529f33c9238b7c80c2e8176c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4fa189df8eaadfed252494fa0bf316b6 = $(`&lt;div id=&quot;html_4fa189df8eaadfed252494fa0bf316b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UNKNOWN&lt;/div&gt;`)[0];
#                 popup_831156c529f33c9238b7c80c2e8176c6.setContent(html_4fa189df8eaadfed252494fa0bf316b6);
#
#
#
#         marker_c3803f343083ac58220da9333c4be2c1.bindPopup(popup_831156c529f33c9238b7c80c2e8176c6)
#         ;
#
#
#
#
#             var marker_c68d1caff50916c3a914a354cf330f5b = L.marker(
#                 [31.230697, -84.207977],
#                 {}
#             ).addTo(map_449425297aec891f4cc2af76c51abd0c);
#
#
#             var icon_3aecfca4727d3b0b42392381b8d3c997 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,

# %%
make_map(df_1999, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10c0ed147f0a1ce9558b9849489a7bca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10c0ed147f0a1ce9558b9849489a7bca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10c0ed147f0a1ce9558b9849489a7bca = L.map(
#                 &quot;map_10c0ed147f0a1ce9558b9849489a7bca&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39ae6b2e7cdd8a60b140bfa33da3e73c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_10c0ed147f0a1ce9558b9849489a7bca);
#
#
#             var marker_cc7406f88d5936eeee91680b7dc6a3a0 = L.marker(
#                 [34.108829, -82.864863],
#                 {}
#             ).addTo(map_10c0ed147f0a1ce9558b9849489a7bca);
#
#
#             var icon_8acaf08289008e0f30a20c26784db1c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cc7406f88d5936eeee91680b7dc6a3a0.setIcon(icon_8acaf08289008e0f30a20c26784db1c2);
#
#
#         var popup_2858aec784b97a50da2308c2a7129b4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f081eececdda365194d03fe57c3b9093 = $(`&lt;div id=&quot;html_f081eececdda365194d03fe57c3b9093&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_2858aec784b97a50da2308c2a7129b4f.setContent(html_f081eececdda365194d03fe57c3b9093);
#
#
#
#         marker_cc7406f88d5936eeee91680b7dc6a3a0.bindPopup(popup_2858aec784b97a50da2308c2a7129b4f)
#         ;
#
#
#
#
#             var marker_cf0b6b20c6a1f10848569a229ac30b82 = L.marker(
#                 [33.953588, -84.544991],
#                 {}
#             ).addTo(map_10c0ed147f0a1ce9558b9849489a7bca);
#
#
#             var icon_fb80e09318cfb7980e83667bd2625bf6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf0b6b20c6a1f10848569a229ac30b82.setIcon(icon_fb80e09318cfb7980e83667bd2625bf6);
#
#
#         var popup_a0fc8b62366a96a6bbfa62cf9dde82ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12ae18de8ab1b4bd35235ccee2ec582f = $(`&lt;div id=&quot;html_12ae18de8ab1b4bd35235ccee2ec582f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_a0fc8b62366a96a6bbfa62cf9dde82ff.setContent(html_12ae18de8ab1b4bd35235ccee2ec582f);
#
#
#
#         marker_cf0b6b20c6a1f10848569a229ac30b82.bindPopup(popup_a0fc8b62366a96a6bbfa62cf9dde82ff)
#         ;
#
#
#
#
#             var marker_3a2ab890e44b3fda432c857f9f3b2a19 = L.marker(
#                 [33.92784, -83.71333],
#                 {}
#             ).addTo(map_10c0ed147f0a1ce9558b9849489a7bca);
#
#
#             var icon_2fd51868978352b89286ae5e6a6b4958 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3a2ab890e44b3fda432c857f9f3b2a19.setIcon(icon_2fd51868978352b89286ae5e6a6b4958);
#
#
#         var popup_a3d49572abc8be765b8099b9b7da460f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b12f7d5049c509a19fb90cc264467109 = $(`&lt;div id=&quot;html_b12f7d5049c509a19fb90cc264467109&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_a3d49572abc8be765b8099b9b7da460f.setContent(html_b12f7d5049c509a19fb90cc264467109);
#
#
#
#         marker_3a2ab890e44b3fda432c857f9f3b2a19.bindPopup(popup_a3d49572abc8be765b8099b9b7da460f)
#         ;
#
#
#
#
#             var marker_5a2e8d1696cf168a9e0fc7bcaa3e646f = L.marker(
#                 [34.211127, -83.888744],
#                 {}
#             ).addTo(map_10c0ed147f0a1ce9558b9849489a7bca);
#
#
#             var icon_635cd4c7bbc991b619a44f45b6202ba5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quo

# %%
make_map(df_2000, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f23c3f3154dd29043559e94cc048b10c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f23c3f3154dd29043559e94cc048b10c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f23c3f3154dd29043559e94cc048b10c = L.map(
#                 &quot;map_f23c3f3154dd29043559e94cc048b10c&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03fa69f23cfbd373220270387712ca50 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f23c3f3154dd29043559e94cc048b10c);
#
#
#             var marker_9f2dc3c3f460da54052899cc688aeabe = L.marker(
#                 [34.211127, -83.888744],
#                 {}
#             ).addTo(map_f23c3f3154dd29043559e94cc048b10c);
#
#
#             var icon_ec450efd2dc58c97d26d2e9dddb50082 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9f2dc3c3f460da54052899cc688aeabe.setIcon(icon_ec450efd2dc58c97d26d2e9dddb50082);
#
#
#         var popup_43c1ab8b84e71778bcab78cddd11c8a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2dcafc6622d2196d08bf5ae62a52daa = $(`&lt;div id=&quot;html_a2dcafc6622d2196d08bf5ae62a52daa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_43c1ab8b84e71778bcab78cddd11c8a7.setContent(html_a2dcafc6622d2196d08bf5ae62a52daa);
#
#
#
#         marker_9f2dc3c3f460da54052899cc688aeabe.bindPopup(popup_43c1ab8b84e71778bcab78cddd11c8a7)
#         ;
#
#
#
#
#             var marker_05230538c89c962b6ad52e360074e723 = L.marker(
#                 [31.769944, -84.420276],
#                 {}
#             ).addTo(map_f23c3f3154dd29043559e94cc048b10c);
#
#
#             var icon_d5fb82807e8151edce586160c9a785a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_05230538c89c962b6ad52e360074e723.setIcon(icon_d5fb82807e8151edce586160c9a785a6);
#
#
#         var popup_e773be14c6cd911f2755c9053caa31a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2310508f2aec40faf4e81d63016cbc5e = $(`&lt;div id=&quot;html_2310508f2aec40faf4e81d63016cbc5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_e773be14c6cd911f2755c9053caa31a4.setContent(html_2310508f2aec40faf4e81d63016cbc5e);
#
#
#
#         marker_05230538c89c962b6ad52e360074e723.bindPopup(popup_e773be14c6cd911f2755c9053caa31a4)
#         ;
#
#
#
#
#             var marker_7d24879c1f45611e9473fe6be80a3ccd = L.marker(
#                 [33.571228, -83.152437],
#                 {}
#             ).addTo(map_f23c3f3154dd29043559e94cc048b10c);
#
#
#             var icon_8303940aec10e21aaa62fdc622f57f4f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7d24879c1f45611e9473fe6be80a3ccd.setIcon(icon_8303940aec10e21aaa62fdc622f57f4f);
#
#
#         var popup_29c140944fcbefe5c3216afa885aadf3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e2acc21cee1cece0b7acc66ec8d9d08 = $(`&lt;div id=&quot;html_5e2acc21cee1cece0b7acc66ec8d9d08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_29c140944fcbefe5c3216afa885aadf3.setContent(html_5e2acc21cee1cece0b7acc66ec8d9d08);
#
#
#
#         marker_7d24879c1f45611e9473fe6be80a3ccd.bindPopup(popup_29c140944fcbefe5c3216afa885aadf3)
#         ;
#
#
#
#
#             var marker_c9878dd2a04604248a2311bb0ac9f643 = L.marker(
#                 [33.755274, -84.390756],
#                 {}
#             ).addTo(map_f23c3f3154dd29043559e94cc048b10c);
#
#
#             var icon_b7ca9663f7b8334d2a051906ee2978ab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign

# %%
make_map(df_2001, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7edbf10e884a8acb2448ae64454edbb0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7edbf10e884a8acb2448ae64454edbb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7edbf10e884a8acb2448ae64454edbb0 = L.map(
#                 &quot;map_7edbf10e884a8acb2448ae64454edbb0&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_825bb47a9b2aecee751379cbda3f62f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7edbf10e884a8acb2448ae64454edbb0);
#
#
#             var marker_f32bffef3806a85542b40a9028649b1b = L.marker(
#                 [34.108829, -82.864863],
#                 {}
#             ).addTo(map_7edbf10e884a8acb2448ae64454edbb0);
#
#
#             var icon_37acc88607d201f2ea29684baf8ede71 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f32bffef3806a85542b40a9028649b1b.setIcon(icon_37acc88607d201f2ea29684baf8ede71);
#
#
#         var popup_e3c6ca2644fddf841c3e73ec683de3fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb5d8ca6cc12efc54a2bae11bc8a1412 = $(`&lt;div id=&quot;html_fb5d8ca6cc12efc54a2bae11bc8a1412&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Conagra Brands Inc&lt;/div&gt;`)[0];
#                 popup_e3c6ca2644fddf841c3e73ec683de3fb.setContent(html_fb5d8ca6cc12efc54a2bae11bc8a1412);
#
#
#
#         marker_f32bffef3806a85542b40a9028649b1b.bindPopup(popup_e3c6ca2644fddf841c3e73ec683de3fb)
#         ;
#
#
#
#
#             var marker_d3f7b338a31bae700b86918d0aafad98 = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_7edbf10e884a8acb2448ae64454edbb0);
#
#
#             var icon_c4fc212842d4acf96e8c9762ad773173 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d3f7b338a31bae700b86918d0aafad98.setIcon(icon_c4fc212842d4acf96e8c9762ad773173);
#
#
#         var popup_8422caf959dc0d2ed20de5b062175f80 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6168b672dee75e2c4b0ff9433af55337 = $(`&lt;div id=&quot;html_6168b672dee75e2c4b0ff9433af55337&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_8422caf959dc0d2ed20de5b062175f80.setContent(html_6168b672dee75e2c4b0ff9433af55337);
#
#
#
#         marker_d3f7b338a31bae700b86918d0aafad98.bindPopup(popup_8422caf959dc0d2ed20de5b062175f80)
#         ;
#
#
#
#
#             var marker_436a5e5ca9bb79ebe972f9307bf7ab14 = L.marker(
#                 [34.012103, -85.063215],
#                 {}
#             ).addTo(map_7edbf10e884a8acb2448ae64454edbb0);
#
#
#             var icon_c3fe5d380dad27c62620b700a08570b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_436a5e5ca9bb79ebe972f9307bf7ab14.setIcon(icon_c3fe5d380dad27c62620b700a08570b3);
#
#
#         var popup_e7a8ccfae0bd8599b5a1f20c6c810411 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe0f25bfbe115ed56ab6dd24c727be39 = $(`&lt;div id=&quot;html_fe0f25bfbe115ed56ab6dd24c727be39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_e7a8ccfae0bd8599b5a1f20c6c810411.setContent(html_fe0f25bfbe115ed56ab6dd24c727be39);
#
#
#
#         marker_436a5e5ca9bb79ebe972f9307bf7ab14.bindPopup(popup_e7a8ccfae0bd8599b5a1f20c6c810411)
#         ;
#
#
#
#
#             var marker_7fdefa5d716ce3e5bcaea9508a5ed076 = L.marker(
#                 [31.502414, -82.849495],
#                 {}
#             ).addTo(map_7edbf10e884a8acb2448ae64454edbb0);
#
#
#             var icon_5f7e1262e9d1a3ed0200a3c97098b496 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &qu

# %%
make_map(df_2002, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f19eb961f5808ec04b88e5070d41d7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f19eb961f5808ec04b88e5070d41d7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f19eb961f5808ec04b88e5070d41d7e = L.map(
#                 &quot;map_2f19eb961f5808ec04b88e5070d41d7e&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3272f8943fc0971f119dd2402d5062a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2f19eb961f5808ec04b88e5070d41d7e);
#
#
#             var marker_ba1375be96bdbc032eae1eb42af55ec7 = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_2f19eb961f5808ec04b88e5070d41d7e);
#
#
#             var icon_b6a00d1b1c0215a92b2aab29c66a0c9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba1375be96bdbc032eae1eb42af55ec7.setIcon(icon_b6a00d1b1c0215a92b2aab29c66a0c9a);
#
#
#         var popup_fb2a43dbdcc074357f088f8b39331f6f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b988f189b2924105ef99bab263c6eed = $(`&lt;div id=&quot;html_2b988f189b2924105ef99bab263c6eed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_fb2a43dbdcc074357f088f8b39331f6f.setContent(html_2b988f189b2924105ef99bab263c6eed);
#
#
#
#         marker_ba1375be96bdbc032eae1eb42af55ec7.bindPopup(popup_fb2a43dbdcc074357f088f8b39331f6f)
#         ;
#
#
#
#
#             var marker_846a7dd293434a582c7fcb2e264a0cb5 = L.marker(
#                 [33.953588, -84.544991],
#                 {}
#             ).addTo(map_2f19eb961f5808ec04b88e5070d41d7e);
#
#
#             var icon_e23683642f3c2bd5a7f7506352c7d789 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_846a7dd293434a582c7fcb2e264a0cb5.setIcon(icon_e23683642f3c2bd5a7f7506352c7d789);
#
#
#         var popup_deacccb388fa0e300f0fdd4d6a6230d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46fef2f36b30874fbef67fc8e0db4797 = $(`&lt;div id=&quot;html_46fef2f36b30874fbef67fc8e0db4797&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_deacccb388fa0e300f0fdd4d6a6230d7.setContent(html_46fef2f36b30874fbef67fc8e0db4797);
#
#
#
#         marker_846a7dd293434a582c7fcb2e264a0cb5.bindPopup(popup_deacccb388fa0e300f0fdd4d6a6230d7)
#         ;
#
#
#
#
#             var marker_195be9910313be1c534ceca9eafc7bea = L.marker(
#                 [31.502414, -82.849495],
#                 {}
#             ).addTo(map_2f19eb961f5808ec04b88e5070d41d7e);
#
#
#             var icon_cb36fa4c700239ecfd7b03b7ec359768 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_195be9910313be1c534ceca9eafc7bea.setIcon(icon_cb36fa4c700239ecfd7b03b7ec359768);
#
#
#         var popup_149f9fc3b62208efdd276764356b5968 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff161a016488a0cb2163abeea6023d15 = $(`&lt;div id=&quot;html_ff161a016488a0cb2163abeea6023d15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UNKNOWN&lt;/div&gt;`)[0];
#                 popup_149f9fc3b62208efdd276764356b5968.setContent(html_ff161a016488a0cb2163abeea6023d15);
#
#
#
#         marker_195be9910313be1c534ceca9eafc7bea.bindPopup(popup_149f9fc3b62208efdd276764356b5968)
#         ;
#
#
#
#
#             var marker_22e0b4612acf1322774d88cbc774bda3 = L.marker(
#                 [34.298237, -83.822074],
#                 {}
#             ).addTo(map_2f19eb961f5808ec04b88e5070d41d7e);
#
#
#             var icon_4538be7f5877f5b892e608cf252d2ec7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sig

# %%
make_map(df_2003, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e30a1b11f876173c936915caeecf40a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e30a1b11f876173c936915caeecf40a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e30a1b11f876173c936915caeecf40a = L.map(
#                 &quot;map_6e30a1b11f876173c936915caeecf40a&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_268a17638b6c8ffc3c6080f1212c6f29 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e30a1b11f876173c936915caeecf40a);
#
#
#             var marker_4f2da04880efce27e0e49a6044a60e1f = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_6e30a1b11f876173c936915caeecf40a);
#
#
#             var icon_5e9af163dedd699e284364d5522c22de = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4f2da04880efce27e0e49a6044a60e1f.setIcon(icon_5e9af163dedd699e284364d5522c22de);
#
#
#         var popup_9e82035f1254afd821adbed0e621abe3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f74f00d6680593cb21a48f1760e8c476 = $(`&lt;div id=&quot;html_f74f00d6680593cb21a48f1760e8c476&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Conagra Brands Inc&lt;/div&gt;`)[0];
#                 popup_9e82035f1254afd821adbed0e621abe3.setContent(html_f74f00d6680593cb21a48f1760e8c476);
#
#
#
#         marker_4f2da04880efce27e0e49a6044a60e1f.bindPopup(popup_9e82035f1254afd821adbed0e621abe3)
#         ;
#
#
#
#
#             var marker_0e3c435957d5d482c7521692ce41bbab = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_6e30a1b11f876173c936915caeecf40a);
#
#
#             var icon_d77f2ee75f58f521841cd5ff5bbbb456 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0e3c435957d5d482c7521692ce41bbab.setIcon(icon_d77f2ee75f58f521841cd5ff5bbbb456);
#
#
#         var popup_5de854b32f4524d9116c29269f059b64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56cc131c346757c0b7d9afddc7701da6 = $(`&lt;div id=&quot;html_56cc131c346757c0b7d9afddc7701da6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_5de854b32f4524d9116c29269f059b64.setContent(html_56cc131c346757c0b7d9afddc7701da6);
#
#
#
#         marker_0e3c435957d5d482c7521692ce41bbab.bindPopup(popup_5de854b32f4524d9116c29269f059b64)
#         ;
#
#
#
#
#             var marker_eb3629a0a28cf099d7df93b84709c870 = L.marker(
#                 [31.527259, -82.847101],
#                 {}
#             ).addTo(map_6e30a1b11f876173c936915caeecf40a);
#
#
#             var icon_6b13557d2622696924467a3943115cb3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_eb3629a0a28cf099d7df93b84709c870.setIcon(icon_6b13557d2622696924467a3943115cb3);
#
#
#         var popup_66aea46e1643910aa3e50a9c3b695a37 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_129d33da30e7a4c0753b1987f990d0cb = $(`&lt;div id=&quot;html_129d33da30e7a4c0753b1987f990d0cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UNKNOWN&lt;/div&gt;`)[0];
#                 popup_66aea46e1643910aa3e50a9c3b695a37.setContent(html_129d33da30e7a4c0753b1987f990d0cb);
#
#
#
#         marker_eb3629a0a28cf099d7df93b84709c870.bindPopup(popup_66aea46e1643910aa3e50a9c3b695a37)
#         ;
#
#
#
#
#             var marker_239c6740e3eb506e5ceb979848681445 = L.marker(
#                 [33.95923, -84.51512],
#                 {}
#             ).addTo(map_6e30a1b11f876173c936915caeecf40a);
#
#
#             var icon_bfac887bb6f8c73ce6cff1657f361e4c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot

# %%
make_map(df_2004, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6347facc3e626fbce8e08db5124ee4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6347facc3e626fbce8e08db5124ee4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6347facc3e626fbce8e08db5124ee4a = L.map(
#                 &quot;map_b6347facc3e626fbce8e08db5124ee4a&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3306cbf1350ac60734fc071ccd34955b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b6347facc3e626fbce8e08db5124ee4a);
#
#
#             var marker_d35c551a365473234c5f6187a98f152a = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_b6347facc3e626fbce8e08db5124ee4a);
#
#
#             var icon_fd38df77dea714758b32e6f11cbf3430 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d35c551a365473234c5f6187a98f152a.setIcon(icon_fd38df77dea714758b32e6f11cbf3430);
#
#
#         var popup_5e541167bde0ebccaacb3afdcbbf7dc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bce66fbd851ec84480b4254e111e8a90 = $(`&lt;div id=&quot;html_bce66fbd851ec84480b4254e111e8a90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pilgrim&#x27;s Pride Corp&lt;/div&gt;`)[0];
#                 popup_5e541167bde0ebccaacb3afdcbbf7dc9.setContent(html_bce66fbd851ec84480b4254e111e8a90);
#
#
#
#         marker_d35c551a365473234c5f6187a98f152a.bindPopup(popup_5e541167bde0ebccaacb3afdcbbf7dc9)
#         ;
#
#
#
#
#             var marker_2ebabf672c27347b24f848f69847e953 = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_b6347facc3e626fbce8e08db5124ee4a);
#
#
#             var icon_d49f67d3130fe578b93691fc11e492ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2ebabf672c27347b24f848f69847e953.setIcon(icon_d49f67d3130fe578b93691fc11e492ea);
#
#
#         var popup_578c56fb3b5735a0e2781a48122ba861 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9a552d819448a1718d158238d4b2a3a = $(`&lt;div id=&quot;html_b9a552d819448a1718d158238d4b2a3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_578c56fb3b5735a0e2781a48122ba861.setContent(html_b9a552d819448a1718d158238d4b2a3a);
#
#
#
#         marker_2ebabf672c27347b24f848f69847e953.bindPopup(popup_578c56fb3b5735a0e2781a48122ba861)
#         ;
#
#
#
#
#             var marker_f3b9c7575fa281ffd822846b88de41a9 = L.marker(
#                 [31.527259, -82.847101],
#                 {}
#             ).addTo(map_b6347facc3e626fbce8e08db5124ee4a);
#
#
#             var icon_3be99aa385d3434e53ad7e3452ea8376 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f3b9c7575fa281ffd822846b88de41a9.setIcon(icon_3be99aa385d3434e53ad7e3452ea8376);
#
#
#         var popup_c4f5bc24965dd59b5637e3977f797149 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6939100ecce55a1ce2d500f03c768706 = $(`&lt;div id=&quot;html_6939100ecce55a1ce2d500f03c768706&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UNKNOWN&lt;/div&gt;`)[0];
#                 popup_c4f5bc24965dd59b5637e3977f797149.setContent(html_6939100ecce55a1ce2d500f03c768706);
#
#
#
#         marker_f3b9c7575fa281ffd822846b88de41a9.bindPopup(popup_c4f5bc24965dd59b5637e3977f797149)
#         ;
#
#
#
#
#             var marker_8225bcae70e743b93bd6aee491e9abc7 = L.marker(
#                 [33.95923, -84.51512],
#                 {}
#             ).addTo(map_b6347facc3e626fbce8e08db5124ee4a);
#
#
#             var icon_62eace1b9a1c5e9c3a0d2286fe6b351d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;

# %%
make_map(df_2005, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_991b4a1c6fa586c04db715803a364f4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_991b4a1c6fa586c04db715803a364f4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_991b4a1c6fa586c04db715803a364f4a = L.map(
#                 &quot;map_991b4a1c6fa586c04db715803a364f4a&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_145611f05879bc6510d263b3158f158b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_991b4a1c6fa586c04db715803a364f4a);
#
#
#             var marker_974ad239fcf71825b2a8e13264c4197d = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_991b4a1c6fa586c04db715803a364f4a);
#
#
#             var icon_739ddae533f11c1298d57f261aace9d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_974ad239fcf71825b2a8e13264c4197d.setIcon(icon_739ddae533f11c1298d57f261aace9d4);
#
#
#         var popup_8295b8435763880ea506699d565a88d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_210ac659188393c9213fb8462b915029 = $(`&lt;div id=&quot;html_210ac659188393c9213fb8462b915029&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pilgrim&#x27;s Pride Corp&lt;/div&gt;`)[0];
#                 popup_8295b8435763880ea506699d565a88d2.setContent(html_210ac659188393c9213fb8462b915029);
#
#
#
#         marker_974ad239fcf71825b2a8e13264c4197d.bindPopup(popup_8295b8435763880ea506699d565a88d2)
#         ;
#
#
#
#
#             var marker_f527d071169aecc6e571333a0a6890b5 = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_991b4a1c6fa586c04db715803a364f4a);
#
#
#             var icon_5ad065784d97f6258c28876590e1d482 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f527d071169aecc6e571333a0a6890b5.setIcon(icon_5ad065784d97f6258c28876590e1d482);
#
#
#         var popup_592ac082cf2c7f3de26294b00a6ed8af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4de0710649e580cc622984ae133b938 = $(`&lt;div id=&quot;html_d4de0710649e580cc622984ae133b938&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_592ac082cf2c7f3de26294b00a6ed8af.setContent(html_d4de0710649e580cc622984ae133b938);
#
#
#
#         marker_f527d071169aecc6e571333a0a6890b5.bindPopup(popup_592ac082cf2c7f3de26294b00a6ed8af)
#         ;
#
#
#
#
#             var marker_8549402474b7f5096f23c3177eb2045e = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_991b4a1c6fa586c04db715803a364f4a);
#
#
#             var icon_7c80a8379b902e9ca9879c41beea8ef5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8549402474b7f5096f23c3177eb2045e.setIcon(icon_7c80a8379b902e9ca9879c41beea8ef5);
#
#
#         var popup_74c5d8e1e87cae9742af758bcbbd4356 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8102d9eea536b3ede35dc4f5004a3a1e = $(`&lt;div id=&quot;html_8102d9eea536b3ede35dc4f5004a3a1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_74c5d8e1e87cae9742af758bcbbd4356.setContent(html_8102d9eea536b3ede35dc4f5004a3a1e);
#
#
#
#         marker_8549402474b7f5096f23c3177eb2045e.bindPopup(popup_74c5d8e1e87cae9742af758bcbbd4356)
#         ;
#
#
#
#
#             var marker_c6590c2cf95a8a675210ef4ed33bf33e = L.marker(
#                 [34.20486, -84.14304],
#                 {}
#             ).addTo(map_991b4a1c6fa586c04db715803a364f4a);
#
#
#             var icon_33167d12ca4e5d0f2c86d7992995a87b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &

# %%
make_map(df_2006, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_258fdb59f389451d6979585ed29f1b8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_258fdb59f389451d6979585ed29f1b8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_258fdb59f389451d6979585ed29f1b8e = L.map(
#                 &quot;map_258fdb59f389451d6979585ed29f1b8e&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1d4ce6de0f97e15231b01d72e2773fb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_258fdb59f389451d6979585ed29f1b8e);
#
#
#             var marker_1a0fc282e0d46f38b2ca31114b0cf2d6 = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_258fdb59f389451d6979585ed29f1b8e);
#
#
#             var icon_3a421a19227b3df84d68a61c7e0df987 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1a0fc282e0d46f38b2ca31114b0cf2d6.setIcon(icon_3a421a19227b3df84d68a61c7e0df987);
#
#
#         var popup_a888917bd3766d3d2e0b659ab0a1499d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00bd3befd1574425c9507af740a192d4 = $(`&lt;div id=&quot;html_00bd3befd1574425c9507af740a192d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pilgrim&#x27;s Pride Corp&lt;/div&gt;`)[0];
#                 popup_a888917bd3766d3d2e0b659ab0a1499d.setContent(html_00bd3befd1574425c9507af740a192d4);
#
#
#
#         marker_1a0fc282e0d46f38b2ca31114b0cf2d6.bindPopup(popup_a888917bd3766d3d2e0b659ab0a1499d)
#         ;
#
#
#
#
#             var marker_a7ba0c8683c8af1189e2c01dfa06e399 = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_258fdb59f389451d6979585ed29f1b8e);
#
#
#             var icon_f41cfd2e10f32dfd4a67db12ca801275 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a7ba0c8683c8af1189e2c01dfa06e399.setIcon(icon_f41cfd2e10f32dfd4a67db12ca801275);
#
#
#         var popup_6c9692c6a9846c052a4fc8c54be1df74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc42752d0c6601502640bb057eec4af7 = $(`&lt;div id=&quot;html_dc42752d0c6601502640bb057eec4af7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_6c9692c6a9846c052a4fc8c54be1df74.setContent(html_dc42752d0c6601502640bb057eec4af7);
#
#
#
#         marker_a7ba0c8683c8af1189e2c01dfa06e399.bindPopup(popup_6c9692c6a9846c052a4fc8c54be1df74)
#         ;
#
#
#
#
#             var marker_ec3681b38cad4d74dd71c11f283c7133 = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_258fdb59f389451d6979585ed29f1b8e);
#
#
#             var icon_7c754d1362f374d1f77feff1bd994e50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ec3681b38cad4d74dd71c11f283c7133.setIcon(icon_7c754d1362f374d1f77feff1bd994e50);
#
#
#         var popup_2795b10a3128b3aaf6e7a4b33a25e384 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de16eacdd347287c5c1add53da19692c = $(`&lt;div id=&quot;html_de16eacdd347287c5c1add53da19692c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perdue Farms Inc&lt;/div&gt;`)[0];
#                 popup_2795b10a3128b3aaf6e7a4b33a25e384.setContent(html_de16eacdd347287c5c1add53da19692c);
#
#
#
#         marker_ec3681b38cad4d74dd71c11f283c7133.bindPopup(popup_2795b10a3128b3aaf6e7a4b33a25e384)
#         ;
#
#
#
#
#             var marker_fae9c3c64ddb5cec128e22216a86dd0f = L.marker(
#                 [34.20486, -84.14304],
#                 {}
#             ).addTo(map_258fdb59f389451d6979585ed29f1b8e);
#
#
#             var icon_72610676ad812dfa4d8b14dee341651d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;i

# %%
make_map(df_2007, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_947eec8eb0bcbdeda71812e7c72d8586 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_947eec8eb0bcbdeda71812e7c72d8586&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_947eec8eb0bcbdeda71812e7c72d8586 = L.map(
#                 &quot;map_947eec8eb0bcbdeda71812e7c72d8586&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76b290505a038f196a91874d708f0205 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_947eec8eb0bcbdeda71812e7c72d8586);
#
#
#             var marker_86e33eedcf3af3573f572cc9305df64f = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_947eec8eb0bcbdeda71812e7c72d8586);
#
#
#             var icon_7ca2aeefb579e5d1a44a75aaee3180be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_86e33eedcf3af3573f572cc9305df64f.setIcon(icon_7ca2aeefb579e5d1a44a75aaee3180be);
#
#
#         var popup_5bcc0a63eef34a33097272a7c86bb32e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f31f6d8a0c04ca0d3b61a2ac12bc061 = $(`&lt;div id=&quot;html_4f31f6d8a0c04ca0d3b61a2ac12bc061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pilgrim&#x27;s Pride Corp&lt;/div&gt;`)[0];
#                 popup_5bcc0a63eef34a33097272a7c86bb32e.setContent(html_4f31f6d8a0c04ca0d3b61a2ac12bc061);
#
#
#
#         marker_86e33eedcf3af3573f572cc9305df64f.bindPopup(popup_5bcc0a63eef34a33097272a7c86bb32e)
#         ;
#
#
#
#
#             var marker_3ff85bebc44ea1657b1e4bc8b0c09fc6 = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_947eec8eb0bcbdeda71812e7c72d8586);
#
#
#             var icon_57e76e9c095256e9be9ab49f94218bf4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3ff85bebc44ea1657b1e4bc8b0c09fc6.setIcon(icon_57e76e9c095256e9be9ab49f94218bf4);
#
#
#         var popup_a89124ad95064737e42bb604c329f49e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd2a6a8aa37b1444984fdfddd99c28d5 = $(`&lt;div id=&quot;html_dd2a6a8aa37b1444984fdfddd99c28d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_a89124ad95064737e42bb604c329f49e.setContent(html_dd2a6a8aa37b1444984fdfddd99c28d5);
#
#
#
#         marker_3ff85bebc44ea1657b1e4bc8b0c09fc6.bindPopup(popup_a89124ad95064737e42bb604c329f49e)
#         ;
#
#
#
#
#             var marker_555b114a02c9abee04883958447079f3 = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_947eec8eb0bcbdeda71812e7c72d8586);
#
#
#             var icon_3b0e3b3289637d06f92e2988dd89d829 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_555b114a02c9abee04883958447079f3.setIcon(icon_3b0e3b3289637d06f92e2988dd89d829);
#
#
#         var popup_0520485ede08be6f6c65b891062b9ea4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5f23d4b1c2830c26325480eff99c5da = $(`&lt;div id=&quot;html_f5f23d4b1c2830c26325480eff99c5da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perdue Farms Inc&lt;/div&gt;`)[0];
#                 popup_0520485ede08be6f6c65b891062b9ea4.setContent(html_f5f23d4b1c2830c26325480eff99c5da);
#
#
#
#         marker_555b114a02c9abee04883958447079f3.bindPopup(popup_0520485ede08be6f6c65b891062b9ea4)
#         ;
#
#
#
#
#             var marker_d2ab397805480a95874ed44d0b9764c1 = L.marker(
#                 [34.20486, -84.14304],
#                 {}
#             ).addTo(map_947eec8eb0bcbdeda71812e7c72d8586);
#
#
#             var icon_fd5db0212884b3041aa9882c124a28bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;i

# %%
make_map(df_2008, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ba20a32f2da42007799cdb1ffab8d27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ba20a32f2da42007799cdb1ffab8d27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ba20a32f2da42007799cdb1ffab8d27 = L.map(
#                 &quot;map_2ba20a32f2da42007799cdb1ffab8d27&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1ddafadb44a8a9804f716db6f00502f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ba20a32f2da42007799cdb1ffab8d27);
#
#
#             var marker_c94e340d045350d01f2faab941b69ce5 = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_2ba20a32f2da42007799cdb1ffab8d27);
#
#
#             var icon_88a5641d26f13018a8a9dfdd2f052907 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c94e340d045350d01f2faab941b69ce5.setIcon(icon_88a5641d26f13018a8a9dfdd2f052907);
#
#
#         var popup_84ba34131e5fa43ca1091e9a2ba97bad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0dc2fc0d5f44b5c8c123d60b7ba953c6 = $(`&lt;div id=&quot;html_0dc2fc0d5f44b5c8c123d60b7ba953c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pilgrim&#x27;s Pride Corp&lt;/div&gt;`)[0];
#                 popup_84ba34131e5fa43ca1091e9a2ba97bad.setContent(html_0dc2fc0d5f44b5c8c123d60b7ba953c6);
#
#
#
#         marker_c94e340d045350d01f2faab941b69ce5.bindPopup(popup_84ba34131e5fa43ca1091e9a2ba97bad)
#         ;
#
#
#
#
#             var marker_7f2d748dc9c87f41c700e4b21f5f63fe = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_2ba20a32f2da42007799cdb1ffab8d27);
#
#
#             var icon_7f5f99f2d2193668ced3e8b9a5944790 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f2d748dc9c87f41c700e4b21f5f63fe.setIcon(icon_7f5f99f2d2193668ced3e8b9a5944790);
#
#
#         var popup_32fa986ad37ab725f75149a90f375e48 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_308cfae33a081f3a55bb78878dc17b13 = $(`&lt;div id=&quot;html_308cfae33a081f3a55bb78878dc17b13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_32fa986ad37ab725f75149a90f375e48.setContent(html_308cfae33a081f3a55bb78878dc17b13);
#
#
#
#         marker_7f2d748dc9c87f41c700e4b21f5f63fe.bindPopup(popup_32fa986ad37ab725f75149a90f375e48)
#         ;
#
#
#
#
#             var marker_2e37805acb78da27f369ad811fccc566 = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_2ba20a32f2da42007799cdb1ffab8d27);
#
#
#             var icon_08847b5b15b542752c0f6f69836c47f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2e37805acb78da27f369ad811fccc566.setIcon(icon_08847b5b15b542752c0f6f69836c47f0);
#
#
#         var popup_b167304fdd893e17476ed46fea5e98d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f0baf4fa539c465ef7a0458976a70a8 = $(`&lt;div id=&quot;html_6f0baf4fa539c465ef7a0458976a70a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perdue Farms Inc&lt;/div&gt;`)[0];
#                 popup_b167304fdd893e17476ed46fea5e98d8.setContent(html_6f0baf4fa539c465ef7a0458976a70a8);
#
#
#
#         marker_2e37805acb78da27f369ad811fccc566.bindPopup(popup_b167304fdd893e17476ed46fea5e98d8)
#         ;
#
#
#
#
#             var marker_9fbce22528383730a1f78db8281de1eb = L.marker(
#                 [34.20486, -84.14304],
#                 {}
#             ).addTo(map_2ba20a32f2da42007799cdb1ffab8d27);
#
#
#             var icon_3e94771bfe7561ac1b62f75c3cdb9dab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;i

# %%
make_map(df_2009, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b9fd38bb6d59cd85d4cd3a95879559f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b9fd38bb6d59cd85d4cd3a95879559f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b9fd38bb6d59cd85d4cd3a95879559f = L.map(
#                 &quot;map_5b9fd38bb6d59cd85d4cd3a95879559f&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8d28da385c74f1a6f1e36b5e85c9e27 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5b9fd38bb6d59cd85d4cd3a95879559f);
#
#
#             var marker_5316445f4036f80ab95a858fe1d5e951 = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_5b9fd38bb6d59cd85d4cd3a95879559f);
#
#
#             var icon_a45a643b8aca1cd8392830e5b2affa27 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5316445f4036f80ab95a858fe1d5e951.setIcon(icon_a45a643b8aca1cd8392830e5b2affa27);
#
#
#         var popup_e2eed5c8cd2b68524add07c209af2da6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6f25c10b67c301830e372242a01bb1d = $(`&lt;div id=&quot;html_e6f25c10b67c301830e372242a01bb1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pilgrim&#x27;s Pride Corp&lt;/div&gt;`)[0];
#                 popup_e2eed5c8cd2b68524add07c209af2da6.setContent(html_e6f25c10b67c301830e372242a01bb1d);
#
#
#
#         marker_5316445f4036f80ab95a858fe1d5e951.bindPopup(popup_e2eed5c8cd2b68524add07c209af2da6)
#         ;
#
#
#
#
#             var marker_821f916ff4663b0e43ca2519d50f6fe9 = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_5b9fd38bb6d59cd85d4cd3a95879559f);
#
#
#             var icon_370ea5aa941098bedfeadc24ec7d079f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_821f916ff4663b0e43ca2519d50f6fe9.setIcon(icon_370ea5aa941098bedfeadc24ec7d079f);
#
#
#         var popup_8642e873e67e7b0e97940f4e903d6002 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5abda28fc450490160b2801f7675fcb = $(`&lt;div id=&quot;html_d5abda28fc450490160b2801f7675fcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_8642e873e67e7b0e97940f4e903d6002.setContent(html_d5abda28fc450490160b2801f7675fcb);
#
#
#
#         marker_821f916ff4663b0e43ca2519d50f6fe9.bindPopup(popup_8642e873e67e7b0e97940f4e903d6002)
#         ;
#
#
#
#
#             var marker_d0bbd8b4680cb72d8dad79709784a6a8 = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_5b9fd38bb6d59cd85d4cd3a95879559f);
#
#
#             var icon_bab8badfa881009fa39a8d1bb16e816e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d0bbd8b4680cb72d8dad79709784a6a8.setIcon(icon_bab8badfa881009fa39a8d1bb16e816e);
#
#
#         var popup_30fecae21fb5217333977a80663e154d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5345dea56f69e917e8970a10ab49a75c = $(`&lt;div id=&quot;html_5345dea56f69e917e8970a10ab49a75c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perdue Farms Inc&lt;/div&gt;`)[0];
#                 popup_30fecae21fb5217333977a80663e154d.setContent(html_5345dea56f69e917e8970a10ab49a75c);
#
#
#
#         marker_d0bbd8b4680cb72d8dad79709784a6a8.bindPopup(popup_30fecae21fb5217333977a80663e154d)
#         ;
#
#
#
#
#             var marker_7a3d81af61a0272838b77b880dd6e475 = L.marker(
#                 [34.20486, -84.14304],
#                 {}
#             ).addTo(map_5b9fd38bb6d59cd85d4cd3a95879559f);
#
#
#             var icon_ed720144d624390d018d193c55a16ef8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;i

# %%
make_map(df_2010, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9328cee3775220233012aa778e5a2278 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9328cee3775220233012aa778e5a2278&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9328cee3775220233012aa778e5a2278 = L.map(
#                 &quot;map_9328cee3775220233012aa778e5a2278&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c96385e19b252a19f19a68ac5d4c027 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9328cee3775220233012aa778e5a2278);
#
#
#             var marker_5632e4dc491d7b058c31c4d585b6f564 = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_9328cee3775220233012aa778e5a2278);
#
#
#             var icon_102dfa36f7f8f5d1dc2833c366009ced = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5632e4dc491d7b058c31c4d585b6f564.setIcon(icon_102dfa36f7f8f5d1dc2833c366009ced);
#
#
#         var popup_51bb1730a64c4908b7f365e2e3f5f3b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f87c89d8107b4ffb42636d50330d156 = $(`&lt;div id=&quot;html_3f87c89d8107b4ffb42636d50330d156&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_51bb1730a64c4908b7f365e2e3f5f3b5.setContent(html_3f87c89d8107b4ffb42636d50330d156);
#
#
#
#         marker_5632e4dc491d7b058c31c4d585b6f564.bindPopup(popup_51bb1730a64c4908b7f365e2e3f5f3b5)
#         ;
#
#
#
#
#             var marker_99b2221b24db2694067c49dafc157da7 = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_9328cee3775220233012aa778e5a2278);
#
#
#             var icon_96c1c7c3ebd88bacc8c991066a447608 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_99b2221b24db2694067c49dafc157da7.setIcon(icon_96c1c7c3ebd88bacc8c991066a447608);
#
#
#         var popup_fbf452b3c9ebf953d89f0a53c71e768e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2742d713864c4d5f39ca806478d7945 = $(`&lt;div id=&quot;html_f2742d713864c4d5f39ca806478d7945&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_fbf452b3c9ebf953d89f0a53c71e768e.setContent(html_f2742d713864c4d5f39ca806478d7945);
#
#
#
#         marker_99b2221b24db2694067c49dafc157da7.bindPopup(popup_fbf452b3c9ebf953d89f0a53c71e768e)
#         ;
#
#
#
#
#             var marker_695d1ab5527517d5e36a47fa39517a93 = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_9328cee3775220233012aa778e5a2278);
#
#
#             var icon_57a5b4148b7cd27c407640965fadc822 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_695d1ab5527517d5e36a47fa39517a93.setIcon(icon_57a5b4148b7cd27c407640965fadc822);
#
#
#         var popup_bcbc9e2facf08c93ee57afb0a0f10447 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7504acb85306ac1b85e9b54904214e8 = $(`&lt;div id=&quot;html_d7504acb85306ac1b85e9b54904214e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perdue Farms Inc&lt;/div&gt;`)[0];
#                 popup_bcbc9e2facf08c93ee57afb0a0f10447.setContent(html_d7504acb85306ac1b85e9b54904214e8);
#
#
#
#         marker_695d1ab5527517d5e36a47fa39517a93.bindPopup(popup_bcbc9e2facf08c93ee57afb0a0f10447)
#         ;
#
#
#
#
#             var marker_64220296ae73f18876dcae902ea29448 = L.marker(
#                 [34.20486, -84.14304],
#                 {}
#             ).addTo(map_9328cee3775220233012aa778e5a2278);
#
#
#             var icon_76593dc043a138eb66e611d7f4591f62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-si

# %%
make_map(df_2011, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb3754acea7275e5cd97c47ff4c1d669 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb3754acea7275e5cd97c47ff4c1d669&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb3754acea7275e5cd97c47ff4c1d669 = L.map(
#                 &quot;map_eb3754acea7275e5cd97c47ff4c1d669&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc90ed0481d69ab91443ae0b7763087b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eb3754acea7275e5cd97c47ff4c1d669);
#
#
#             var marker_4affa349595275c62b00d4e727c2e539 = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_eb3754acea7275e5cd97c47ff4c1d669);
#
#
#             var icon_b64de3f9f682ac434384946676b99085 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4affa349595275c62b00d4e727c2e539.setIcon(icon_b64de3f9f682ac434384946676b99085);
#
#
#         var popup_d47e95a5088278e08d4cc8d89f7b261e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba57bae3e41c758d168f4b48057cd163 = $(`&lt;div id=&quot;html_ba57bae3e41c758d168f4b48057cd163&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_d47e95a5088278e08d4cc8d89f7b261e.setContent(html_ba57bae3e41c758d168f4b48057cd163);
#
#
#
#         marker_4affa349595275c62b00d4e727c2e539.bindPopup(popup_d47e95a5088278e08d4cc8d89f7b261e)
#         ;
#
#
#
#
#             var marker_83fa4d73d842912c7af581455bfe32b5 = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_eb3754acea7275e5cd97c47ff4c1d669);
#
#
#             var icon_fa6208c60f03762fa9cb5f8e08f7b68e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83fa4d73d842912c7af581455bfe32b5.setIcon(icon_fa6208c60f03762fa9cb5f8e08f7b68e);
#
#
#         var popup_ffbf242ba828662aabe1f8fba8eee74c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2690a433136af1cd7e406d24cc4325b7 = $(`&lt;div id=&quot;html_2690a433136af1cd7e406d24cc4325b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_ffbf242ba828662aabe1f8fba8eee74c.setContent(html_2690a433136af1cd7e406d24cc4325b7);
#
#
#
#         marker_83fa4d73d842912c7af581455bfe32b5.bindPopup(popup_ffbf242ba828662aabe1f8fba8eee74c)
#         ;
#
#
#
#
#             var marker_266f1ee8358509e91321819429e7afea = L.marker(
#                 [32.438432, -83.637597],
#                 {}
#             ).addTo(map_eb3754acea7275e5cd97c47ff4c1d669);
#
#
#             var icon_ef8c2a76d81b56b2a1d732326f80cd68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_266f1ee8358509e91321819429e7afea.setIcon(icon_ef8c2a76d81b56b2a1d732326f80cd68);
#
#
#         var popup_855fc0c1e8d112a40a5ddb30e1ea6ed8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e47ebb54bb80635f754c2d32b761c60 = $(`&lt;div id=&quot;html_2e47ebb54bb80635f754c2d32b761c60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Perdue Farms Inc&lt;/div&gt;`)[0];
#                 popup_855fc0c1e8d112a40a5ddb30e1ea6ed8.setContent(html_2e47ebb54bb80635f754c2d32b761c60);
#
#
#
#         marker_266f1ee8358509e91321819429e7afea.bindPopup(popup_855fc0c1e8d112a40a5ddb30e1ea6ed8)
#         ;
#
#
#
#
#             var marker_07121ab9dbc44065d5f79294182265f9 = L.marker(
#                 [34.20486, -84.14304],
#                 {}
#             ).addTo(map_eb3754acea7275e5cd97c47ff4c1d669);
#
#
#             var icon_b0a908ebdb8487df6d8e1b1a45b80158 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-si

# %%
make_map(df_2012, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1ee65ff2dfeb2c2b2de396f2b4cdea2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1ee65ff2dfeb2c2b2de396f2b4cdea2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1ee65ff2dfeb2c2b2de396f2b4cdea2 = L.map(
#                 &quot;map_f1ee65ff2dfeb2c2b2de396f2b4cdea2&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b04e7f2098f5ce967e963d755651465 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f1ee65ff2dfeb2c2b2de396f2b4cdea2);
#
#
#             var marker_763847039890147afbd90e9da552f36d = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_f1ee65ff2dfeb2c2b2de396f2b4cdea2);
#
#
#             var icon_47057406681e2df8bb4bda16cd3c1816 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_763847039890147afbd90e9da552f36d.setIcon(icon_47057406681e2df8bb4bda16cd3c1816);
#
#
#         var popup_ddcbf189700d7ef09591d87ed3e81ec8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6ba247decc2a78f5a1d52bd4c2bb5235 = $(`&lt;div id=&quot;html_6ba247decc2a78f5a1d52bd4c2bb5235&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_ddcbf189700d7ef09591d87ed3e81ec8.setContent(html_6ba247decc2a78f5a1d52bd4c2bb5235);
#
#
#
#         marker_763847039890147afbd90e9da552f36d.bindPopup(popup_ddcbf189700d7ef09591d87ed3e81ec8)
#         ;
#
#
#
#
#             var marker_2c3351973077cbc18bf928c4a1db9dcf = L.marker(
#                 [34.501338, -84.94096],
#                 {}
#             ).addTo(map_f1ee65ff2dfeb2c2b2de396f2b4cdea2);
#
#
#             var icon_df8018c089f4b4805a4e255ae19a328a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2c3351973077cbc18bf928c4a1db9dcf.setIcon(icon_df8018c089f4b4805a4e255ae19a328a);
#
#
#         var popup_10e5ccaa36695890e93e53f5864462e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34735b63ba476325398715923ed300f3 = $(`&lt;div id=&quot;html_34735b63ba476325398715923ed300f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_10e5ccaa36695890e93e53f5864462e4.setContent(html_34735b63ba476325398715923ed300f3);
#
#
#
#         marker_2c3351973077cbc18bf928c4a1db9dcf.bindPopup(popup_10e5ccaa36695890e93e53f5864462e4)
#         ;
#
#
#
#
#             var marker_0ba69b53f6e0e291ac7973e27986b089 = L.marker(
#                 [34.94585, -84.96405],
#                 {}
#             ).addTo(map_f1ee65ff2dfeb2c2b2de396f2b4cdea2);
#
#
#             var icon_94930cc1c370e85397fe09a2c93e5d04 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0ba69b53f6e0e291ac7973e27986b089.setIcon(icon_94930cc1c370e85397fe09a2c93e5d04);
#
#
#         var popup_ffb6bfa7770932b4c2f5619b9ea8c991 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e336680c2e3b6aa9a1355e84b232c47 = $(`&lt;div id=&quot;html_8e336680c2e3b6aa9a1355e84b232c47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_ffb6bfa7770932b4c2f5619b9ea8c991.setContent(html_8e336680c2e3b6aa9a1355e84b232c47);
#
#
#
#         marker_0ba69b53f6e0e291ac7973e27986b089.bindPopup(popup_ffb6bfa7770932b4c2f5619b9ea8c991)
#         ;
#
#
#
#
#             var marker_a18bc8b45990224207d778109cf6a856 = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_f1ee65ff2dfeb2c2b2de396f2b4cdea2);
#
#
#             var icon_cf792caaf297bd29cfa508fdbd0829b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&

# %%
make_map(df_2013, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61eb07264b05f6e3fad58019c0fbca7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61eb07264b05f6e3fad58019c0fbca7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61eb07264b05f6e3fad58019c0fbca7c = L.map(
#                 &quot;map_61eb07264b05f6e3fad58019c0fbca7c&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61df9b65757bcbf907bdbf178a0aca32 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_61eb07264b05f6e3fad58019c0fbca7c);
#
#
#             var marker_934885896b6e2ac8eee4c8bdf776bf7d = L.marker(
#                 [34.096808, -82.838544],
#                 {}
#             ).addTo(map_61eb07264b05f6e3fad58019c0fbca7c);
#
#
#             var icon_cb5447e62258e6837c08b253702a0eee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_934885896b6e2ac8eee4c8bdf776bf7d.setIcon(icon_cb5447e62258e6837c08b253702a0eee);
#
#
#         var popup_435d6611ad6fd15fecf55fe94bb94a77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ec2349f461e525ca53fd1955c25c22e = $(`&lt;div id=&quot;html_0ec2349f461e525ca53fd1955c25c22e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_435d6611ad6fd15fecf55fe94bb94a77.setContent(html_0ec2349f461e525ca53fd1955c25c22e);
#
#
#
#         marker_934885896b6e2ac8eee4c8bdf776bf7d.bindPopup(popup_435d6611ad6fd15fecf55fe94bb94a77)
#         ;
#
#
#
#
#             var marker_97232ab88a4f06c22e6cbaf0746e9891 = L.marker(
#                 [34.501338, -84.94096],
#                 {}
#             ).addTo(map_61eb07264b05f6e3fad58019c0fbca7c);
#
#
#             var icon_439b2f7b48f65db9994619bb6d58b150 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_97232ab88a4f06c22e6cbaf0746e9891.setIcon(icon_439b2f7b48f65db9994619bb6d58b150);
#
#
#         var popup_ff2d2541a5e776237c9e44b3f4e7c50d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bcbeea6160a5cb45c8836b99efd682b = $(`&lt;div id=&quot;html_9bcbeea6160a5cb45c8836b99efd682b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_ff2d2541a5e776237c9e44b3f4e7c50d.setContent(html_9bcbeea6160a5cb45c8836b99efd682b);
#
#
#
#         marker_97232ab88a4f06c22e6cbaf0746e9891.bindPopup(popup_ff2d2541a5e776237c9e44b3f4e7c50d)
#         ;
#
#
#
#
#             var marker_e7603e467443f09b9b9428b9f450a8c0 = L.marker(
#                 [34.946772, -84.96381],
#                 {}
#             ).addTo(map_61eb07264b05f6e3fad58019c0fbca7c);
#
#
#             var icon_ef0c1d7f3581669c223e17072af68497 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e7603e467443f09b9b9428b9f450a8c0.setIcon(icon_ef0c1d7f3581669c223e17072af68497);
#
#
#         var popup_e84916137fed8054bfedf0872f063797 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42380429e694cf46e137f643c2f7e58a = $(`&lt;div id=&quot;html_42380429e694cf46e137f643c2f7e58a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_e84916137fed8054bfedf0872f063797.setContent(html_42380429e694cf46e137f643c2f7e58a);
#
#
#
#         marker_e7603e467443f09b9b9428b9f450a8c0.bindPopup(popup_e84916137fed8054bfedf0872f063797)
#         ;
#
#
#
#
#             var marker_7d322971e1ce9cb1aafbcb3991db0749 = L.marker(
#                 [32.096856, -83.768228],
#                 {}
#             ).addTo(map_61eb07264b05f6e3fad58019c0fbca7c);
#
#
#             var icon_835521f53517d4871f785f15f8a4dac5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;icon

# %%
make_map(df_2014, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c84456490104eb772519eba0244a8aaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c84456490104eb772519eba0244a8aaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c84456490104eb772519eba0244a8aaa = L.map(
#                 &quot;map_c84456490104eb772519eba0244a8aaa&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_107500ef011c6a612bbb23e71da5c63a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c84456490104eb772519eba0244a8aaa);
#
#
#             var marker_50c3b834daadf290fe71478963fdaa89 = L.marker(
#                 [34.0968, -82.83854],
#                 {}
#             ).addTo(map_c84456490104eb772519eba0244a8aaa);
#
#
#             var icon_1428dccd1a0921b43d5fc2311b5f66d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_50c3b834daadf290fe71478963fdaa89.setIcon(icon_1428dccd1a0921b43d5fc2311b5f66d4);
#
#
#         var popup_b999ea187a7310c3547531a6a16fd155 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e348f35f0dc3c67df0db21d0771d2471 = $(`&lt;div id=&quot;html_e348f35f0dc3c67df0db21d0771d2471&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_b999ea187a7310c3547531a6a16fd155.setContent(html_e348f35f0dc3c67df0db21d0771d2471);
#
#
#
#         marker_50c3b834daadf290fe71478963fdaa89.bindPopup(popup_b999ea187a7310c3547531a6a16fd155)
#         ;
#
#
#
#
#             var marker_8c3f054ba0395e524ece82f22a8ee5a7 = L.marker(
#                 [34.501338, -84.94096],
#                 {}
#             ).addTo(map_c84456490104eb772519eba0244a8aaa);
#
#
#             var icon_4bac3d1c94f3b954125c0ed4f22cb308 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c3f054ba0395e524ece82f22a8ee5a7.setIcon(icon_4bac3d1c94f3b954125c0ed4f22cb308);
#
#
#         var popup_37bb3de9b2fa763ce2fe2588896825df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2240f55d511c3b21ce4da27bb1f8dfd4 = $(`&lt;div id=&quot;html_2240f55d511c3b21ce4da27bb1f8dfd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_37bb3de9b2fa763ce2fe2588896825df.setContent(html_2240f55d511c3b21ce4da27bb1f8dfd4);
#
#
#
#         marker_8c3f054ba0395e524ece82f22a8ee5a7.bindPopup(popup_37bb3de9b2fa763ce2fe2588896825df)
#         ;
#
#
#
#
#             var marker_45dd1503edc3cc64528f2db7213835be = L.marker(
#                 [34.94585, -84.96405],
#                 {}
#             ).addTo(map_c84456490104eb772519eba0244a8aaa);
#
#
#             var icon_e6ab32c6a150178d4d28a94bc7f27b57 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_45dd1503edc3cc64528f2db7213835be.setIcon(icon_e6ab32c6a150178d4d28a94bc7f27b57);
#
#
#         var popup_4f73088c1e6cbf9a030d854517d67e7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3310f96e3b08627a38259ae1c69142c9 = $(`&lt;div id=&quot;html_3310f96e3b08627a38259ae1c69142c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_4f73088c1e6cbf9a030d854517d67e7f.setContent(html_3310f96e3b08627a38259ae1c69142c9);
#
#
#
#         marker_45dd1503edc3cc64528f2db7213835be.bindPopup(popup_4f73088c1e6cbf9a030d854517d67e7f)
#         ;
#
#
#
#
#             var marker_c002b2776e737af1f588e8e9008a65df = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_c84456490104eb772519eba0244a8aaa);
#
#
#             var icon_54d0b6c379efefd8eaa5dbaa838bb9e7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&

# %%
make_map(df_2015, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0c984b23fca4e5f9f698dc9e25b9808 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0c984b23fca4e5f9f698dc9e25b9808&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0c984b23fca4e5f9f698dc9e25b9808 = L.map(
#                 &quot;map_a0c984b23fca4e5f9f698dc9e25b9808&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7062d8bb970399f9d039a392745f6d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a0c984b23fca4e5f9f698dc9e25b9808);
#
#
#             var marker_1f907859afec90826db75f09bfd8db6b = L.marker(
#                 [34.096801, -82.838561],
#                 {}
#             ).addTo(map_a0c984b23fca4e5f9f698dc9e25b9808);
#
#
#             var icon_db4d0c3ce8a3ad00d87d8ed6bc6ffe17 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1f907859afec90826db75f09bfd8db6b.setIcon(icon_db4d0c3ce8a3ad00d87d8ed6bc6ffe17);
#
#
#         var popup_2785df459ee779ebcc509923379cbbac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11b67380a3770ece6ab7d247cb18f595 = $(`&lt;div id=&quot;html_11b67380a3770ece6ab7d247cb18f595&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_2785df459ee779ebcc509923379cbbac.setContent(html_11b67380a3770ece6ab7d247cb18f595);
#
#
#
#         marker_1f907859afec90826db75f09bfd8db6b.bindPopup(popup_2785df459ee779ebcc509923379cbbac)
#         ;
#
#
#
#
#             var marker_b9ff255bd40b8b24ebd1727da29cf6be = L.marker(
#                 [34.501338, -84.94096],
#                 {}
#             ).addTo(map_a0c984b23fca4e5f9f698dc9e25b9808);
#
#
#             var icon_2ff0064c9722789e9825d6a7455c5219 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b9ff255bd40b8b24ebd1727da29cf6be.setIcon(icon_2ff0064c9722789e9825d6a7455c5219);
#
#
#         var popup_a720548a5223e2eea0fa4046c5982c15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f992d16ce0cf75b8a1b90e3752b67b62 = $(`&lt;div id=&quot;html_f992d16ce0cf75b8a1b90e3752b67b62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_a720548a5223e2eea0fa4046c5982c15.setContent(html_f992d16ce0cf75b8a1b90e3752b67b62);
#
#
#
#         marker_b9ff255bd40b8b24ebd1727da29cf6be.bindPopup(popup_a720548a5223e2eea0fa4046c5982c15)
#         ;
#
#
#
#
#             var marker_3d5fc1bb45f17c79bde95be1e4e1cd16 = L.marker(
#                 [34.94585, -84.96405],
#                 {}
#             ).addTo(map_a0c984b23fca4e5f9f698dc9e25b9808);
#
#
#             var icon_4caec8ba2eafcaa0b78103ee3af590c5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3d5fc1bb45f17c79bde95be1e4e1cd16.setIcon(icon_4caec8ba2eafcaa0b78103ee3af590c5);
#
#
#         var popup_55440c00612a348f4982c635ecea183c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4deeb18bfe73909e55e9e8d0b4c270a8 = $(`&lt;div id=&quot;html_4deeb18bfe73909e55e9e8d0b4c270a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_55440c00612a348f4982c635ecea183c.setContent(html_4deeb18bfe73909e55e9e8d0b4c270a8);
#
#
#
#         marker_3d5fc1bb45f17c79bde95be1e4e1cd16.bindPopup(popup_55440c00612a348f4982c635ecea183c)
#         ;
#
#
#
#
#             var marker_49993c7901cf02f8194705739ff427e8 = L.marker(
#                 [32.09686, -83.76823],
#                 {}
#             ).addTo(map_a0c984b23fca4e5f9f698dc9e25b9808);
#
#
#             var icon_3a96b4b1c856e8cf920b13179ea4e951 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconCol

# %%
make_map(df_2016, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12eb4a6d89204527a3037a688c430bba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12eb4a6d89204527a3037a688c430bba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12eb4a6d89204527a3037a688c430bba = L.map(
#                 &quot;map_12eb4a6d89204527a3037a688c430bba&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f41d81b92139ca9d3a40d617e50bd8d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_12eb4a6d89204527a3037a688c430bba);
#
#
#             var marker_4d7e83ee57e843aceb91ed2350ff9774 = L.marker(
#                 [34.096801, -82.838561],
#                 {}
#             ).addTo(map_12eb4a6d89204527a3037a688c430bba);
#
#
#             var icon_4cb949c034fa7494f36b9c0670f121aa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4d7e83ee57e843aceb91ed2350ff9774.setIcon(icon_4cb949c034fa7494f36b9c0670f121aa);
#
#
#         var popup_1587bbdb58d63d82dd6d1a418a90b584 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_975dc15324eed2ac01196d38f3a413f4 = $(`&lt;div id=&quot;html_975dc15324eed2ac01196d38f3a413f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_1587bbdb58d63d82dd6d1a418a90b584.setContent(html_975dc15324eed2ac01196d38f3a413f4);
#
#
#
#         marker_4d7e83ee57e843aceb91ed2350ff9774.bindPopup(popup_1587bbdb58d63d82dd6d1a418a90b584)
#         ;
#
#
#
#
#             var marker_e462dc5ce25a55a7b19b582d1013b036 = L.marker(
#                 [34.5424, -84.9318],
#                 {}
#             ).addTo(map_12eb4a6d89204527a3037a688c430bba);
#
#
#             var icon_11ee01adc7dd7cacdd16428c682fb2c3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e462dc5ce25a55a7b19b582d1013b036.setIcon(icon_11ee01adc7dd7cacdd16428c682fb2c3);
#
#
#         var popup_53bcc364aa071a49ac123c457ef19de2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a76da2ee28180c4eb06ecd82a97454e = $(`&lt;div id=&quot;html_1a76da2ee28180c4eb06ecd82a97454e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_53bcc364aa071a49ac123c457ef19de2.setContent(html_1a76da2ee28180c4eb06ecd82a97454e);
#
#
#
#         marker_e462dc5ce25a55a7b19b582d1013b036.bindPopup(popup_53bcc364aa071a49ac123c457ef19de2)
#         ;
#
#
#
#
#             var marker_dc753a1b948b61f69beaa8b8ec668141 = L.marker(
#                 [34.94585, -84.96405],
#                 {}
#             ).addTo(map_12eb4a6d89204527a3037a688c430bba);
#
#
#             var icon_0826a410b34b3500fdd6608c0642d5e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dc753a1b948b61f69beaa8b8ec668141.setIcon(icon_0826a410b34b3500fdd6608c0642d5e2);
#
#
#         var popup_e639d409cf489952d19abf5be6434ec0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d66ca35a549803b760d512719d14dd6 = $(`&lt;div id=&quot;html_4d66ca35a549803b760d512719d14dd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_e639d409cf489952d19abf5be6434ec0.setContent(html_4d66ca35a549803b760d512719d14dd6);
#
#
#
#         marker_dc753a1b948b61f69beaa8b8ec668141.bindPopup(popup_e639d409cf489952d19abf5be6434ec0)
#         ;
#
#
#
#
#             var marker_65b617078854e28e7729635805f5792e = L.marker(
#                 [32.096856, -83.768228],
#                 {}
#             ).addTo(map_12eb4a6d89204527a3037a688c430bba);
#
#
#             var icon_1b6739467f3af5adac42ca5320470c96 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColo

# %%
make_map(df_2017, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b029cbc008e3b41f28a626950074e44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b029cbc008e3b41f28a626950074e44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b029cbc008e3b41f28a626950074e44 = L.map(
#                 &quot;map_3b029cbc008e3b41f28a626950074e44&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8dd7d7e273535defca397600803bae7e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b029cbc008e3b41f28a626950074e44);
#
#
#             var marker_e4cd4b80a2436ae82067aa8c5470eac5 = L.marker(
#                 [34.096801, -82.838561],
#                 {}
#             ).addTo(map_3b029cbc008e3b41f28a626950074e44);
#
#
#             var icon_0d728c02c8ae5cc47ee042b88f4fce12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e4cd4b80a2436ae82067aa8c5470eac5.setIcon(icon_0d728c02c8ae5cc47ee042b88f4fce12);
#
#
#         var popup_e402ac2402684cea0fcb47fb14ea6c2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ebf7bd34022a07c6b59a0ae6725d2a1e = $(`&lt;div id=&quot;html_ebf7bd34022a07c6b59a0ae6725d2a1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_e402ac2402684cea0fcb47fb14ea6c2d.setContent(html_ebf7bd34022a07c6b59a0ae6725d2a1e);
#
#
#
#         marker_e4cd4b80a2436ae82067aa8c5470eac5.bindPopup(popup_e402ac2402684cea0fcb47fb14ea6c2d)
#         ;
#
#
#
#
#             var marker_2d7e0be637b608693c79655c5be17955 = L.marker(
#                 [34.538635, -84.933498],
#                 {}
#             ).addTo(map_3b029cbc008e3b41f28a626950074e44);
#
#
#             var icon_8bc93c469a585299e5827a7cf071bd6e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2d7e0be637b608693c79655c5be17955.setIcon(icon_8bc93c469a585299e5827a7cf071bd6e);
#
#
#         var popup_ef7842a8c42805f8d97f30a53471cdd9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a81f083ce791c6f24bbbd1658a676941 = $(`&lt;div id=&quot;html_a81f083ce791c6f24bbbd1658a676941&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_ef7842a8c42805f8d97f30a53471cdd9.setContent(html_a81f083ce791c6f24bbbd1658a676941);
#
#
#
#         marker_2d7e0be637b608693c79655c5be17955.bindPopup(popup_ef7842a8c42805f8d97f30a53471cdd9)
#         ;
#
#
#
#
#             var marker_2bdaf639e548c8bbe8c6c7708de0860f = L.marker(
#                 [34.945231, -84.961497],
#                 {}
#             ).addTo(map_3b029cbc008e3b41f28a626950074e44);
#
#
#             var icon_8d6db21923b25e8120444c24d57c8bdc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2bdaf639e548c8bbe8c6c7708de0860f.setIcon(icon_8d6db21923b25e8120444c24d57c8bdc);
#
#
#         var popup_a80c69021a51e2b31e926e1c9f66f1ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29dca890ca6ab2e2e0f21a0f002fbbf3 = $(`&lt;div id=&quot;html_29dca890ca6ab2e2e0f21a0f002fbbf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_a80c69021a51e2b31e926e1c9f66f1ed.setContent(html_29dca890ca6ab2e2e0f21a0f002fbbf3);
#
#
#
#         marker_2bdaf639e548c8bbe8c6c7708de0860f.bindPopup(popup_a80c69021a51e2b31e926e1c9f66f1ed)
#         ;
#
#
#
#
#             var marker_73796eab9f62e50c767e9658aeecb64f = L.marker(
#                 [32.096856, -83.768228],
#                 {}
#             ).addTo(map_3b029cbc008e3b41f28a626950074e44);
#
#
#             var icon_d5eabdcfc3f213e74e833cb3908bf414 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;ic

# %%
make_map(df_2018, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12b0c032eaf13063d0cdb9801b275c2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12b0c032eaf13063d0cdb9801b275c2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12b0c032eaf13063d0cdb9801b275c2d = L.map(
#                 &quot;map_12b0c032eaf13063d0cdb9801b275c2d&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12b23c8090a5ed1935f1bd3d1032104e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_12b0c032eaf13063d0cdb9801b275c2d);
#
#
#             var marker_548d0b4a8679dc3881b256a2adf62bd1 = L.marker(
#                 [33.968363, -83.434066],
#                 {}
#             ).addTo(map_12b0c032eaf13063d0cdb9801b275c2d);
#
#
#             var icon_1e57c80997955361aad3aa78a315418b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_548d0b4a8679dc3881b256a2adf62bd1.setIcon(icon_1e57c80997955361aad3aa78a315418b);
#
#
#         var popup_fe05f4386df4c470eb56a675adcbc1d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfa962830413534e67dda0b5482fe705 = $(`&lt;div id=&quot;html_dfa962830413534e67dda0b5482fe705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_fe05f4386df4c470eb56a675adcbc1d5.setContent(html_dfa962830413534e67dda0b5482fe705);
#
#
#
#         marker_548d0b4a8679dc3881b256a2adf62bd1.bindPopup(popup_fe05f4386df4c470eb56a675adcbc1d5)
#         ;
#
#
#
#
#             var marker_963837093a105a305fc7427eb5d65d75 = L.marker(
#                 [34.538635, -84.933498],
#                 {}
#             ).addTo(map_12b0c032eaf13063d0cdb9801b275c2d);
#
#
#             var icon_4a4530339cb3c51993e8c459d2d893f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_963837093a105a305fc7427eb5d65d75.setIcon(icon_4a4530339cb3c51993e8c459d2d893f8);
#
#
#         var popup_9375c2732312df78b8caf28cd66b9134 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c9a5f6717c02af824d59d62ec3324f8 = $(`&lt;div id=&quot;html_1c9a5f6717c02af824d59d62ec3324f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_9375c2732312df78b8caf28cd66b9134.setContent(html_1c9a5f6717c02af824d59d62ec3324f8);
#
#
#
#         marker_963837093a105a305fc7427eb5d65d75.bindPopup(popup_9375c2732312df78b8caf28cd66b9134)
#         ;
#
#
#
#
#             var marker_1934b5bf35a9b0c67257d93349c168e7 = L.marker(
#                 [34.945231, -84.961497],
#                 {}
#             ).addTo(map_12b0c032eaf13063d0cdb9801b275c2d);
#
#
#             var icon_32ec4ac9d02a33940a5516b691955958 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1934b5bf35a9b0c67257d93349c168e7.setIcon(icon_32ec4ac9d02a33940a5516b691955958);
#
#
#         var popup_b5f54abfb085018eb4e6238cfd3bdbde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_382e124c1c9870f3d920333e2c79e977 = $(`&lt;div id=&quot;html_382e124c1c9870f3d920333e2c79e977&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_b5f54abfb085018eb4e6238cfd3bdbde.setContent(html_382e124c1c9870f3d920333e2c79e977);
#
#
#
#         marker_1934b5bf35a9b0c67257d93349c168e7.bindPopup(popup_b5f54abfb085018eb4e6238cfd3bdbde)
#         ;
#
#
#
#
#             var marker_7a846112f1a3eea07096d75bd18a2ec5 = L.marker(
#                 [32.096862, -83.768232],
#                 {}
#             ).addTo(map_12b0c032eaf13063d0cdb9801b275c2d);
#
#
#             var icon_0611356b6dc8f4975e648e774b7a6e27 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;ic

# %%
make_map(df_2019, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c920598b73a7b4f58ac15dfe85d700b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c920598b73a7b4f58ac15dfe85d700b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c920598b73a7b4f58ac15dfe85d700b5 = L.map(
#                 &quot;map_c920598b73a7b4f58ac15dfe85d700b5&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a6a7298941ea374b2ccf03495b485bd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c920598b73a7b4f58ac15dfe85d700b5);
#
#
#             var marker_24cf5f87f077f9ee60084864395b84c9 = L.marker(
#                 [34.096808, -82.838565],
#                 {}
#             ).addTo(map_c920598b73a7b4f58ac15dfe85d700b5);
#
#
#             var icon_3e7c5ba3b5a3f30d58a7b085cfdba4e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_24cf5f87f077f9ee60084864395b84c9.setIcon(icon_3e7c5ba3b5a3f30d58a7b085cfdba4e2);
#
#
#         var popup_d3b02296e7e23e4c4a8443b4e090de0d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4fb45f3480550f07fb70c16f89080a40 = $(`&lt;div id=&quot;html_4fb45f3480550f07fb70c16f89080a40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_d3b02296e7e23e4c4a8443b4e090de0d.setContent(html_4fb45f3480550f07fb70c16f89080a40);
#
#
#
#         marker_24cf5f87f077f9ee60084864395b84c9.bindPopup(popup_d3b02296e7e23e4c4a8443b4e090de0d)
#         ;
#
#
#
#
#             var marker_89f128e533f7a9f9c2f790cd0cf4abe9 = L.marker(
#                 [33.96832, -83.43656],
#                 {}
#             ).addTo(map_c920598b73a7b4f58ac15dfe85d700b5);
#
#
#             var icon_8b04f0e224501dd17088d769fd35e23e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89f128e533f7a9f9c2f790cd0cf4abe9.setIcon(icon_8b04f0e224501dd17088d769fd35e23e);
#
#
#         var popup_1ae112299dffc0287d0f65f8fa32081b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81388570ca316bfce22e430ed7da3967 = $(`&lt;div id=&quot;html_81388570ca316bfce22e430ed7da3967&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_1ae112299dffc0287d0f65f8fa32081b.setContent(html_81388570ca316bfce22e430ed7da3967);
#
#
#
#         marker_89f128e533f7a9f9c2f790cd0cf4abe9.bindPopup(popup_1ae112299dffc0287d0f65f8fa32081b)
#         ;
#
#
#
#
#             var marker_0030ebc2a95b5b41f5aebd5d5a53f7f5 = L.marker(
#                 [34.945231, -84.961497],
#                 {}
#             ).addTo(map_c920598b73a7b4f58ac15dfe85d700b5);
#
#
#             var icon_c8739bf8356515ed9114f2430ccb45f2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0030ebc2a95b5b41f5aebd5d5a53f7f5.setIcon(icon_c8739bf8356515ed9114f2430ccb45f2);
#
#
#         var popup_ccc852cc93e66d8f0e61eedf9b11f7d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68ade58b8d0048411c635fe18a44daab = $(`&lt;div id=&quot;html_68ade58b8d0048411c635fe18a44daab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_ccc852cc93e66d8f0e61eedf9b11f7d7.setContent(html_68ade58b8d0048411c635fe18a44daab);
#
#
#
#         marker_0030ebc2a95b5b41f5aebd5d5a53f7f5.bindPopup(popup_ccc852cc93e66d8f0e61eedf9b11f7d7)
#         ;
#
#
#
#
#             var marker_8a27b735ac4d8587f2aa6add3a00f673 = L.marker(
#                 [32.096862, -83.768232],
#                 {}
#             ).addTo(map_c920598b73a7b4f58ac15dfe85d700b5);
#
#
#             var icon_c31ad4617f352ce438f8d015ac184192 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;icon

# %%
make_map(df_2020, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7401542887fd958c350f0332fca7e746 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7401542887fd958c350f0332fca7e746&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7401542887fd958c350f0332fca7e746 = L.map(
#                 &quot;map_7401542887fd958c350f0332fca7e746&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fffae3ba4f57ae190dfeb8cb9111b9e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7401542887fd958c350f0332fca7e746);
#
#
#             var marker_c9a503ede1de89d11432a4fb90bc6ee0 = L.marker(
#                 [34.096808, -82.838565],
#                 {}
#             ).addTo(map_7401542887fd958c350f0332fca7e746);
#
#
#             var icon_e3ef89d3ad1f2eb56e260c37e7d629ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c9a503ede1de89d11432a4fb90bc6ee0.setIcon(icon_e3ef89d3ad1f2eb56e260c37e7d629ec);
#
#
#         var popup_21be6bf7c92f663a52c006502ea598b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f4ebe8365bcd300eea4f751df4ba5d8 = $(`&lt;div id=&quot;html_5f4ebe8365bcd300eea4f751df4ba5d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_21be6bf7c92f663a52c006502ea598b4.setContent(html_5f4ebe8365bcd300eea4f751df4ba5d8);
#
#
#
#         marker_c9a503ede1de89d11432a4fb90bc6ee0.bindPopup(popup_21be6bf7c92f663a52c006502ea598b4)
#         ;
#
#
#
#
#             var marker_8b33234a5f5b9e472a6e159668515864 = L.marker(
#                 [33.96832, -83.43656],
#                 {}
#             ).addTo(map_7401542887fd958c350f0332fca7e746);
#
#
#             var icon_ee611db02733f730bd47a1186615b255 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8b33234a5f5b9e472a6e159668515864.setIcon(icon_ee611db02733f730bd47a1186615b255);
#
#
#         var popup_7b5e9ffb70bce959e6dfa5410e174a09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54442528fb735853a808203e7cd5c6e9 = $(`&lt;div id=&quot;html_54442528fb735853a808203e7cd5c6e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_7b5e9ffb70bce959e6dfa5410e174a09.setContent(html_54442528fb735853a808203e7cd5c6e9);
#
#
#
#         marker_8b33234a5f5b9e472a6e159668515864.bindPopup(popup_7b5e9ffb70bce959e6dfa5410e174a09)
#         ;
#
#
#
#
#             var marker_3e536f8cd885ed55f9fd33115bde271e = L.marker(
#                 [34.945231, -84.961497],
#                 {}
#             ).addTo(map_7401542887fd958c350f0332fca7e746);
#
#
#             var icon_bcd3a1510cdf277071f2f4070602e0ef = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3e536f8cd885ed55f9fd33115bde271e.setIcon(icon_bcd3a1510cdf277071f2f4070602e0ef);
#
#
#         var popup_37562812de72569610cea75b5999f2b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56c414fc998536d7faf38c1c3a9e068d = $(`&lt;div id=&quot;html_56c414fc998536d7faf38c1c3a9e068d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_37562812de72569610cea75b5999f2b7.setContent(html_56c414fc998536d7faf38c1c3a9e068d);
#
#
#
#         marker_3e536f8cd885ed55f9fd33115bde271e.bindPopup(popup_37562812de72569610cea75b5999f2b7)
#         ;
#
#
#
#
#             var marker_83c684c7ef66100bb90912e02dd71426 = L.marker(
#                 [33.571234, -83.152441],
#                 {}
#             ).addTo(map_7401542887fd958c350f0332fca7e746);
#
#
#             var icon_5e96b3a05b8458a3aeecccc593d2c002 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;icon

# %%
make_map(df_2021, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c5d87b51ea8791232772b620d721f95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c5d87b51ea8791232772b620d721f95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c5d87b51ea8791232772b620d721f95 = L.map(
#                 &quot;map_6c5d87b51ea8791232772b620d721f95&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11b29bf82c160da5aa98722431f47731 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c5d87b51ea8791232772b620d721f95);
#
#
#             var marker_5afc4ea53cb35ed17264bdcbe650d231 = L.marker(
#                 [34.096808, -82.838565],
#                 {}
#             ).addTo(map_6c5d87b51ea8791232772b620d721f95);
#
#
#             var icon_1bd0a0c3519024d0d6c7fc362c646222 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5afc4ea53cb35ed17264bdcbe650d231.setIcon(icon_1bd0a0c3519024d0d6c7fc362c646222);
#
#
#         var popup_9dd9a5ed36c2c876593bb102b0f4b592 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5b5d7f4f8ea625fa8cf5b30fe1c0ded = $(`&lt;div id=&quot;html_f5b5d7f4f8ea625fa8cf5b30fe1c0ded&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_9dd9a5ed36c2c876593bb102b0f4b592.setContent(html_f5b5d7f4f8ea625fa8cf5b30fe1c0ded);
#
#
#
#         marker_5afc4ea53cb35ed17264bdcbe650d231.bindPopup(popup_9dd9a5ed36c2c876593bb102b0f4b592)
#         ;
#
#
#
#
#             var marker_5f51decdfd8f05c3a3f11c143d670cda = L.marker(
#                 [33.96832, -83.43656],
#                 {}
#             ).addTo(map_6c5d87b51ea8791232772b620d721f95);
#
#
#             var icon_eb54a98aa373afdcb9f5da2eb9f64cdf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5f51decdfd8f05c3a3f11c143d670cda.setIcon(icon_eb54a98aa373afdcb9f5da2eb9f64cdf);
#
#
#         var popup_b3cda515a5ecf6c80943ef397086fd2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4aae80f1312d130b46a60567056b8dc7 = $(`&lt;div id=&quot;html_4aae80f1312d130b46a60567056b8dc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_b3cda515a5ecf6c80943ef397086fd2e.setContent(html_4aae80f1312d130b46a60567056b8dc7);
#
#
#
#         marker_5f51decdfd8f05c3a3f11c143d670cda.bindPopup(popup_b3cda515a5ecf6c80943ef397086fd2e)
#         ;
#
#
#
#
#             var marker_19ad38e81dd071256b61afffe39b2a02 = L.marker(
#                 [34.538635, -84.933498],
#                 {}
#             ).addTo(map_6c5d87b51ea8791232772b620d721f95);
#
#
#             var icon_eb93ad2e35d53a497c0265a30934ddf1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_19ad38e81dd071256b61afffe39b2a02.setIcon(icon_eb93ad2e35d53a497c0265a30934ddf1);
#
#
#         var popup_a284787ee946b7d765fe34e515f7e301 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_399542db3374364431b6a6f4c50f2f16 = $(`&lt;div id=&quot;html_399542db3374364431b6a6f4c50f2f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_a284787ee946b7d765fe34e515f7e301.setContent(html_399542db3374364431b6a6f4c50f2f16);
#
#
#
#         marker_19ad38e81dd071256b61afffe39b2a02.bindPopup(popup_a284787ee946b7d765fe34e515f7e301)
#         ;
#
#
#
#
#             var marker_e46ecc4fcef427003b40e65426819096 = L.marker(
#                 [34.945231, -84.961497],
#                 {}
#             ).addTo(map_6c5d87b51ea8791232772b620d721f95);
#
#
#             var icon_dfc7c514ae1c8c6c78b19c35f9af293a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;icon

# %%
make_map(df_2022, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db7b37140e5b4555d689939282ed83eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db7b37140e5b4555d689939282ed83eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db7b37140e5b4555d689939282ed83eb = L.map(
#                 &quot;map_db7b37140e5b4555d689939282ed83eb&quot;,
#                 {
#                     center: [32.157, -82.907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72c4677496a311590c4e16c8d9688a68 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_db7b37140e5b4555d689939282ed83eb);
#
#
#             var marker_c42a9328457286258ee016af8f7c4792 = L.marker(
#                 [34.096808, -82.838565],
#                 {}
#             ).addTo(map_db7b37140e5b4555d689939282ed83eb);
#
#
#             var icon_d5f7804f910032cdeb51511294258727 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c42a9328457286258ee016af8f7c4792.setIcon(icon_d5f7804f910032cdeb51511294258727);
#
#
#         var popup_febf891b712f8caad16520159034fb82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_659ece79898b9eeb55577b9fe92385ee = $(`&lt;div id=&quot;html_659ece79898b9eeb55577b9fe92385ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_febf891b712f8caad16520159034fb82.setContent(html_659ece79898b9eeb55577b9fe92385ee);
#
#
#
#         marker_c42a9328457286258ee016af8f7c4792.bindPopup(popup_febf891b712f8caad16520159034fb82)
#         ;
#
#
#
#
#             var marker_a3b5fdf87d30d3a8d3e6a8039ec5ef36 = L.marker(
#                 [34.054545, -83.100871],
#                 {}
#             ).addTo(map_db7b37140e5b4555d689939282ed83eb);
#
#
#             var icon_5f7f93d98c902c8607848d8b0dd40f47 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a3b5fdf87d30d3a8d3e6a8039ec5ef36.setIcon(icon_5f7f93d98c902c8607848d8b0dd40f47);
#
#
#         var popup_0007cc9031c135490e75c5ac17cf9ad0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28f342399ad7fee366bb23e8304a2cc3 = $(`&lt;div id=&quot;html_28f342399ad7fee366bb23e8304a2cc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;House of Raeford Farms Inc&lt;/div&gt;`)[0];
#                 popup_0007cc9031c135490e75c5ac17cf9ad0.setContent(html_28f342399ad7fee366bb23e8304a2cc3);
#
#
#
#         marker_a3b5fdf87d30d3a8d3e6a8039ec5ef36.bindPopup(popup_0007cc9031c135490e75c5ac17cf9ad0)
#         ;
#
#
#
#
#             var marker_38a29dbe1e8081620fdc1b471d398bbf = L.marker(
#                 [33.96832, -83.43656],
#                 {}
#             ).addTo(map_db7b37140e5b4555d689939282ed83eb);
#
#
#             var icon_13ec84851773ed9aff0bdcbe2c9bd7fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_38a29dbe1e8081620fdc1b471d398bbf.setIcon(icon_13ec84851773ed9aff0bdcbe2c9bd7fa);
#
#
#         var popup_d23f9ba2e06e190f5ca8b412ea811ed3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b913eb31a5a8a90fa10427374398e57b = $(`&lt;div id=&quot;html_b913eb31a5a8a90fa10427374398e57b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JBS USA&lt;/div&gt;`)[0];
#                 popup_d23f9ba2e06e190f5ca8b412ea811ed3.setContent(html_b913eb31a5a8a90fa10427374398e57b);
#
#
#
#         marker_38a29dbe1e8081620fdc1b471d398bbf.bindPopup(popup_d23f9ba2e06e190f5ca8b412ea811ed3)
#         ;
#
#
#
#
#             var marker_48fdbb8f62ef6b5498371b7dd22141db = L.marker(
#                 [34.538635, -84.933498],
#                 {}
#             ).addTo(map_db7b37140e5b4555d689939282ed83eb);
#
#
#             var icon_fced852bf7b8b1ea5e456de573b4e3b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;in
