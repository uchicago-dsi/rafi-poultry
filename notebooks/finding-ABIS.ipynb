# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/abby/Desktop/2022.csv")
df.head()
# Out:
#    Unnamed: 0                    COMPANY         ADDRESS LINE 1          CITY  \
# 0           0           MIRAGE DRAPERIES  4731 E SUNNY DUNES RD  PALM SPRINGS
# 1           1                        NaN          11700 OLIO RD       FISHERS
# 2           2  STONE RESIN SURFACING LLC         1 MAYFLOWER PL       MILFORD
# 3           3                        NaN            2121 7TH ST   PARKERSBURG
# 4           4      IRONWOOD STATE PRISON   19005 WILEYS WELL RD        BLYTHE
#
#   STATE  ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 0    CA  92264.0  1536.0         65.0        760       2  ...               6
# 1    IN  46037.0  7618.0         57.0        317       1  ...               7
# 2    CT   6460.0  4520.0          9.0        203       2  ...               7
# 3    WV  26101.0  3803.0        107.0        740       1  ...               7
# 4    CA  92225.0  2287.0         65.0        760       2  ...               7
#
# ...

# %%
df.loc[df['ABI'] == 7537913]
# Out:
#          Unnamed: 0          COMPANY         ADDRESS LINE 1        CITY STATE  \
# 7849218     7849218  TYSON FOODS INC  2200 W DON TYSON PKWY  SPRINGDALE    AR
#
#          ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 7849218  72762.0  6901.0        143.0        479       2  ...               7
#
#         CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE MATCH CODE  \
# 7849218      10403.0           2.0  36.154021 -94.154599          P
#
#          CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 7849218    22220.0        2.0       0.0    5143.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 987289857]
# Out:
#          Unnamed: 0  COMPANY       ADDRESS LINE 1     CITY STATE  ZIPCODE  \
# 5237907     5237907  JBS USA  1770 PROMONTORY CIR  GREELEY    CO  80634.0
#
#            ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 5237907  9039.0        123.0        970       2  ...               8
#
#         CENSUS TRACT  CENSUS BLOCK   LATITUDE   LONGITUDE MATCH CODE  \
# 5237907       2101.0           4.0  40.411168 -104.855864          P
#
#          CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 5237907    24540.0        2.0     216.0    8123.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 7516065]
# Out:
#           Unnamed: 0            COMPANY ADDRESS LINE 1    CITY STATE  ZIPCODE  \
# 11281273    11281273  HORMEL FOODS CORP    1 HORMEL PL  AUSTIN    MN  55912.0
#
#             ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 11281273  3680.0         99.0        507       2  ...               7
#
#          CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE MATCH CODE  \
# 11281273        100.0           1.0  43.681528 -92.967875          0
#
#           CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 11281273    12380.0        1.0     462.0   27099.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 453614844]
# Out:
#           Unnamed: 0      COMPANY      ADDRESS LINE 1     CITY STATE  ZIPCODE  \
# 15842222    15842222  CARGILL INC  15407 MCGINTY RD W  WAYZATA    MN  55391.0
#
#             ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 15842222  2399.0         53.0        952       2  ...               6
#
#          CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE MATCH CODE  \
# 15842222      26301.0           1.0  44.952336 -93.479931          P
#
#           CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 15842222    33460.0        2.0     378.0   27053.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 9564816]
# Out:
#           Unnamed: 0       COMPANY ADDRESS LINE 1        CITY STATE  ZIPCODE  \
# 10903107    10903107  FOSTER FARMS  1000 DAVIS ST  LIVINGSTON    CA  95334.0
#
#             ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 10903107  1526.0         47.0        209       2  ...               6
#
#          CENSUS TRACT  CENSUS BLOCK   LATITUDE   LONGITUDE MATCH CODE  \
# 10903107        301.0           1.0  37.390186 -120.724886          P
#
#           CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 10903107    32900.0        2.0     488.0    6047.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 441416815]
# Out:
#        Unnamed: 0              COMPANY ADDRESS LINE 1    CITY STATE  ZIPCODE  \
# 83903       83903  SANDERSON FARMS INC   127 FLYNT RD  LAUREL    MS  39443.0
#
#          ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 83903  9062.0         67.0        601       2  ...               7
#
#       CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE MATCH CODE  CBSA CODE  \
# 83903     950401.0           2.0  31.716851 -89.159586          P    29860.0
#
#       CBSA LEVEL  CSA CODE FIPS CODE
# 83903        1.0     279.0   28067.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 517549762]
# Out:
#          Unnamed: 0         COMPANY         ADDRESS LINE 1        CITY STATE  \
# 7451439     7451439  KOCH FOODS INC  1300 HIGGINS RD # 100  PARK RIDGE    IL
#
#          ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 7451439  60068.0  5766.0         31.0        847       2  ...               7
#
#         CENSUS TRACT  CENSUS BLOCK  LATITUDE  LONGITUDE MATCH CODE  CBSA CODE  \
# 7451439     805702.0           2.0  41.98784  -87.84257          P    16980.0
#
#         CBSA LEVEL  CSA CODE FIPS CODE
# 7451439        2.0     176.0   17031.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 835874538]
# Out:
#          Unnamed: 0         COMPANY       ADDRESS LINE 1         CITY STATE  \
# 8313159     8313159  MOUNTAIRE CORP  1901 NAPA VALLEY DR  LITTLE ROCK    AR
#
#          ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 8313159  72212.0  3913.0        119.0        501       2  ...               6
#
#         CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE MATCH CODE  \
# 8313159       2206.0           1.0  34.771072 -92.410637          P
#
#          CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 8313159    30780.0        2.0     340.0    5119.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 7529217]
# Out:
#          Unnamed: 0           COMPANY           ADDRESS LINE 1       CITY  \
# 5499929     5499929  PERDUE FARMS INC  31149 OLD OCEAN CITY RD  SALISBURY
#
#         STATE  ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ...  \
# 5499929    MD  21804.0  1806.0         45.0        410       2  ...
#
#         POPULATION CODE CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE  \
# 5499929               7      10603.0           4.0  38.373403 -75.533356
#
#         MATCH CODE  CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 5499929          P    41540.0        2.0     480.0   24045.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 433353331]
# Out:
#          Unnamed: 0               COMPANY    ADDRESS LINE 1      CITY STATE  \
# 9769570     9769570  CONTINENTAL GRAIN CO  767 5TH AVE # 15  NEW YORK    NY
#
#          ZIPCODE  ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 9769570  10153.0  15.0         61.0        212       2  ...               1
#
#         CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE MATCH CODE  \
# 9769570      11202.0           1.0  40.763537 -73.972248          P
#
#          CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 9769570    35620.0        2.0     408.0   36061.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 513523]
# Out:
#           Unnamed: 0                     COMPANY     ADDRESS LINE 1  \
# 12785766    12785766  HOUSE OF RAEFORD FARMS INC  3425 S US 117 HWY
#
#                CITY STATE  ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  \
# 12785766  ROSE HILL    NC  28458.0  8430.0         61.0        910       2
#
#           ... POPULATION CODE CENSUS TRACT  CENSUS BLOCK   LATITUDE  \
# 12785766  ...               5      90802.0           1.0  34.853773
#
#           LONGITUDE MATCH CODE  CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 12785766 -78.030532          P        0.0        NaN       0.0   37061.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 436136139]
# Out:
#          Unnamed: 0               COMPANY       ADDRESS LINE 1     CITY STATE  \
# 5476894     5476894  PILGRIM'S PRIDE CORP  1770 PROMONTORY CIR  GREELEY    CO
#
#          ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 5476894  80634.0  9039.0        123.0        970       2  ...               8
#
#         CENSUS TRACT  CENSUS BLOCK   LATITUDE   LONGITUDE MATCH CODE  \
# 5476894       2101.0           4.0  40.411168 -104.855864          P
#
#          CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 5476894    24540.0        2.0     216.0    8123.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 512392]
# Out:
#          Unnamed: 0       COMPANY      ADDRESS LINE 1        CITY STATE  \
# 7988927     7988927  GEORGE'S INC  402 W ROBINSON AVE  SPRINGDALE    AR
#
#          ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 7988927  72764.0  6359.0        143.0        479       2  ...               8
#
#         CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE MATCH CODE  \
# 7988927      10301.0           1.0  36.167844 -94.137676          P
#
#          CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 7988927    22220.0        2.0       0.0    5143.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 431481290]
# Out:
#          Unnamed: 0              COMPANY                  ADDRESS LINE 1  \
# 3785674     3785674  CAL-MAINE FOODS INC  1052 HIGHLAND COLONY PKWY #200
#
#               CITY STATE  ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  \
# 3785674  RIDGELAND    MS  39157.0  8764.0         89.0        601       2
#
#          ... POPULATION CODE CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE  \
# 3785674  ...               7      30205.0           1.0  32.442568  -90.14809
#
#         MATCH CODE  CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 3785674          P    27140.0        2.0     298.0   28089.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 7509045]
# Out:
#          Unnamed: 0             COMPANY                  ADDRESS LINE 1  \
# 7549001     7549001  CONAGRA BRANDS INC  222 MERCHANDISE MART PLZ #1300
#
#             CITY STATE  ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ...  \
# 7549001  CHICAGO    IL  60654.0  1010.0         31.0        312       2  ...
#
#         POPULATION CODE CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE  \
# 7549001               6      81800.0           3.0  41.888369 -87.635361
#
#         MATCH CODE  CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 7549001          P    16980.0        2.0     176.0   17031.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 7534076]
# Out:
#          Unnamed: 0            COMPANY ADDRESS LINE 1            CITY STATE  \
# 8402133     8402133  SIMMONS FOODS INC  601 N HICO ST  SILOAM SPRINGS    AR
#
#          ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ... POPULATION CODE  \
# 8402133  72761.0  2410.0          7.0        479       2  ...               7
#
#         CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE MATCH CODE  \
# 8402133      21101.0           4.0  36.190768 -94.530012          P
#
#          CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 8402133    22220.0        2.0       0.0    5007.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 531052413]
# Out:
#           Unnamed: 0         COMPANY       ADDRESS LINE 1        CITY STATE  \
# 13805573    13805573  PECO FOODS INC  1101 GREENSBORO AVE  TUSCALOOSA    AL
#
#           ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ...  \
# 13805573  35401.0  2836.0        125.0        205       2  ...
#
#          POPULATION CODE CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE  \
# 13805573               7      11600.0           1.0  33.203954 -87.565139
#
#          MATCH CODE  CBSA CODE CBSA LEVEL  CSA CODE FIPS CODE
# 13805573          P    46220.0        2.0       0.0    1125.0
#
# [1 rows x 54 columns]

# %%
df.loc[df['ABI'] == 1941509]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, COMPANY, ADDRESS LINE 1, CITY, STATE, ZIPCODE, ZIP4, COUNTY CODE, AREA CODE, IDCODE, LOCATION EMPLOYEE SIZE CODE, LOCATION SALES VOLUME CODE, PRIMARY SIC CODE, SIC6_DESCRIPTIONS, PRIMARY NAICS CODE, NAICS8 DESCRIPTIONS, SIC CODE, SIC6_DESCRIPTIONS (SIC), SIC CODE 1, SIC6_DESCRIPTIONS (SIC1), SIC CODE 2, SIC6_DESCRIPTIONS(SIC2), SIC CODE 3, SIC6_DESCRIPTIONS(SIC3), SIC CODE 4, SIC6_DESCRIPTIONS(SIC4), ARCHIVE VERSION YEAR, YELLOW PAGE CODE, EMPLOYEE SIZE (5) - LOCATION, SALES VOLUME (9) - LOCATION, BUSINESS STATUS CODE, INDUSTRY SPECIFIC FIRST BYTE, YEAR ESTABLISHED, OFFICE SIZE CODE, COMPANY HOLDING STATUS, ABI, SUBSIDIARY NUMBER, PARENT NUMBER, PARENT ACTUAL EMPLOYEE SIZE, PARENT ACTUAL SALES VOLUME, PARENT EMPLOYEE SIZE CODE, PARENT SALES VOLUME CODE, SITE NUMBER, ADDRESS TYPE INDICATOR, POPULATION CODE, CENSUS TRACT, CENSUS BLOCK, LATITUDE, LONGITUDE, MATCH CODE, CBSA CODE, CBSA LEVEL, CSA CODE, FIPS CODE]
# Index: []
#
# ...
