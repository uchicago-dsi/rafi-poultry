# %% [markdown]
# ### CAFO Poultry Plants EDA
#
# This notebook includes exploratory data analysis on and mapping of poultry plants in the state permits and Counterglow datasets.

# %%
import pandas as pd
from pipeline.utils.visualize import map_state
from pipeline.constants import CLEANED_CAFO_POULTRY_FPATH, CLEANED_COUNTERGLOW_FPATH, MATCHED_FARMS_FPATH, UNMATCHED_FARMS_FPATH

# %%
permit_data_joined = pd.read_csv(CLEANED_CAFO_POULTRY_FPATH)
counterglow = pd.read_csv(CLEANED_COUNTERGLOW_FPATH)

permit_data_joined.head()
# Out:
#    Unnamed: 0                     name                        permit state  \
# 0           0             4D Farms LLC  General Permit - Poultry AFO    MS
# 1           1             4S Farms LLC  General Permit - Poultry AFO    MS
# 2           2  A B Westbrook Farms LLC  General Permit - Poultry AFO    MS
# 3           3          A and J Poultry  General Permit - Poultry AFO    MS
# 4           4     A and W Garner Farms  General Permit - Poultry AFO    MS
#
#                                             source address  lat  long
# 0  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 1  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 2  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 3  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 4  Mississippi Department of Environmental Quality     NaN  NaN   NaN

# %% [markdown]
# There are currently three states in the combined state permit dataset, but more can be added to the cafo folder for the clean_cafo function to process.

# %%
permit_data_joined['state'].unique()
# Out:
# array(['MS', 'NC', 'AL'], dtype=object)

# %%
counterglow.head()
# Out:
#    Unnamed: 0 Name   Latitude  Longitude  \
# 0           0   78  43.396729 -95.923149
# 1           1   84  42.925350 -96.429291
# 2           2   87  40.658218 -92.410202
# 3           3   88  40.643219 -92.409889
# 4           4   89  40.660851 -92.421219
#
#                                              Address City State        County  \
# 0       1757 Lily Avenue George 51237, United States  NaN    IA   Lyon County
# 1    1804 500th Street Hawarden 51023, United States  NaN    IA  Sioux County
# 2  21166 Mahogany Avenue Bloomfield 52537, United...  NaN    IA  Davis County
# 3  27268 Mahogany Avenue Bloomfield 52537, United...  NaN    IA  Davis County
# 4  21166 280th Street Bloomfield 52537, United St...  NaN    IA  Davis County
#
#    Description Business/company name  ... Phone number Region Facility name  \
# 0          NaN                   NaN  ...          NaN    NaN           NaN
# 1          NaN                   NaN  ...          NaN    NaN           NaN
# 2          NaN                   NaN  ...          NaN    NaN           NaN
# 3          NaN                   NaN  ...          NaN    NaN           NaN
# 4          NaN                   NaN  ...          NaN    NaN           NaN
#
#   Number of animals Full address Website URL  Postcode  Suburb/city  \
# 0               NaN          NaN         NaN       NaN          NaN
# 1               NaN          NaN         NaN       NaN          NaN
# 2               NaN          NaN         NaN       NaN          NaN
# 3               NaN          NaN         NaN       NaN          NaN
# 4               NaN          NaN         NaN       NaN          NaN
#
#   Contracted to    Farm Type
# 0           NaN  Pigs (Meat)
# 1           NaN  Pigs (Meat)
# 2           NaN  Pigs (Meat)
# 3           NaN  Pigs (Meat)
# 4           NaN  Pigs (Meat)
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Cleaning
#
# To clean these datasets, we matched poultry CAFOs by name and location (if provided) in the state permit dataset to CAFOs listed in the Counterglow dataset, while recording how fuzzy the match was (ie. whether it was a perfect name and location match or a fuzzy match). Both matched and unmatched farms are provided in separate files.

# %%
matched_farms = pd.read_csv(MATCHED_FARMS_FPATH)
unmatched_farms = pd.read_csv(UNMATCHED_FARMS_FPATH)

matched_farms.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                            name  \
# 0             9           9             ALAN YOUNG, POULTRY
# 1            16          16  ALLEN AND JONNI JONES, POULTRY
# 2            23          23          ANDY HOLTCAMP, POULTRY
# 3            29          29       ARNOLD OVERSTREET POULTRY
# 4            31          31        ARTIS R WINDHAM, POULTRY
#
#                          permit state  \
# 0  General Permit - Poultry AFO    MS
# 1  General Permit - Poultry AFO    MS
# 2  General Permit - Poultry AFO    MS
# 3  General Permit - Poultry AFO    MS
# 4  General Permit - Poultry AFO    MS
#
#                                             source address  lat  long  \
# 0  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 1  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 2  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 3  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 4  Mississippi Department of Environmental Quality     NaN  NaN   NaN
#
#             Exact Name Match                     Fuzzy Name  \
# 0                        NaN             ALAN YOUNG POULTRY
# 1                        NaN  ALLEN AND JONNI JONES POULTRY
# 2                        NaN          ANDY HOLTCAMP POULTRY
# 3  ARNOLD OVERSTREET POULTRY                            NaN
# 4                        NaN        ARTIS R WINDHAM POULTRY
#
#   Exact Name/Location  Fuzzy Name/Exact Location Location Match
# 0                 NaN                        NaN            NaN
# 1                 NaN                        NaN            NaN
# 2                 NaN                        NaN            NaN
# 3                 NaN                        NaN            NaN
# 4                 NaN                        NaN            NaN

# %%
unmatched_farms.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                     name  \
# 0             0           0             4D FARMS LLC
# 1             1           1             4S FARMS LLC
# 2             2           2  A B WESTBROOK FARMS LLC
# 3             3           3          A AND J POULTRY
# 4             4           4     A AND W GARNER FARMS
#
#                          permit state  \
# 0  General Permit - Poultry AFO    MS
# 1  General Permit - Poultry AFO    MS
# 2  General Permit - Poultry AFO    MS
# 3  General Permit - Poultry AFO    MS
# 4  General Permit - Poultry AFO    MS
#
#                                             source address  lat  long  \
# 0  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 1  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 2  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 3  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 4  Mississippi Department of Environmental Quality     NaN  NaN   NaN
#
#    Exact Name Match  ...  Phone number  Region  Facility name  \
# 0               NaN  ...           NaN     NaN            NaN
# 1               NaN  ...           NaN     NaN            NaN
# 2               NaN  ...           NaN     NaN            NaN
# 3               NaN  ...           NaN     NaN            NaN
# 4               NaN  ...           NaN     NaN            NaN
#
#    Number of animals Full address Website URL  Postcode  Suburb/city  \
# 0                NaN          NaN         NaN       NaN          NaN
# 1                NaN          NaN         NaN       NaN          NaN
# 2                NaN          NaN         NaN       NaN          NaN
# 3                NaN          NaN         NaN       NaN          NaN
# 4                NaN          NaN         NaN       NaN          NaN
#
#    Contracted to Farm Type
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Visualizations of CAFOs
#
# Green markers indicate CAFOs that were found in both datasets, red markers were CAFOs only present in Counterglow, and blue markers were CAFOs only present in state permit data. Only farms with location provided could be plotted.

# %%
nc_map = map_state(MATCHED_FARMS_FPATH, UNMATCHED_FARMS_FPATH, "NC")
nc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56b23e7619b9eed02c0e6b016183fe97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56b23e7619b9eed02c0e6b016183fe97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56b23e7619b9eed02c0e6b016183fe97 = L.map(
#                 &quot;map_56b23e7619b9eed02c0e6b016183fe97&quot;,
#                 {
#                     center: [35.7917213, -78.300188],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_56b23e7619b9eed02c0e6b016183fe97);
#
#
#
#
#
#             var tile_layer_0b62c2dd98c27a7551ba163d093f1c52 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_56b23e7619b9eed02c0e6b016183fe97);
#
#
#             var marker_cfc415176846720790ac67bee3930de6 = L.marker(
#                 [35.182138, -80.276524],
#                 {}
#             ).addTo(map_56b23e7619b9eed02c0e6b016183fe97);
#
#
#             var icon_32f5abeb3e0e751eaa3dad0f46913602 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cfc415176846720790ac67bee3930de6.setIcon(icon_32f5abeb3e0e751eaa3dad0f46913602);
#
#
#         var popup_76f1986b80199b573623f2353e14b733 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_afddf608cfb239dbf6d60e878a2cb20c = $(`&lt;div id=&quot;html_afddf608cfb239dbf6d60e878a2cb20c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FLINT RIDGE PULLET FARM&lt;/div&gt;`)[0];
#                 popup_76f1986b80199b573623f2353e14b733.setContent(html_afddf608cfb239dbf6d60e878a2cb20c);
#
#
#
#         marker_cfc415176846720790ac67bee3930de6.bindPopup(popup_76f1986b80199b573623f2353e14b733)
#         ;
#
#
#
#
#             var marker_2810ac91ed3449d8f8eb9dd8ef4b5348 = L.marker(
#                 [36.0736, -78.1347],
#                 {}
#             ).addTo(map_56b23e7619b9eed02c0e6b016183fe97);
#
#
#             var icon_e49bc65ac8f07a2b587a91fd4a910088 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2810ac91ed3449d8f8eb9dd8ef4b5348.setIcon(icon_e49bc65ac8f07a2b587a91fd4a910088);
#
#
#         var popup_e20a639347e52042d1bbe097cf1ba684 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5bbdcfe10a62bbd6bcdf6b42b4b5010 = $(`&lt;div id=&quot;html_c5bbdcfe10a62bbd6bcdf6b42b4b5010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GARDNER FARM POULTRY&lt;/div&gt;`)[0];
#                 popup_e20a639347e52042d1bbe097cf1ba684.setContent(html_c5bbdcfe10a62bbd6bcdf6b42b4b5010);
#
#
#
#         marker_2810ac91ed3449d8f8eb9dd8ef4b5348.bindPopup(popup_e20a639347e52042d1bbe097cf1ba684)
#         ;
#
#
#
#
#             var marker_e0d03775057fbd5a7023af41eafbe6b4 = L.marker(
#                 [35.6417, -76.525],
#                 {}
#             ).addTo(map_56b23e7619b9eed02c0e6b016183fe97);
#
#
#             var icon_1e66f7312a08cc5132fb97300f043e6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0d03775057fbd5a7023af41eafbe6b4.setIcon(icon_1e66f7312a08cc5132fb97300f043e6c);
#
#
#         var popup_20a88922c5d836faba073719a1d6a53a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_66ac24882c439751078cbd938d1dbfd2 = $(`&lt;div id=&quot;html_66ac24882c439751078cbd938d1dbfd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;HYDE COUNTY EGG FARM&lt;/div&gt;`)[0];
#                 popup_20a88922c5d836faba073719a1d6a53a.setContent(html_66ac24882c439751078cbd938d1dbfd2);
#
#
#
#         marker_e0d03775057fbd5a7023af41eafbe6b4.bindPopup(popup_20a88922c5d836faba073719a1d6a53a)
#         ;
#
#
#
#
#             var marker_5bddd46fd7a0aa6d657948e99608ca9d = L.marker(
#                 [35.6417, -76.525],
#                 {}
#             ).addTo(map_56b23e7619b9eed02c0e6b016183fe97);
#
#
#             var icon_a7d52942c89aad6425b90d49961f024b = L.AwesomeMarkers.icon(
