# %% [markdown]
# ### CAFO Poultry Plants EDA
#
# This notebook includes exploratory data analysis on and mapping of poultry plants in the state permits and Counterglow datasets.

# %%
import pandas as pd
import sys, os
sys.path.append(os.path.join(os.path.abspath(""), '..', 'pipeline'))
from utils.visualize import map_state

# %%
# TODO: load configuration here
permit_data_joined = pd.read_csv("../data/clean/cleaned_matched_farms.csv")
counterglow = pd.read_csv("../data/raw/Counterglow+Facility+List+Complete.csv")

permit_data_joined
# Out:
#       Unnamed: 0                     name                        permit state  \
# 0              0             4D Farms LLC  General Permit - Poultry AFO    MS
# 1              1             4S Farms LLC  General Permit - Poultry AFO    MS
# 2              2  A B Westbrook Farms LLC  General Permit - Poultry AFO    MS
# 3              3          A and J Poultry  General Permit - Poultry AFO    MS
# 4              4     A and W Garner Farms  General Permit - Poultry AFO    MS
# ...          ...                      ...                           ...   ...
# 1430        1430           Shadinger Farm                       Broiler    AL
# 1431        1431                 T&R Farm                       Broiler    AL
# 1432        1432              Vince Roden                       Broiler    AL
# 1433        1433          Holyfield Farms                       Broiler    AL
# 1434        1434          Lee Wright Farm                       Broiler    AL
#
#                                                source address  lat  long
# 0     Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 1     Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 2     Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 3     Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 4     Mississippi Department of Environmental Quality     NaN  NaN   NaN
# ...                                               ...     ...  ...   ...
# 1430     Alabama Department of Environment Management     NaN  NaN   NaN
# 1431     Alabama Department of Environment Management     NaN  NaN   NaN
# 1432     Alabama Department of Environment Management     NaN  NaN   NaN
# 1433     Alabama Department of Environment Management     NaN  NaN   NaN
# 1434     Alabama Department of Environment Management     NaN  NaN   NaN
#
# [1435 rows x 8 columns]

# %%
counterglow
# Out:
#       Name        Lat      Lat.1  \
# 0       78  43.396729 -95.923149
# 1       84  42.925350 -96.429291
# 2       87  40.658218 -92.410202
# 3       88  40.643219 -92.409889
# 4       89  40.660851 -92.421219
# ...    ...        ...        ...
# 29848  NaN  34.711910 -80.968360
# 29849  NaN  34.100560 -80.515688
# 29850  NaN  34.714550 -80.660840
# 29851  NaN  34.118400 -80.582200
# 29852  NaN  34.475500 -80.619600
#
#                                                  Address City State  \
# 0           1757 Lily Avenue George 51237, United States  NaN    IA
# 1        1804 500th Street Hawarden 51023, United States  NaN    IA
# 2      21166 Mahogany Avenue Bloomfield 52537, United...  NaN    IA
# 3      27268 Mahogany Avenue Bloomfield 52537, United...  NaN    IA
# 4      21166 280th Street Bloomfield 52537, United St...  NaN    IA
# ...                                                  ...  ...   ...
# 29848                                                NaN  NaN    SC
# 29849                                                NaN  NaN    SC
# 29850                                                NaN  NaN    SC
# 29851                                                NaN  NaN    SC
# 29852                                                NaN  NaN    SC
#
#                  County  Description Business/company name Postal address  \
# 0           Lyon County          NaN                   NaN            NaN
# 1          Sioux County          NaN                   NaN            NaN
# 2          Davis County          NaN                   NaN            NaN
# 3          Davis County          NaN                   NaN            NaN
# 4          Davis County          NaN                   NaN            NaN
# ...                 ...          ...                   ...            ...
# 29848  Lancaster County          NaN                   NaN            NaN
# 29849     Sumter County          NaN                   NaN            NaN
# 29850  Lancaster County          NaN                   NaN            NaN
# 29851    Kershaw County          NaN                   NaN            NaN
# 29852  Lancaster County          NaN                   NaN            NaN
#
#       Phone number Region Facility name Number of animals Full address  \
# 0              NaN    NaN           NaN               NaN          NaN
# 1              NaN    NaN           NaN               NaN          NaN
# 2              NaN    NaN           NaN               NaN          NaN
# 3              NaN    NaN           NaN               NaN          NaN
# 4              NaN    NaN           NaN               NaN          NaN
# ...            ...    ...           ...               ...          ...
# 29848          NaN    NaN           NaN               NaN          NaN
# 29849          NaN    NaN           NaN               NaN          NaN
# 29850          NaN    NaN           NaN               NaN          NaN
# 29851          NaN    NaN           NaN               NaN          NaN
# 29852          NaN    NaN           NaN               NaN          NaN
#
#        Website URL  Postcode Suburb/city Contracted to        Farm Type
# 0              NaN       NaN         NaN           NaN      Pigs (Meat)
# 1              NaN       NaN         NaN           NaN      Pigs (Meat)
# 2              NaN       NaN         NaN           NaN      Pigs (Meat)
# 3              NaN       NaN         NaN           NaN      Pigs (Meat)
# 4              NaN       NaN         NaN           NaN      Pigs (Meat)
# ...            ...       ...         ...           ...              ...
# 29848          NaN       NaN         NaN           NaN  Chickens (Meat)
# 29849          NaN       NaN         NaN           NaN  Chickens (Meat)
# 29850          NaN       NaN         NaN           NaN  Chickens (Meat)
# 29851          NaN       NaN         NaN           NaN  Chickens (Meat)
# 29852          NaN       NaN         NaN           NaN  Chickens (Meat)
#
# [29853 rows x 20 columns]

# %% [markdown]
# #### Cleaning
#
# To clean these datasets, we matched poultry CAFOs by name and location (if provided) in the state permit dataset to CAFOs listed in the Counterglow dataset, while recording how fuzzy the match was. Both matched and unmatched farms are provided in separate files.

# %%
matched_farms = pd.read_csv("../data/clean/matched_farms.csv")
unmatched_farms = pd.read_csv("../data/clean/unmatched_farms.csv")

matched_farms
# Out:
#      Unnamed: 0                            name  \
# 0             9             ALAN YOUNG, POULTRY
# 1            16  ALLEN AND JONNI JONES, POULTRY
# 2            23          ANDY HOLTCAMP, POULTRY
# 3            29       ARNOLD OVERSTREET POULTRY
# 4            31        ARTIS R WINDHAM, POULTRY
# ..          ...                             ...
# 363        1404               ROSE POULTRY FARM
# 364        1405       SPRING HOPE POULTRY INC 2
# 365        1406                     A&D POULTRY
# 366        1407               LATTA'S EGG RANCH
# 367        1408              SIMPSON'S EGGS INC
#
#                             permit state  \
# 0     General Permit - Poultry AFO    MS
# 1     General Permit - Poultry AFO    MS
# 2     General Permit - Poultry AFO    MS
# 3     General Permit - Poultry AFO    MS
# 4     General Permit - Poultry AFO    MS
# ..                             ...   ...
# 363           Wet Poultry - Layers    NC
# 364           Wet Poultry - Layers    NC
# 365           Wet Poultry - Layers    NC
# 366           Wet Poultry - Layers    NC
# 367  Dry Poultry - Laying Chickens    NC
#
#                                                 source  \
# 0      Mississippi Department of Environmental Quality
# 1      Mississippi Department of Environmental Quality
# 2      Mississippi Department of Environmental Quality
# 3      Mississippi Department of Environmental Quality
# 4      Mississippi Department of Environmental Quality
# ..                                                 ...
# 363  North Carolina Department of Environmental Qua...
# 364  North Carolina Department of Environmental Qua...
# 365  North Carolina Department of Environmental Qua...
# 366  North Carolina Department of Environmental Qua...
# 367  North Carolina Department of Environmental Qua...
#
#                     address        lat       long           Exact Name Match  \
# 0                       NaN        NaN        NaN                        NaN
# 1                       NaN        NaN        NaN                        NaN
# 2                       NaN        NaN        NaN                        NaN
# 3                       NaN        NaN        NaN  ARNOLD OVERSTREET POULTRY
# 4                       NaN        NaN        NaN                        NaN
# ..                      ...        ...        ...                        ...
# 363   3326 Taylors Store Rd  36.022800 -77.977800                        NaN
# 364       4051 N NC Hwy 581  36.004400 -78.123600  SPRING HOPE POULTRY INC 2
# 365         2541 Poultry Ln  36.003300 -77.988900                A&D POULTRY
# 366  1016 Governor Burke Rd  36.103600 -79.086400                        NaN
# 367                     NaN  35.127575 -80.419556                        NaN
#
#                         Fuzzy Name Exact Name/Location  \
# 0               ALAN YOUNG POULTRY                 NaN
# 1    ALLEN AND JONNI JONES POULTRY                 NaN
# 2            ANDY HOLTCAMP POULTRY                 NaN
# 3                              NaN                 NaN
# 4          ARTIS R WINDHAM POULTRY                 NaN
# ..                             ...                 ...
# 363                            NaN   ROSE POULTRY FARM
# 364                            NaN                 NaN
# 365                            NaN                 NaN
# 366                            NaN   LATTA'S EGG RANCH
# 367                            NaN  SIMPSON'S EGGS INC
#
#      Fuzzy Name/Exact Location Location Match
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2                          NaN            NaN
# 3                          NaN            NaN
# 4                          NaN            NaN
# ..                         ...            ...
# 363                        NaN            NaN
# 364                        NaN            NaN
# 365                        NaN            NaN
# 366                        NaN            NaN
# 367                        NaN            NaN
#
# [368 rows x 13 columns]

# %%
unmatched_farms
# Out:
#       Unnamed: 0                     name                        permit state  \
# 0              0             4D FARMS LLC  General Permit - Poultry AFO    MS
# 1              1             4S FARMS LLC  General Permit - Poultry AFO    MS
# 2              2  A B WESTBROOK FARMS LLC  General Permit - Poultry AFO    MS
# 3              3          A AND J POULTRY  General Permit - Poultry AFO    MS
# 4              4     A AND W GARNER FARMS  General Permit - Poultry AFO    MS
# ...          ...                      ...                           ...   ...
# 4108        4108                      NaN                           NaN    SC
# 4109        4109                      NaN                           NaN    SC
# 4110        4110                      NaN                           NaN    SC
# 4111        4111                      NaN                           NaN    SC
# 4112        4112                      NaN                           NaN    SC
#
#                                                source address       lat  \
# 0     Mississippi Department of Environmental Quality     NaN       NaN
# 1     Mississippi Department of Environmental Quality     NaN       NaN
# 2     Mississippi Department of Environmental Quality     NaN       NaN
# 3     Mississippi Department of Environmental Quality     NaN       NaN
# 4     Mississippi Department of Environmental Quality     NaN       NaN
# ...                                               ...     ...       ...
# 4108                                      Counterglow     NaN  34.71191
# 4109                                      Counterglow     NaN  34.10056
# 4110                                      Counterglow     NaN  34.71455
# 4111                                      Counterglow     NaN  34.11840
# 4112                                      Counterglow     NaN  34.47550
#
#            long  Exact Name Match  Fuzzy Name  ... Phone number  Region  \
# 0           NaN               NaN         NaN  ...          NaN     NaN
# 1           NaN               NaN         NaN  ...          NaN     NaN
# 2           NaN               NaN         NaN  ...          NaN     NaN
# 3           NaN               NaN         NaN  ...          NaN     NaN
# 4           NaN               NaN         NaN  ...          NaN     NaN
# ...         ...               ...         ...  ...          ...     ...
# 4108 -80.968360               NaN         NaN  ...          NaN     NaN
# 4109 -80.515688               NaN         NaN  ...          NaN     NaN
# 4110 -80.660840               NaN         NaN  ...          NaN     NaN
# 4111 -80.582200               NaN         NaN  ...          NaN     NaN
# 4112 -80.619600               NaN         NaN  ...          NaN     NaN
#
#       Facility name  Number of animals Full address Website URL  Postcode  \
# 0               NaN                NaN          NaN         NaN       NaN
# 1               NaN                NaN          NaN         NaN       NaN
# 2               NaN                NaN          NaN         NaN       NaN
# 3               NaN                NaN          NaN         NaN       NaN
# 4               NaN                NaN          NaN         NaN       NaN
# ...             ...                ...          ...         ...       ...
# 4108            NaN                NaN          NaN         NaN       NaN
# 4109            NaN                NaN          NaN         NaN       NaN
# 4110            NaN                NaN          NaN         NaN       NaN
# 4111            NaN                NaN          NaN         NaN       NaN
# 4112            NaN                NaN          NaN         NaN       NaN
#
#       Suburb/city  Contracted to        Farm Type
# 0             NaN            NaN              NaN
# 1             NaN            NaN              NaN
# 2             NaN            NaN              NaN
# 3             NaN            NaN              NaN
# 4             NaN            NaN              NaN
# ...           ...            ...              ...
# 4108          NaN            NaN  Chickens (Meat)
# 4109          NaN            NaN  Chickens (Meat)
# 4110          NaN            NaN  Chickens (Meat)
# 4111          NaN            NaN  Chickens (Meat)
# 4112          NaN            NaN  Chickens (Meat)
#
# [4113 rows x 29 columns]

# %% [markdown]
# ### Visualizations of CAFOs
#
# Green markers indicate CAFOs that were found in both datasets, red markers were CAFOs only present in Counterglow, and blue markers were CAFOs only present in state permit data. Only farms with location provided could be plotted.

# %%
nc_map = map_state(matched_farms, unmatched_farms, "NC")
nc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a1a7ec77061e53e7d5d961ae105f766 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a1a7ec77061e53e7d5d961ae105f766&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a1a7ec77061e53e7d5d961ae105f766 = L.map(
#                 &quot;map_0a1a7ec77061e53e7d5d961ae105f766&quot;,
#                 {
#                     center: [35.7917213, -78.300188],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0a1a7ec77061e53e7d5d961ae105f766);
#
#
#
#
#
#             var tile_layer_ebf177409454b9a8a6c6958c09eab8ab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a1a7ec77061e53e7d5d961ae105f766);
#
#
#             var marker_d7df87312c4a4ee3ba86d6e99c73833d = L.marker(
#                 [35.182138, -80.276524],
#                 {}
#             ).addTo(map_0a1a7ec77061e53e7d5d961ae105f766);
#
#
#             var icon_ba2052f9f7e02b519b0879fd97d491c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d7df87312c4a4ee3ba86d6e99c73833d.setIcon(icon_ba2052f9f7e02b519b0879fd97d491c9);
#
#
#         var popup_74026669b64eda67df9b2f0018e829af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d920ce37ac8b65c6aaf1cd85f29fc6bb = $(`&lt;div id=&quot;html_d920ce37ac8b65c6aaf1cd85f29fc6bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FLINT RIDGE PULLET FARM&lt;/div&gt;`)[0];
#                 popup_74026669b64eda67df9b2f0018e829af.setContent(html_d920ce37ac8b65c6aaf1cd85f29fc6bb);
#
#
#
#         marker_d7df87312c4a4ee3ba86d6e99c73833d.bindPopup(popup_74026669b64eda67df9b2f0018e829af)
#         ;
#
#
#
#
#             var marker_2fb0e51388fc2adebff2cf68813a9e83 = L.marker(
#                 [36.0736, -78.1347],
#                 {}
#             ).addTo(map_0a1a7ec77061e53e7d5d961ae105f766);
#
#
#             var icon_4f1ba12eb3afe1553a15cfbaf4308f19 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2fb0e51388fc2adebff2cf68813a9e83.setIcon(icon_4f1ba12eb3afe1553a15cfbaf4308f19);
#
#
#         var popup_810f9615913b2fa8220b9906a206a73f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d7605e2d84f082427bbfd05d22d77f5 = $(`&lt;div id=&quot;html_5d7605e2d84f082427bbfd05d22d77f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GARDNER FARM POULTRY&lt;/div&gt;`)[0];
#                 popup_810f9615913b2fa8220b9906a206a73f.setContent(html_5d7605e2d84f082427bbfd05d22d77f5);
#
#
#
#         marker_2fb0e51388fc2adebff2cf68813a9e83.bindPopup(popup_810f9615913b2fa8220b9906a206a73f)
#         ;
#
#
#
#
#             var marker_0ba64971420305982915df3aede4e5b0 = L.marker(
#                 [35.6417, -76.525],
#                 {}
#             ).addTo(map_0a1a7ec77061e53e7d5d961ae105f766);
#
#
#             var icon_56f9273bf8f36a5d7f6ce79cff7a6771 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0ba64971420305982915df3aede4e5b0.setIcon(icon_56f9273bf8f36a5d7f6ce79cff7a6771);
#
#
#         var popup_b36d33d2a1f86fce231affab0f904594 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_038d92c335769885dfde6328f8e4bc8e = $(`&lt;div id=&quot;html_038d92c335769885dfde6328f8e4bc8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;HYDE COUNTY EGG FARM&lt;/div&gt;`)[0];
#                 popup_b36d33d2a1f86fce231affab0f904594.setContent(html_038d92c335769885dfde6328f8e4bc8e);
#
#
#
#         marker_0ba64971420305982915df3aede4e5b0.bindPopup(popup_b36d33d2a1f86fce231affab0f904594)
#         ;
#
#
#
#
#             var marker_3c00565a97c55f80856fe245c87de0ac = L.marker(
#                 [35.6417, -76.525],
#                 {}
#             ).addTo(map_0a1a7ec77061e53e7d5d961ae105f766);
#
#
#             var icon_621a472912220b1e6185cfa12b2ebda9 = L.AwesomeMarkers.icon(
