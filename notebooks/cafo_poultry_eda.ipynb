# %% [markdown]
# ### CAFO Poultry Plants EDA
#
# This notebook includes exploratory data analysis on and mapping of poultry plants in the state permits and Counterglow datasets.
#
# State permit data was obtained from individual state government websites, as CAFOs are usually regulated for environmental quality issues. As each state website formats their data differently, input columns were standardized in a farm_source config file for each dataset in the raw/cafo folder.
#
# The Counterglow dataset was obtained from Project Counterglow and contains crowdsourced data on the locations of CAFOs.

# %%
import pandas as pd
from pipeline.utils.visualize import map_state
from pipeline.constants import CLEANED_CAFO_POULTRY_FPATH, CLEANED_COUNTERGLOW_FPATH, MATCHED_FARMS_FPATH, UNMATCHED_FARMS_FPATH

# %%
permit_data_joined = pd.read_csv(CLEANED_CAFO_POULTRY_FPATH)
counterglow = pd.read_csv(CLEANED_COUNTERGLOW_FPATH)

permit_data_joined.head()
# Out:
#    Unnamed: 0                     name                        permit state  \
# 0           0             4D Farms LLC  General Permit - Poultry AFO    MS
# 1           1             4S Farms LLC  General Permit - Poultry AFO    MS
# 2           2  A B Westbrook Farms LLC  General Permit - Poultry AFO    MS
# 3           3          A and J Poultry  General Permit - Poultry AFO    MS
# 4           4     A and W Garner Farms  General Permit - Poultry AFO    MS
#
#                                             source address  lat  long
# 0  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 1  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 2  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 3  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 4  Mississippi Department of Environmental Quality     NaN  NaN   NaN

# %% [markdown]
# There are currently three states in the combined state permit dataset, but more can be added to the cafo folder for the clean_cafo function to process.

# %%
permit_data_joined['state'].unique()
# Out:
# array(['MS', 'NC', 'AL'], dtype=object)

# %%
no_loc = permit_data_joined['lat'].isnull().sum()
contains_loc = len(permit_data_joined) - no_loc

print(f"In the combined state permit dataset, there are {no_loc} entries with no longitude/latitude data and {contains_loc} entries with data.")
# Out:
# In the combined state permit dataset, there are 1415 entries with no longitude/latitude data and 20 entries with data.

# %%
counterglow.head()
# Out:
#    Unnamed: 0 Name   Latitude  Longitude  \
# 0           0   78  43.396729 -95.923149
# 1           1   84  42.925350 -96.429291
# 2           2   87  40.658218 -92.410202
# 3           3   88  40.643219 -92.409889
# 4           4   89  40.660851 -92.421219
#
#                                              Address City State        County  \
# 0       1757 Lily Avenue George 51237, United States  NaN    IA   Lyon County
# 1    1804 500th Street Hawarden 51023, United States  NaN    IA  Sioux County
# 2  21166 Mahogany Avenue Bloomfield 52537, United...  NaN    IA  Davis County
# 3  27268 Mahogany Avenue Bloomfield 52537, United...  NaN    IA  Davis County
# 4  21166 280th Street Bloomfield 52537, United St...  NaN    IA  Davis County
#
#    Description Business/company name  ... Phone number Region Facility name  \
# 0          NaN                   NaN  ...          NaN    NaN           NaN
# 1          NaN                   NaN  ...          NaN    NaN           NaN
# 2          NaN                   NaN  ...          NaN    NaN           NaN
# 3          NaN                   NaN  ...          NaN    NaN           NaN
# 4          NaN                   NaN  ...          NaN    NaN           NaN
#
#   Number of animals Full address Website URL  Postcode  Suburb/city  \
# 0               NaN          NaN         NaN       NaN          NaN
# 1               NaN          NaN         NaN       NaN          NaN
# 2               NaN          NaN         NaN       NaN          NaN
# 3               NaN          NaN         NaN       NaN          NaN
# 4               NaN          NaN         NaN       NaN          NaN
#
#   Contracted to    Farm Type
# 0           NaN  Pigs (Meat)
# 1           NaN  Pigs (Meat)
# 2           NaN  Pigs (Meat)
# 3           NaN  Pigs (Meat)
# 4           NaN  Pigs (Meat)
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Cleaning
#
# To clean these datasets, we matched poultry CAFOs by name and location (if provided) in the state permit dataset to CAFOs listed in the Counterglow dataset, while recording how fuzzy the match was (ie. whether it was a perfect name and location match or a fuzzy match). Both matched and unmatched farms are provided in separate files.

# %%
matched_farms = pd.read_csv(MATCHED_FARMS_FPATH)
unmatched_farms = pd.read_csv(UNMATCHED_FARMS_FPATH)

matched_farms.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                            name  \
# 0             9           9             ALAN YOUNG, POULTRY
# 1            16          16  ALLEN AND JONNI JONES, POULTRY
# 2            23          23          ANDY HOLTCAMP, POULTRY
# 3            29          29       ARNOLD OVERSTREET POULTRY
# 4            31          31        ARTIS R WINDHAM, POULTRY
#
#                          permit state  \
# 0  General Permit - Poultry AFO    MS
# 1  General Permit - Poultry AFO    MS
# 2  General Permit - Poultry AFO    MS
# 3  General Permit - Poultry AFO    MS
# 4  General Permit - Poultry AFO    MS
#
#                                             source address  lat  long  \
# 0  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 1  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 2  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 3  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 4  Mississippi Department of Environmental Quality     NaN  NaN   NaN
#
#             Exact Name Match                     Fuzzy Name  \
# 0                        NaN             ALAN YOUNG POULTRY
# 1                        NaN  ALLEN AND JONNI JONES POULTRY
# 2                        NaN          ANDY HOLTCAMP POULTRY
# 3  ARNOLD OVERSTREET POULTRY                            NaN
# 4                        NaN        ARTIS R WINDHAM POULTRY
#
#   Exact Name/Location  Fuzzy Name/Exact Location Location Match
# 0                 NaN                        NaN            NaN
# 1                 NaN                        NaN            NaN
# 2                 NaN                        NaN            NaN
# 3                 NaN                        NaN            NaN
# 4                 NaN                        NaN            NaN

# %%
unmatched_farms.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                     name  \
# 0             0           0             4D FARMS LLC
# 1             1           1             4S FARMS LLC
# 2             2           2  A B WESTBROOK FARMS LLC
# 3             3           3          A AND J POULTRY
# 4             4           4     A AND W GARNER FARMS
#
#                          permit state  \
# 0  General Permit - Poultry AFO    MS
# 1  General Permit - Poultry AFO    MS
# 2  General Permit - Poultry AFO    MS
# 3  General Permit - Poultry AFO    MS
# 4  General Permit - Poultry AFO    MS
#
#                                             source address  lat  long  \
# 0  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 1  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 2  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 3  Mississippi Department of Environmental Quality     NaN  NaN   NaN
# 4  Mississippi Department of Environmental Quality     NaN  NaN   NaN
#
#    Exact Name Match  ...  Phone number  Region  Facility name  \
# 0               NaN  ...           NaN     NaN            NaN
# 1               NaN  ...           NaN     NaN            NaN
# 2               NaN  ...           NaN     NaN            NaN
# 3               NaN  ...           NaN     NaN            NaN
# 4               NaN  ...           NaN     NaN            NaN
#
#    Number of animals Full address Website URL  Postcode  Suburb/city  \
# 0                NaN          NaN         NaN       NaN          NaN
# 1                NaN          NaN         NaN       NaN          NaN
# 2                NaN          NaN         NaN       NaN          NaN
# 3                NaN          NaN         NaN       NaN          NaN
# 4                NaN          NaN         NaN       NaN          NaN
#
#    Contracted to Farm Type
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Visualizations of CAFOs
#
# Green markers indicate CAFOs that were found in both datasets, red markers were CAFOs only present in Counterglow, and blue markers were CAFOs only present in state permit data. Only farms with longitude and latitude coordinates provided were plotted. All maps are saved in HTML format in the data/html folder after running main.py.

# %%
nc_map = map_state(MATCHED_FARMS_FPATH, UNMATCHED_FARMS_FPATH, "NC")
nc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8cb446622baf59a7d6d841081510de9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8cb446622baf59a7d6d841081510de9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8cb446622baf59a7d6d841081510de9 = L.map(
#                 &quot;map_e8cb446622baf59a7d6d841081510de9&quot;,
#                 {
#                     center: [35.7917213, -78.300188],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e8cb446622baf59a7d6d841081510de9);
#
#
#
#
#
#             var tile_layer_2a303b0a4cd1cb081578d4a881c3f967 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e8cb446622baf59a7d6d841081510de9);
#
#
#             var marker_e0b4a8a5de284a12ecdbcd925009d324 = L.marker(
#                 [35.182138, -80.276524],
#                 {}
#             ).addTo(map_e8cb446622baf59a7d6d841081510de9);
#
#
#             var icon_e9825d30b9724ed2530a486f5ce1e6da = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0b4a8a5de284a12ecdbcd925009d324.setIcon(icon_e9825d30b9724ed2530a486f5ce1e6da);
#
#
#         var popup_85471872f28578620197faa56787748c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2609c2fdfdf6dc935e044566bfed9257 = $(`&lt;div id=&quot;html_2609c2fdfdf6dc935e044566bfed9257&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;FLINT RIDGE PULLET FARM&lt;/div&gt;`)[0];
#                 popup_85471872f28578620197faa56787748c.setContent(html_2609c2fdfdf6dc935e044566bfed9257);
#
#
#
#         marker_e0b4a8a5de284a12ecdbcd925009d324.bindPopup(popup_85471872f28578620197faa56787748c)
#         ;
#
#
#
#
#             var marker_8a26a0debe6c182914adecd912ac593e = L.marker(
#                 [36.0736, -78.1347],
#                 {}
#             ).addTo(map_e8cb446622baf59a7d6d841081510de9);
#
#
#             var icon_bd6b0eac55ae808e1a052d89ea1a1a03 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8a26a0debe6c182914adecd912ac593e.setIcon(icon_bd6b0eac55ae808e1a052d89ea1a1a03);
#
#
#         var popup_28560a0bd3668e6911ad26250f96cd5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f02bfc0e9fb920ec6e6114009faf52f0 = $(`&lt;div id=&quot;html_f02bfc0e9fb920ec6e6114009faf52f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GARDNER FARM POULTRY&lt;/div&gt;`)[0];
#                 popup_28560a0bd3668e6911ad26250f96cd5a.setContent(html_f02bfc0e9fb920ec6e6114009faf52f0);
#
#
#
#         marker_8a26a0debe6c182914adecd912ac593e.bindPopup(popup_28560a0bd3668e6911ad26250f96cd5a)
#         ;
#
#
#
#
#             var marker_7ad7ecd537a605a26d3df8ed2fef4ff3 = L.marker(
#                 [35.6417, -76.525],
#                 {}
#             ).addTo(map_e8cb446622baf59a7d6d841081510de9);
#
#
#             var icon_0e8fb46366ee01ae15780b472e9fb2cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ad7ecd537a605a26d3df8ed2fef4ff3.setIcon(icon_0e8fb46366ee01ae15780b472e9fb2cc);
#
#
#         var popup_129070f291cb0ea8e6000ba3dc1db678 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_411ea12b02f7219b7ada9c959e6c2bf0 = $(`&lt;div id=&quot;html_411ea12b02f7219b7ada9c959e6c2bf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;HYDE COUNTY EGG FARM&lt;/div&gt;`)[0];
#                 popup_129070f291cb0ea8e6000ba3dc1db678.setContent(html_411ea12b02f7219b7ada9c959e6c2bf0);
#
#
#
#         marker_7ad7ecd537a605a26d3df8ed2fef4ff3.bindPopup(popup_129070f291cb0ea8e6000ba3dc1db678)
#         ;
#
#
#
#
#             var marker_110c9dd98ff48e7de4883f8963c07821 = L.marker(
#                 [35.6417, -76.525],
#                 {}
#             ).addTo(map_e8cb446622baf59a7d6d841081510de9);
#
#
#             var icon_75ffe1f179c7556246254976bbf8a035 = L.AwesomeMarkers.icon(
