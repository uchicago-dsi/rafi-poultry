# %% [markdown]
# ## Load-In Data

# %%
import pandas as pd
import numpy as np
import folium
import geopandas as gpd

# %%
master_df = pd.read_csv("/Users/abby/Desktop/RAFI/master-df.csv")
master_df = master_df.dropna(subset=['LONGITUDE', 'LATITUDE', 'COMPANY'])
arkansas = master_df.loc[master_df.STATE == 'AR']
arkansas.drop(columns=['Unnamed: 0']).head(5)
# Out:
#               COMPANY       ADDRESS LINE 1       CITY STATE  ZIPCODE  \
# 8   SIMMONS FOODS INC  2101 TWIN CIRCLE DR  VAN BUREN    AR  72956.0
# 9   SIMMONS FOODS INC  2101 TWIN CIRCLE DR  VAN BUREN    AR  72956.0
# 10  SIMMONS FOODS INC  2101 TWIN CIRCLE DR  VAN BUREN    AR  72956.0
# 11  SIMMONS FOODS INC  2101 TWIN CIRCLE DR  VAN BUREN    AR  72956.0
# 12  SIMMONS FOODS INC  2101 TWIN CIRCLE DR  VAN BUREN    AR  72956.0
#
#     PRIMARY SIC CODE  ARCHIVE VERSION YEAR  YEAR ESTABLISHED        ABI  \
# 8           201501.0                  2022               NaN  512247248
# 9           201501.0                  2021               NaN  512247248
# 10          201501.0                  2020               NaN  512247248
# 11          201501.0                  2019               NaN  512247248
# 12          201501.0                  2018               NaN  512247248
#
#     PARENT NUMBER   LATITUDE  LONGITUDE  YEAR 1ST APPEARED        PARENT NAME  \
# 8       7534076.0  35.428061 -94.336725                NaN  Simmons Foods Inc
# 9       7534076.0  35.428061 -94.336725             1999.0  Simmons Foods Inc
# 10      7534076.0  35.428061 -94.336725                NaN  Simmons Foods Inc
# 11      7534076.0  35.428061 -94.336725                NaN  Simmons Foods Inc
# 12      7534076.0  35.428061 -94.336725                NaN  Simmons Foods Inc
#
#    CHANGE_BOOL  CHANGE_NUM
# 8         None         1.0
# 9         None         1.0
# 10        None         1.0
# 11        None         1.0
# 12        None         1.0

# %%
arkansas.isnull().sum()
# Out:
# Unnamed: 0                 0
# COMPANY                    0
# ADDRESS LINE 1            25
# CITY                       0
# STATE                      0
# ZIPCODE                    0
# PRIMARY SIC CODE           0
# ARCHIVE VERSION YEAR       0
# YEAR ESTABLISHED         953
# ABI                        0
# PARENT NUMBER            386
# LATITUDE                   0
# LONGITUDE                  0
# YEAR 1ST APPEARED       1561
# PARENT NAME                0
# CHANGE_BOOL                0
# CHANGE_NUM                 0
# dtype: int64

# %% [markdown]
# ## Separate by Years

# %%
df_2022 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2022].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2021 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2021].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2020 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2020].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2019 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2019].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2018 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2018].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2017 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2017].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2016 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2016].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2015 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2015].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2014 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2014].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2013 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2013].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2012 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2012].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2011 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2011].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2010 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2010].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2009 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2009].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2008 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2008].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2007 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2007].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2006 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2006].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2005 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2005].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2004 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2004].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2003 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2003].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2002 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2002].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2001 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2001].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_2000 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 2000].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_1999 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 1999].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_1998 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 1998].reset_index(drop=True).drop(columns=['Unnamed: 0'])
df_1997 = arkansas.loc[arkansas['ARCHIVE VERSION YEAR'] == 1997].reset_index(drop=True).drop(columns=['Unnamed: 0'])

# %%
df_2022.head(10)
# Out:
#                   COMPANY         ADDRESS LINE 1            CITY STATE  \
# 0       SIMMONS FOODS INC    2101 TWIN CIRCLE DR       VAN BUREN    AR
# 1         TYSON FOODS INC           620 TYLER RD    RUSSELLVILLE    AR
# 2       SIMMONS FOODS INC    814 S WASHINGTON ST  SILOAM SPRINGS    AR
# 3          PECO FOODS INC           625 ALLEN ST      BATESVILLE    AR
# 4         TYSON FOODS INC           601 TYSON DR    GREEN FOREST    AR
# 5                BRUSS CO  2200 W DON TYSON PKWY      SPRINGDALE    AR
# 6         TYSON FOODS INC                    NaN     CLARKSVILLE    AR
# 7         TYSON FOODS INC          702 E MAIN ST    RUSSELLVILLE    AR
# 8  OZARK MOUNTAIN POULTRY       9022 HARRISON ST      BATESVILLE    AR
# 9         WAYNE FARMS LLC          2301 E 8TH ST        DANVILLE    AR
#
#    ZIPCODE  PRIMARY SIC CODE  ARCHIVE VERSION YEAR  YEAR ESTABLISHED  \
# 0  72956.0          201501.0                  2022               NaN
# 1  72802.0          514704.0                  2022               NaN
# 2  72761.0          201501.0                  2022            1949.0
# 3  72501.0           25401.0                  2022            1891.0
# 4  72638.0          514704.0                  2022            1967.0
# 5  72762.0          201501.0                  2022            1935.0
# 6  72830.0           25401.0                  2022               NaN
# 7  72801.0           25401.0                  2022               NaN
# 8  72501.0          201501.0                  2022               NaN
# 9  72833.0          201501.0                  2022               NaN
#
#          ABI  PARENT NUMBER   LATITUDE  LONGITUDE  YEAR 1ST APPEARED  \
# 0  512247248      7534076.0  35.428061 -94.336725                NaN
# 1  382158996      7537913.0  35.269775 -93.085968                NaN
# 2  712259047      7534076.0  36.177236 -94.537565                NaN
# 3  403318413    531052413.0  35.764666 -91.648842                NaN
# 4    9435439      7537913.0  36.331154 -93.429489                NaN
# 5  712252656      7537913.0  36.154021 -94.154599                NaN
# 6  427795881      7537913.0  35.490400 -93.482300                NaN
# 7  439121994      7537913.0  35.277468 -93.123781                NaN
# 8  718225944            NaN  35.703198 -91.475651                NaN
# 9  379566995    433353331.0  35.055283 -93.368973                NaN
#
#             PARENT NAME CHANGE_BOOL  CHANGE_NUM
# 0     Simmons Foods Inc        None         1.0
# 1       Tyson Foods Inc       False         0.0
# 2     Simmons Foods Inc       False         0.0
# 3        Peco Foods Inc        None         1.0
# 4       Tyson Foods Inc       False         0.0
# 5       Tyson Foods Inc       False         0.0
# 6       Tyson Foods Inc       False         0.0
# 7       Tyson Foods Inc       False         0.0
# 8                  None       False         0.0
# 9  Continental Grain Co        None         1.0

# %% [markdown]
# ## Making the USA

# %%
AR_LAT = 35.2010
AR_LNG = -91.8318
m = folium.Map(location=[AR_LAT, AR_LNG],zoom_start=7)

# %%
arkansas['PARENT NAME'].value_counts()
# Out:
# Tyson Foods Inc         660
# None                    492
# JBS USA                  89
# Cargil Inc               78
# George's Inc             60
# Simmons Foods Inc        56
# Small Biz                51
# Continental Grain Co     27
# Conagra Brands Inc       27
# Mountaire Corp           24
# Cal-main Foods Inc       23
# Pilgrim's Pride Corp     23
# Peco Foods Inc           12
# Foster Farms              8
# Name: PARENT NAME, dtype: int64

# %%
col_dict = dict({'None': 'blue', 
                "Tyson Foods Inc": 'green', 
                "Simmons Foods Inc": 'red', 
                "George's Inc": 'purple', 
                "JBS USA": 'orange', 
                "Cargil Inc": 'darkblue',
                "Small Biz": 'beige',
                "Foster Farms": 'gray',
                "Conagra Brands Inc": 'lightgreen',
                "Peco Foods Inc": 'black',
                "Continental Grain Co": 'darkred',
                "Mountaire Corp": 'white',
                "Pilgrim's Pride Corp": 'pink',
                "Cal-main Foods Inc": 'lightgray'})

# %%
df_2022['COLOR'] = df_2022['PARENT NAME'].map(col_dict)
df_2022.head(3)
# Out:
#              COMPANY       ADDRESS LINE 1            CITY STATE  ZIPCODE  \
# 0  SIMMONS FOODS INC  2101 TWIN CIRCLE DR       VAN BUREN    AR  72956.0
# 1    TYSON FOODS INC         620 TYLER RD    RUSSELLVILLE    AR  72802.0
# 2  SIMMONS FOODS INC  814 S WASHINGTON ST  SILOAM SPRINGS    AR  72761.0
#
#    PRIMARY SIC CODE  ARCHIVE VERSION YEAR  YEAR ESTABLISHED        ABI  \
# 0          201501.0                  2022               NaN  512247248
# 1          514704.0                  2022               NaN  382158996
# 2          201501.0                  2022            1949.0  712259047
#
#    PARENT NUMBER   LATITUDE  LONGITUDE  YEAR 1ST APPEARED        PARENT NAME  \
# 0      7534076.0  35.428061 -94.336725                NaN  Simmons Foods Inc
# 1      7537913.0  35.269775 -93.085968                NaN    Tyson Foods Inc
# 2      7534076.0  36.177236 -94.537565                NaN  Simmons Foods Inc
#
#   CHANGE_BOOL  CHANGE_NUM  COLOR
# 0        None         1.0    red
# 1       False         0.0  green
# 2       False         0.0    red

# %%
def make_map(df, map_name):
    map_name = folium.Map(location=[AR_LAT, AR_LNG],zoom_start=6)
    
    df['COLOR'] = df['PARENT NAME'].map(col_dict)

    for index, location_info in df.iterrows():
        folium.Marker([location_info["LATITUDE"], location_info["LONGITUDE"]], popup = location_info['PARENT NAME'],
                icon=folium.Icon(color=location_info['COLOR'])).add_to(map_name)
        
    display(map_name)

# %%
make_map(df_2022, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f5469529ee6fc65c3c4a4a46c9c89d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f5469529ee6fc65c3c4a4a46c9c89d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f5469529ee6fc65c3c4a4a46c9c89d0 = L.map(
#                 &quot;map_0f5469529ee6fc65c3c4a4a46c9c89d0&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1eed8c3623c91374b087dd7435d374eb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0f5469529ee6fc65c3c4a4a46c9c89d0);
#
#
#             var marker_463164083fcf14a91db76f8ffd4b597b = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_0f5469529ee6fc65c3c4a4a46c9c89d0);
#
#
#             var icon_6d19aa0aa1b8b53f6d50c5c4ac96e5bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_463164083fcf14a91db76f8ffd4b597b.setIcon(icon_6d19aa0aa1b8b53f6d50c5c4ac96e5bc);
#
#
#         var popup_3613bbbe80bce9eb92bf335d438c8369 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9b98943cee68d1484243ea21efcba3c = $(`&lt;div id=&quot;html_e9b98943cee68d1484243ea21efcba3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_3613bbbe80bce9eb92bf335d438c8369.setContent(html_e9b98943cee68d1484243ea21efcba3c);
#
#
#
#         marker_463164083fcf14a91db76f8ffd4b597b.bindPopup(popup_3613bbbe80bce9eb92bf335d438c8369)
#         ;
#
#
#
#
#             var marker_9a5d71cf343f7515631e19f5127ae2a6 = L.marker(
#                 [35.269775, -93.085968],
#                 {}
#             ).addTo(map_0f5469529ee6fc65c3c4a4a46c9c89d0);
#
#
#             var icon_d41b1b08a12619c8bd873b765f2c8edf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a5d71cf343f7515631e19f5127ae2a6.setIcon(icon_d41b1b08a12619c8bd873b765f2c8edf);
#
#
#         var popup_2396883be246fc7d37e45ce8a55e4ca7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89c4d9ab21293763957179301e139434 = $(`&lt;div id=&quot;html_89c4d9ab21293763957179301e139434&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_2396883be246fc7d37e45ce8a55e4ca7.setContent(html_89c4d9ab21293763957179301e139434);
#
#
#
#         marker_9a5d71cf343f7515631e19f5127ae2a6.bindPopup(popup_2396883be246fc7d37e45ce8a55e4ca7)
#         ;
#
#
#
#
#             var marker_1ed27fb52e90a06b8a7e57b846622eb3 = L.marker(
#                 [36.177236, -94.537565],
#                 {}
#             ).addTo(map_0f5469529ee6fc65c3c4a4a46c9c89d0);
#
#
#             var icon_47ce9de845677ee5daf3b3d47dfda611 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1ed27fb52e90a06b8a7e57b846622eb3.setIcon(icon_47ce9de845677ee5daf3b3d47dfda611);
#
#
#         var popup_e19a2451913b6e1fbe8be21bd5c79ab4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9952d82e9459182dde9bfa9dd6098aef = $(`&lt;div id=&quot;html_9952d82e9459182dde9bfa9dd6098aef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_e19a2451913b6e1fbe8be21bd5c79ab4.setContent(html_9952d82e9459182dde9bfa9dd6098aef);
#
#
#
#         marker_1ed27fb52e90a06b8a7e57b846622eb3.bindPopup(popup_e19a2451913b6e1fbe8be21bd5c79ab4)
#         ;
#
#
#
#
#             var marker_08f4854d2cc5fc7196bb3d46dd01f567 = L.marker(
#                 [35.764666, -91.648842],
#                 {}
#             ).addTo(map_0f5469529ee6fc65c3c4a4a46c9c89d0);
#
#
#             var icon_443ce3325207e09cf253a5ea1d5d9fcc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:

# %%
make_map(df_2021, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b7a9aba5d9962b1d303df2db2716b1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b7a9aba5d9962b1d303df2db2716b1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b7a9aba5d9962b1d303df2db2716b1d = L.map(
#                 &quot;map_0b7a9aba5d9962b1d303df2db2716b1d&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c9f74db47e133daad538ccf0247464e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b7a9aba5d9962b1d303df2db2716b1d);
#
#
#             var marker_c3890bd68db544dc1de630417a27a785 = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_0b7a9aba5d9962b1d303df2db2716b1d);
#
#
#             var icon_cc3ba25b53b87a78ad313c182ee40bd3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3890bd68db544dc1de630417a27a785.setIcon(icon_cc3ba25b53b87a78ad313c182ee40bd3);
#
#
#         var popup_9c4bc4e03d88db88bbe4d6d1e2335f67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4bbecd438fc504478131a341feabfd94 = $(`&lt;div id=&quot;html_4bbecd438fc504478131a341feabfd94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_9c4bc4e03d88db88bbe4d6d1e2335f67.setContent(html_4bbecd438fc504478131a341feabfd94);
#
#
#
#         marker_c3890bd68db544dc1de630417a27a785.bindPopup(popup_9c4bc4e03d88db88bbe4d6d1e2335f67)
#         ;
#
#
#
#
#             var marker_e100a94f17579a8dc4c93582a8f5442a = L.marker(
#                 [35.269775, -93.085968],
#                 {}
#             ).addTo(map_0b7a9aba5d9962b1d303df2db2716b1d);
#
#
#             var icon_e95611e48842b9b3c6bb674cc660be7e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e100a94f17579a8dc4c93582a8f5442a.setIcon(icon_e95611e48842b9b3c6bb674cc660be7e);
#
#
#         var popup_24c586921f39c227dd0c5a597cf060c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_049f1e3bb460c61341725538609c1db4 = $(`&lt;div id=&quot;html_049f1e3bb460c61341725538609c1db4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_24c586921f39c227dd0c5a597cf060c1.setContent(html_049f1e3bb460c61341725538609c1db4);
#
#
#
#         marker_e100a94f17579a8dc4c93582a8f5442a.bindPopup(popup_24c586921f39c227dd0c5a597cf060c1)
#         ;
#
#
#
#
#             var marker_2ce652edb1079b9e2077a2e244b64e8f = L.marker(
#                 [36.177236, -94.537565],
#                 {}
#             ).addTo(map_0b7a9aba5d9962b1d303df2db2716b1d);
#
#
#             var icon_339985676a520ffab48d8a4dae1331ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2ce652edb1079b9e2077a2e244b64e8f.setIcon(icon_339985676a520ffab48d8a4dae1331ce);
#
#
#         var popup_62f29d6eb3ae923e34a9e944f2dd62ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0068aadbd6fa61f0df04498cb7678406 = $(`&lt;div id=&quot;html_0068aadbd6fa61f0df04498cb7678406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_62f29d6eb3ae923e34a9e944f2dd62ea.setContent(html_0068aadbd6fa61f0df04498cb7678406);
#
#
#
#         marker_2ce652edb1079b9e2077a2e244b64e8f.bindPopup(popup_62f29d6eb3ae923e34a9e944f2dd62ea)
#         ;
#
#
#
#
#             var marker_4804cd1dd09181d615bbd601699e8a9c = L.marker(
#                 [35.764666, -91.648842],
#                 {}
#             ).addTo(map_0b7a9aba5d9962b1d303df2db2716b1d);
#
#
#             var icon_5e1a51882777327530eb4fc4599e82ff = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:

# %%
make_map(df_2020, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd85b01e6379b4e8b2bf2d284e6d6b73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd85b01e6379b4e8b2bf2d284e6d6b73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd85b01e6379b4e8b2bf2d284e6d6b73 = L.map(
#                 &quot;map_dd85b01e6379b4e8b2bf2d284e6d6b73&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f082ae33ac7214222ba6d58fbe4486b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dd85b01e6379b4e8b2bf2d284e6d6b73);
#
#
#             var marker_1ece2afa401a5f853b8b68c211e43118 = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_dd85b01e6379b4e8b2bf2d284e6d6b73);
#
#
#             var icon_47dffa50799dfb6e31c4cd97d0599e70 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1ece2afa401a5f853b8b68c211e43118.setIcon(icon_47dffa50799dfb6e31c4cd97d0599e70);
#
#
#         var popup_8659712d59f9c8482bbde57ddf5a03a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a18fef98a5b4281baf309603c98a328 = $(`&lt;div id=&quot;html_7a18fef98a5b4281baf309603c98a328&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_8659712d59f9c8482bbde57ddf5a03a1.setContent(html_7a18fef98a5b4281baf309603c98a328);
#
#
#
#         marker_1ece2afa401a5f853b8b68c211e43118.bindPopup(popup_8659712d59f9c8482bbde57ddf5a03a1)
#         ;
#
#
#
#
#             var marker_e419e562b9a95e33892cc7c2b5526db5 = L.marker(
#                 [35.269775, -93.085968],
#                 {}
#             ).addTo(map_dd85b01e6379b4e8b2bf2d284e6d6b73);
#
#
#             var icon_7efca0ef6abaa54e85171f58044ed577 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e419e562b9a95e33892cc7c2b5526db5.setIcon(icon_7efca0ef6abaa54e85171f58044ed577);
#
#
#         var popup_db58bf120c6c2b8aad1235ef0dfbff50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_017ac35a1d008e0e88f8551b31fdb3e0 = $(`&lt;div id=&quot;html_017ac35a1d008e0e88f8551b31fdb3e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_db58bf120c6c2b8aad1235ef0dfbff50.setContent(html_017ac35a1d008e0e88f8551b31fdb3e0);
#
#
#
#         marker_e419e562b9a95e33892cc7c2b5526db5.bindPopup(popup_db58bf120c6c2b8aad1235ef0dfbff50)
#         ;
#
#
#
#
#             var marker_a3b1fb0759a29487cb72e61d80b98a4a = L.marker(
#                 [36.177236, -94.537565],
#                 {}
#             ).addTo(map_dd85b01e6379b4e8b2bf2d284e6d6b73);
#
#
#             var icon_a447aa22d91afa58d0019eaeacd2711b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a3b1fb0759a29487cb72e61d80b98a4a.setIcon(icon_a447aa22d91afa58d0019eaeacd2711b);
#
#
#         var popup_e2afe940be8e5008542127a97da6ac66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e3076a58cf93709c6b0280e177671c1 = $(`&lt;div id=&quot;html_7e3076a58cf93709c6b0280e177671c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_e2afe940be8e5008542127a97da6ac66.setContent(html_7e3076a58cf93709c6b0280e177671c1);
#
#
#
#         marker_a3b1fb0759a29487cb72e61d80b98a4a.bindPopup(popup_e2afe940be8e5008542127a97da6ac66)
#         ;
#
#
#
#
#             var marker_33b8b32af48623db432148b87f2219f8 = L.marker(
#                 [35.764666, -91.648842],
#                 {}
#             ).addTo(map_dd85b01e6379b4e8b2bf2d284e6d6b73);
#
#
#             var icon_2d255425f5328f3355e4175058472bc8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:

# %%
make_map(df_2019, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10bbcd04f5f088ec885ba9c6c5355a91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10bbcd04f5f088ec885ba9c6c5355a91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10bbcd04f5f088ec885ba9c6c5355a91 = L.map(
#                 &quot;map_10bbcd04f5f088ec885ba9c6c5355a91&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1144222440b7cd9ae44df5209c753fd6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_10bbcd04f5f088ec885ba9c6c5355a91);
#
#
#             var marker_8fba6be0f9f4b7bb62777660f6b594f8 = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_10bbcd04f5f088ec885ba9c6c5355a91);
#
#
#             var icon_7142923ea72b9e254a787c1954b1fd10 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8fba6be0f9f4b7bb62777660f6b594f8.setIcon(icon_7142923ea72b9e254a787c1954b1fd10);
#
#
#         var popup_55c0657acabde622b038ee19b7dfb71c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21d8cd901da841d69a011a6eb61201af = $(`&lt;div id=&quot;html_21d8cd901da841d69a011a6eb61201af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_55c0657acabde622b038ee19b7dfb71c.setContent(html_21d8cd901da841d69a011a6eb61201af);
#
#
#
#         marker_8fba6be0f9f4b7bb62777660f6b594f8.bindPopup(popup_55c0657acabde622b038ee19b7dfb71c)
#         ;
#
#
#
#
#             var marker_c0814afc399d20422f49f217b9ba15fd = L.marker(
#                 [35.269776, -93.085968],
#                 {}
#             ).addTo(map_10bbcd04f5f088ec885ba9c6c5355a91);
#
#
#             var icon_bf0482114ff932fbd6db4175d21d5b1a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0814afc399d20422f49f217b9ba15fd.setIcon(icon_bf0482114ff932fbd6db4175d21d5b1a);
#
#
#         var popup_5c69768507464d789e27991967e89796 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e5564f92af2bf23230357d4b7601793 = $(`&lt;div id=&quot;html_2e5564f92af2bf23230357d4b7601793&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_5c69768507464d789e27991967e89796.setContent(html_2e5564f92af2bf23230357d4b7601793);
#
#
#
#         marker_c0814afc399d20422f49f217b9ba15fd.bindPopup(popup_5c69768507464d789e27991967e89796)
#         ;
#
#
#
#
#             var marker_b33438fd57e14c6b03d11fd532dd0a69 = L.marker(
#                 [35.764666, -91.648842],
#                 {}
#             ).addTo(map_10bbcd04f5f088ec885ba9c6c5355a91);
#
#
#             var icon_04a4b417994564691791e2dda8a85896 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b33438fd57e14c6b03d11fd532dd0a69.setIcon(icon_04a4b417994564691791e2dda8a85896);
#
#
#         var popup_0f88bf5a6965a163de95666f21c0802e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5fb3a6f14a81718d12f3227487dd91f3 = $(`&lt;div id=&quot;html_5fb3a6f14a81718d12f3227487dd91f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_0f88bf5a6965a163de95666f21c0802e.setContent(html_5fb3a6f14a81718d12f3227487dd91f3);
#
#
#
#         marker_b33438fd57e14c6b03d11fd532dd0a69.bindPopup(popup_0f88bf5a6965a163de95666f21c0802e)
#         ;
#
#
#
#
#             var marker_10ee2bfa8631cfedda8ebe96dcd99c47 = L.marker(
#                 [36.33113, -93.42862],
#                 {}
#             ).addTo(map_10bbcd04f5f088ec885ba9c6c5355a91);
#
#
#             var icon_668a520122b1225c8ca7b622fea7c694 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sig

# %%
make_map(df_2018, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1166a549f054c474f2e5e1a41034306e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1166a549f054c474f2e5e1a41034306e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1166a549f054c474f2e5e1a41034306e = L.map(
#                 &quot;map_1166a549f054c474f2e5e1a41034306e&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff9d4cb2548d06e4c25ea3f1317f8324 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1166a549f054c474f2e5e1a41034306e);
#
#
#             var marker_875011a5afa2cab9f86a283a4f2073ed = L.marker(
#                 [35.428061, -94.336725],
#                 {}
#             ).addTo(map_1166a549f054c474f2e5e1a41034306e);
#
#
#             var icon_4dfc1df5369293212ce3b267926d3881 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_875011a5afa2cab9f86a283a4f2073ed.setIcon(icon_4dfc1df5369293212ce3b267926d3881);
#
#
#         var popup_c55296bce56bce0975c9fefd07d753c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70e694b59a70f5ce944e49ea2ae3fae7 = $(`&lt;div id=&quot;html_70e694b59a70f5ce944e49ea2ae3fae7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_c55296bce56bce0975c9fefd07d753c9.setContent(html_70e694b59a70f5ce944e49ea2ae3fae7);
#
#
#
#         marker_875011a5afa2cab9f86a283a4f2073ed.bindPopup(popup_c55296bce56bce0975c9fefd07d753c9)
#         ;
#
#
#
#
#             var marker_5e090633c744f04b68ac147936b2eaf2 = L.marker(
#                 [35.269776, -93.085968],
#                 {}
#             ).addTo(map_1166a549f054c474f2e5e1a41034306e);
#
#
#             var icon_cc883b0b23b895349abb0f60b02149b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5e090633c744f04b68ac147936b2eaf2.setIcon(icon_cc883b0b23b895349abb0f60b02149b1);
#
#
#         var popup_6e25ab0a885216bce3a1437601cec553 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b779f9c83164c512ed6e5dc3f5f36a4 = $(`&lt;div id=&quot;html_5b779f9c83164c512ed6e5dc3f5f36a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_6e25ab0a885216bce3a1437601cec553.setContent(html_5b779f9c83164c512ed6e5dc3f5f36a4);
#
#
#
#         marker_5e090633c744f04b68ac147936b2eaf2.bindPopup(popup_6e25ab0a885216bce3a1437601cec553)
#         ;
#
#
#
#
#             var marker_ca33e1415f05b1b89ed5742d1acc96f5 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_1166a549f054c474f2e5e1a41034306e);
#
#
#             var icon_b0e31b194ecf89b1d540ce325ed06002 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca33e1415f05b1b89ed5742d1acc96f5.setIcon(icon_b0e31b194ecf89b1d540ce325ed06002);
#
#
#         var popup_2210a85a22808e634923517bdbdc4e39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc4447cf6254345fb99865410a24a8df = $(`&lt;div id=&quot;html_bc4447cf6254345fb99865410a24a8df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_2210a85a22808e634923517bdbdc4e39.setContent(html_bc4447cf6254345fb99865410a24a8df);
#
#
#
#         marker_ca33e1415f05b1b89ed5742d1acc96f5.bindPopup(popup_2210a85a22808e634923517bdbdc4e39)
#         ;
#
#
#
#
#             var marker_5ac949cce3976756fb6aeb393ab778fa = L.marker(
#                 [36.331155, -93.429488],
#                 {}
#             ).addTo(map_1166a549f054c474f2e5e1a41034306e);
#
#
#             var icon_a6061bde0b716deb11dfe31c3be8d966 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sig

# %%
make_map(df_2017, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac85e688966f323d17e12dd8f2ecf5d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac85e688966f323d17e12dd8f2ecf5d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac85e688966f323d17e12dd8f2ecf5d0 = L.map(
#                 &quot;map_ac85e688966f323d17e12dd8f2ecf5d0&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4dd1fa228065aecec24f1d80f5289b62 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ac85e688966f323d17e12dd8f2ecf5d0);
#
#
#             var marker_40b161e35a8faabe864ffbd3654d2613 = L.marker(
#                 [35.428048, -94.33674],
#                 {}
#             ).addTo(map_ac85e688966f323d17e12dd8f2ecf5d0);
#
#
#             var icon_278927b833c87d48852e439d6ce3d7ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_40b161e35a8faabe864ffbd3654d2613.setIcon(icon_278927b833c87d48852e439d6ce3d7ed);
#
#
#         var popup_3d4a76e7ba84e89485def35f2a141f41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_392e747ae9a269efb1378dc2325bd576 = $(`&lt;div id=&quot;html_392e747ae9a269efb1378dc2325bd576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_3d4a76e7ba84e89485def35f2a141f41.setContent(html_392e747ae9a269efb1378dc2325bd576);
#
#
#
#         marker_40b161e35a8faabe864ffbd3654d2613.bindPopup(popup_3d4a76e7ba84e89485def35f2a141f41)
#         ;
#
#
#
#
#             var marker_d890c5b5fbc3dd72c899dd28c49d6598 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_ac85e688966f323d17e12dd8f2ecf5d0);
#
#
#             var icon_f7ec4c0b9127df8107b556dec10e6e82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d890c5b5fbc3dd72c899dd28c49d6598.setIcon(icon_f7ec4c0b9127df8107b556dec10e6e82);
#
#
#         var popup_88d5b80d14daaa230b2266f1ed706f3f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ff5b7c3f6c12b9b1d6a24b3e606f060 = $(`&lt;div id=&quot;html_9ff5b7c3f6c12b9b1d6a24b3e606f060&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_88d5b80d14daaa230b2266f1ed706f3f.setContent(html_9ff5b7c3f6c12b9b1d6a24b3e606f060);
#
#
#
#         marker_d890c5b5fbc3dd72c899dd28c49d6598.bindPopup(popup_88d5b80d14daaa230b2266f1ed706f3f)
#         ;
#
#
#
#
#             var marker_e34d95ed9baa8f6f4be97bfa5eac1f2d = L.marker(
#                 [35.703198, -91.475651],
#                 {}
#             ).addTo(map_ac85e688966f323d17e12dd8f2ecf5d0);
#
#
#             var icon_7c40ad4a249df53a02fe92e48c35865f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e34d95ed9baa8f6f4be97bfa5eac1f2d.setIcon(icon_7c40ad4a249df53a02fe92e48c35865f);
#
#
#         var popup_cb616656f9dabbf0de1d5a61eac4df0c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6452e9038a4800539bb8730e6617af4e = $(`&lt;div id=&quot;html_6452e9038a4800539bb8730e6617af4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_cb616656f9dabbf0de1d5a61eac4df0c.setContent(html_6452e9038a4800539bb8730e6617af4e);
#
#
#
#         marker_e34d95ed9baa8f6f4be97bfa5eac1f2d.bindPopup(popup_cb616656f9dabbf0de1d5a61eac4df0c)
#         ;
#
#
#
#
#             var marker_0a9b6923205b2d5fb7a62aa3b2d27882 = L.marker(
#                 [35.05528, -93.36897],
#                 {}
#             ).addTo(map_ac85e688966f323d17e12dd8f2ecf5d0);
#
#
#             var icon_ea6224fdc345c0761e2223c9c27ee93a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&qu

# %%
make_map(df_2016, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0539912f5176bac976c5b2d0a60b7cce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0539912f5176bac976c5b2d0a60b7cce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0539912f5176bac976c5b2d0a60b7cce = L.map(
#                 &quot;map_0539912f5176bac976c5b2d0a60b7cce&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfd1b3ec9c8389af00df86943c2b2270 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0539912f5176bac976c5b2d0a60b7cce);
#
#
#             var marker_9918af3bc206fdb8e1ab121833f3cf8a = L.marker(
#                 [35.428048, -94.33674],
#                 {}
#             ).addTo(map_0539912f5176bac976c5b2d0a60b7cce);
#
#
#             var icon_a826875f85c03cb1f66f147c8b4669c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9918af3bc206fdb8e1ab121833f3cf8a.setIcon(icon_a826875f85c03cb1f66f147c8b4669c2);
#
#
#         var popup_68aab8343644f20b5f5ab6f12d4f17d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ac36c938a673eb767172957769242d0 = $(`&lt;div id=&quot;html_7ac36c938a673eb767172957769242d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_68aab8343644f20b5f5ab6f12d4f17d0.setContent(html_7ac36c938a673eb767172957769242d0);
#
#
#
#         marker_9918af3bc206fdb8e1ab121833f3cf8a.bindPopup(popup_68aab8343644f20b5f5ab6f12d4f17d0)
#         ;
#
#
#
#
#             var marker_a1b8e9f4154e36df7d8b4a220a234665 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_0539912f5176bac976c5b2d0a60b7cce);
#
#
#             var icon_d3ca056b2425989bdae0c708f0998543 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a1b8e9f4154e36df7d8b4a220a234665.setIcon(icon_d3ca056b2425989bdae0c708f0998543);
#
#
#         var popup_d46515853b14ca5fac9febef317e4f39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05ae0fd41b8eb094fc682ea9adf621e1 = $(`&lt;div id=&quot;html_05ae0fd41b8eb094fc682ea9adf621e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_d46515853b14ca5fac9febef317e4f39.setContent(html_05ae0fd41b8eb094fc682ea9adf621e1);
#
#
#
#         marker_a1b8e9f4154e36df7d8b4a220a234665.bindPopup(popup_d46515853b14ca5fac9febef317e4f39)
#         ;
#
#
#
#
#             var marker_13b38d4bc854be9622c688740c473c41 = L.marker(
#                 [35.703198, -91.475651],
#                 {}
#             ).addTo(map_0539912f5176bac976c5b2d0a60b7cce);
#
#
#             var icon_1185404ee8b59d149be9ad1aba5a863b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13b38d4bc854be9622c688740c473c41.setIcon(icon_1185404ee8b59d149be9ad1aba5a863b);
#
#
#         var popup_64c3c4fa52b6245091c8a8c00728d2de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a487b22f814b348f3a94fdbefed7a45d = $(`&lt;div id=&quot;html_a487b22f814b348f3a94fdbefed7a45d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_64c3c4fa52b6245091c8a8c00728d2de.setContent(html_a487b22f814b348f3a94fdbefed7a45d);
#
#
#
#         marker_13b38d4bc854be9622c688740c473c41.bindPopup(popup_64c3c4fa52b6245091c8a8c00728d2de)
#         ;
#
#
#
#
#             var marker_8579504a24f6088490fac76eb015d324 = L.marker(
#                 [35.0553, -93.3685],
#                 {}
#             ).addTo(map_0539912f5176bac976c5b2d0a60b7cce);
#
#
#             var icon_06e82c13957758bcdb9a40b1139380bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot

# %%
make_map(df_2015, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dedaa23eb238abacd8f47f329b4c488e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dedaa23eb238abacd8f47f329b4c488e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dedaa23eb238abacd8f47f329b4c488e = L.map(
#                 &quot;map_dedaa23eb238abacd8f47f329b4c488e&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86fcf854287ae990a04eb38a0c74fe73 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dedaa23eb238abacd8f47f329b4c488e);
#
#
#             var marker_87609e1290ffee1dba1717c97ffce414 = L.marker(
#                 [35.428048, -94.33674],
#                 {}
#             ).addTo(map_dedaa23eb238abacd8f47f329b4c488e);
#
#
#             var icon_13437af776e5a736e9fe7fbb28a6cfb0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_87609e1290ffee1dba1717c97ffce414.setIcon(icon_13437af776e5a736e9fe7fbb28a6cfb0);
#
#
#         var popup_752306e538c0b3fe9360beebbb823e82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8021e0e98b462076f8ab95ea097e010 = $(`&lt;div id=&quot;html_a8021e0e98b462076f8ab95ea097e010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_752306e538c0b3fe9360beebbb823e82.setContent(html_a8021e0e98b462076f8ab95ea097e010);
#
#
#
#         marker_87609e1290ffee1dba1717c97ffce414.bindPopup(popup_752306e538c0b3fe9360beebbb823e82)
#         ;
#
#
#
#
#             var marker_11c5d293161bd7b079a9474fb29865f4 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_dedaa23eb238abacd8f47f329b4c488e);
#
#
#             var icon_0adf98a4bd869a96fac05d354e565a7d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_11c5d293161bd7b079a9474fb29865f4.setIcon(icon_0adf98a4bd869a96fac05d354e565a7d);
#
#
#         var popup_7fc41ca6f6af9d9a4d39333ab390b596 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5fe4f60374b9871d9f59fd149467179f = $(`&lt;div id=&quot;html_5fe4f60374b9871d9f59fd149467179f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_7fc41ca6f6af9d9a4d39333ab390b596.setContent(html_5fe4f60374b9871d9f59fd149467179f);
#
#
#
#         marker_11c5d293161bd7b079a9474fb29865f4.bindPopup(popup_7fc41ca6f6af9d9a4d39333ab390b596)
#         ;
#
#
#
#
#             var marker_884df87c078457688f9adc86b746c9aa = L.marker(
#                 [35.062086, -93.351198],
#                 {}
#             ).addTo(map_dedaa23eb238abacd8f47f329b4c488e);
#
#
#             var icon_9dfc582e14259d1e5bdcf028cc203e57 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_884df87c078457688f9adc86b746c9aa.setIcon(icon_9dfc582e14259d1e5bdcf028cc203e57);
#
#
#         var popup_12e057dd7434ff59f930700bc014ada8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b635fe43eb747df69db8152640019f8 = $(`&lt;div id=&quot;html_5b635fe43eb747df69db8152640019f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_12e057dd7434ff59f930700bc014ada8.setContent(html_5b635fe43eb747df69db8152640019f8);
#
#
#
#         marker_884df87c078457688f9adc86b746c9aa.bindPopup(popup_12e057dd7434ff59f930700bc014ada8)
#         ;
#
#
#
#
#             var marker_4b27fe01a60c58fb25aaefe2fbc70613 = L.marker(
#                 [36.15404, -94.15428],
#                 {}
#             ).addTo(map_dedaa23eb238abacd8f47f329b4c488e);
#
#
#             var icon_94fd49054815ba9f8c8859b2d7f03fc9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:

# %%
make_map(df_2014, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_790164191b0d657efb0bd905e6746c92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_790164191b0d657efb0bd905e6746c92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_790164191b0d657efb0bd905e6746c92 = L.map(
#                 &quot;map_790164191b0d657efb0bd905e6746c92&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a10e54907f02ba66836ecfafd5b3a781 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_790164191b0d657efb0bd905e6746c92);
#
#
#             var marker_0690153070f2b9dadcb0ff0ac1b12ba9 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_790164191b0d657efb0bd905e6746c92);
#
#
#             var icon_ec6cb45057e676cb3de3e86fdb240f67 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0690153070f2b9dadcb0ff0ac1b12ba9.setIcon(icon_ec6cb45057e676cb3de3e86fdb240f67);
#
#
#         var popup_0658a9921b768bcd02a4793323ebea09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56a604085c5f8ca1ddabd713658b565d = $(`&lt;div id=&quot;html_56a604085c5f8ca1ddabd713658b565d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simmons Foods Inc&lt;/div&gt;`)[0];
#                 popup_0658a9921b768bcd02a4793323ebea09.setContent(html_56a604085c5f8ca1ddabd713658b565d);
#
#
#
#         marker_0690153070f2b9dadcb0ff0ac1b12ba9.bindPopup(popup_0658a9921b768bcd02a4793323ebea09)
#         ;
#
#
#
#
#             var marker_bbd0dfc611f3838cb9d919916babb235 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_790164191b0d657efb0bd905e6746c92);
#
#
#             var icon_85a4220ed03e487a847a922447e2068c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bbd0dfc611f3838cb9d919916babb235.setIcon(icon_85a4220ed03e487a847a922447e2068c);
#
#
#         var popup_1f1a63203ed2490779fbc28c5d19bd5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42a46bc83b4ce10fdf947e9b0fbf1d20 = $(`&lt;div id=&quot;html_42a46bc83b4ce10fdf947e9b0fbf1d20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_1f1a63203ed2490779fbc28c5d19bd5d.setContent(html_42a46bc83b4ce10fdf947e9b0fbf1d20);
#
#
#
#         marker_bbd0dfc611f3838cb9d919916babb235.bindPopup(popup_1f1a63203ed2490779fbc28c5d19bd5d)
#         ;
#
#
#
#
#             var marker_d1a6da4b418926fe7215c90855ddb6e6 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_790164191b0d657efb0bd905e6746c92);
#
#
#             var icon_d482551f80c71e1e612bd9e33bcd13a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d1a6da4b418926fe7215c90855ddb6e6.setIcon(icon_d482551f80c71e1e612bd9e33bcd13a1);
#
#
#         var popup_82c635f84abe8a6d54fff52b315b9f0f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48f9280ae3b5329abad853e63ea872f8 = $(`&lt;div id=&quot;html_48f9280ae3b5329abad853e63ea872f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_82c635f84abe8a6d54fff52b315b9f0f.setContent(html_48f9280ae3b5329abad853e63ea872f8);
#
#
#
#         marker_d1a6da4b418926fe7215c90855ddb6e6.bindPopup(popup_82c635f84abe8a6d54fff52b315b9f0f)
#         ;
#
#
#
#
#             var marker_87b226d309e9af8060e543db491e64a9 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_790164191b0d657efb0bd905e6746c92);
#
#
#             var icon_5310a4741e9bbb31643494c84d12e097 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &

# %%
make_map(df_2013, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fdde51484ba53ec11660277af62b8a29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fdde51484ba53ec11660277af62b8a29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fdde51484ba53ec11660277af62b8a29 = L.map(
#                 &quot;map_fdde51484ba53ec11660277af62b8a29&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_020e144792dd0bd2da539cac57ca6302 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fdde51484ba53ec11660277af62b8a29);
#
#
#             var marker_aeeea906254f6e625eba41f54f8187dc = L.marker(
#                 [35.763903, -91.64909],
#                 {}
#             ).addTo(map_fdde51484ba53ec11660277af62b8a29);
#
#
#             var icon_34ce4b5d5d6e0214b7a993526ef74ce9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aeeea906254f6e625eba41f54f8187dc.setIcon(icon_34ce4b5d5d6e0214b7a993526ef74ce9);
#
#
#         var popup_51fd081e6522ea8dfde743f6b0419b97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5972a0e526ce54e1256b5dfe7f70ed37 = $(`&lt;div id=&quot;html_5972a0e526ce54e1256b5dfe7f70ed37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_51fd081e6522ea8dfde743f6b0419b97.setContent(html_5972a0e526ce54e1256b5dfe7f70ed37);
#
#
#
#         marker_aeeea906254f6e625eba41f54f8187dc.bindPopup(popup_51fd081e6522ea8dfde743f6b0419b97)
#         ;
#
#
#
#
#             var marker_39beeb36873891e9cfc6161deeb8ae7e = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_fdde51484ba53ec11660277af62b8a29);
#
#
#             var icon_adf0504ddd2972e2d5baae2389e3d019 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_39beeb36873891e9cfc6161deeb8ae7e.setIcon(icon_adf0504ddd2972e2d5baae2389e3d019);
#
#
#         var popup_62a0b3f960c0992de8c4a2d42a065333 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd5a2850f936e80682007aa0baff0a35 = $(`&lt;div id=&quot;html_cd5a2850f936e80682007aa0baff0a35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_62a0b3f960c0992de8c4a2d42a065333.setContent(html_cd5a2850f936e80682007aa0baff0a35);
#
#
#
#         marker_39beeb36873891e9cfc6161deeb8ae7e.bindPopup(popup_62a0b3f960c0992de8c4a2d42a065333)
#         ;
#
#
#
#
#             var marker_830d585416d1524579f166950f460935 = L.marker(
#                 [36.154423, -94.15444],
#                 {}
#             ).addTo(map_fdde51484ba53ec11660277af62b8a29);
#
#
#             var icon_8d9e93470ebb130eea6e39b104b578ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_830d585416d1524579f166950f460935.setIcon(icon_8d9e93470ebb130eea6e39b104b578ea);
#
#
#         var popup_c6e34591badd564e3867a9455a088739 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5def64e56ad1f3bcf08ea535c1433d61 = $(`&lt;div id=&quot;html_5def64e56ad1f3bcf08ea535c1433d61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_c6e34591badd564e3867a9455a088739.setContent(html_5def64e56ad1f3bcf08ea535c1433d61);
#
#
#
#         marker_830d585416d1524579f166950f460935.bindPopup(popup_c6e34591badd564e3867a9455a088739)
#         ;
#
#
#
#
#             var marker_73846c24a2a7a7366921d85167f3c09c = L.marker(
#                 [35.261343, -93.121268],
#                 {}
#             ).addTo(map_fdde51484ba53ec11660277af62b8a29);
#
#
#             var icon_2fbc49ec7faf1da353c7f4694994a0a9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot

# %%
make_map(df_2012, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_977c35055f6035a10d56f94ffc9d236e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_977c35055f6035a10d56f94ffc9d236e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_977c35055f6035a10d56f94ffc9d236e = L.map(
#                 &quot;map_977c35055f6035a10d56f94ffc9d236e&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0185866ad96a81890fcd818233da8c3a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_977c35055f6035a10d56f94ffc9d236e);
#
#
#             var marker_d0f3123b406bcc9b2829db0bcd2404da = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_977c35055f6035a10d56f94ffc9d236e);
#
#
#             var icon_a8456423dd9fcbfacd2c99faaeec924c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d0f3123b406bcc9b2829db0bcd2404da.setIcon(icon_a8456423dd9fcbfacd2c99faaeec924c);
#
#
#         var popup_990206ad39b80e0970e6d87f057221ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_464a353970ccef3bdef0f5e553f7d7f6 = $(`&lt;div id=&quot;html_464a353970ccef3bdef0f5e553f7d7f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peco Foods Inc&lt;/div&gt;`)[0];
#                 popup_990206ad39b80e0970e6d87f057221ef.setContent(html_464a353970ccef3bdef0f5e553f7d7f6);
#
#
#
#         marker_d0f3123b406bcc9b2829db0bcd2404da.bindPopup(popup_990206ad39b80e0970e6d87f057221ef)
#         ;
#
#
#
#
#             var marker_0680c0010a41337a2f85305f50ee6c85 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_977c35055f6035a10d56f94ffc9d236e);
#
#
#             var icon_e6da5af14619fc8d09bbb86cd9d16707 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0680c0010a41337a2f85305f50ee6c85.setIcon(icon_e6da5af14619fc8d09bbb86cd9d16707);
#
#
#         var popup_21a5f68e8ec483374fc2e697ccf4c2b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd5d436e6a186305ce2e694acad6ae9f = $(`&lt;div id=&quot;html_fd5d436e6a186305ce2e694acad6ae9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_21a5f68e8ec483374fc2e697ccf4c2b0.setContent(html_fd5d436e6a186305ce2e694acad6ae9f);
#
#
#
#         marker_0680c0010a41337a2f85305f50ee6c85.bindPopup(popup_21a5f68e8ec483374fc2e697ccf4c2b0)
#         ;
#
#
#
#
#             var marker_f79bdfac737517d752922480ee2ecbe3 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_977c35055f6035a10d56f94ffc9d236e);
#
#
#             var icon_de596e8c7d627da1e4d6a451aa218f7c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f79bdfac737517d752922480ee2ecbe3.setIcon(icon_de596e8c7d627da1e4d6a451aa218f7c);
#
#
#         var popup_e6f01098f8bb98240ba47169703cb468 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_593e31845b93ccc32b75c8b4da4350c8 = $(`&lt;div id=&quot;html_593e31845b93ccc32b75c8b4da4350c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_e6f01098f8bb98240ba47169703cb468.setContent(html_593e31845b93ccc32b75c8b4da4350c8);
#
#
#
#         marker_f79bdfac737517d752922480ee2ecbe3.bindPopup(popup_e6f01098f8bb98240ba47169703cb468)
#         ;
#
#
#
#
#             var marker_b82bf6d1d275a8225eefcf5313f6fef4 = L.marker(
#                 [35.26134, -93.12126],
#                 {}
#             ).addTo(map_977c35055f6035a10d56f94ffc9d236e);
#
#
#             var icon_2cf083ce12790a34d7036d4815117647 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &

# %%
make_map(df_2011, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98ed0c203561323f9467a28c52038895 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98ed0c203561323f9467a28c52038895&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98ed0c203561323f9467a28c52038895 = L.map(
#                 &quot;map_98ed0c203561323f9467a28c52038895&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7278251871dc26edd411355b8393aaf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_98ed0c203561323f9467a28c52038895);
#
#
#             var marker_0909a94c2970361d087b6f02b33fc470 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_98ed0c203561323f9467a28c52038895);
#
#
#             var icon_5e89a6cbff471c65a89ade7f77e6b917 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0909a94c2970361d087b6f02b33fc470.setIcon(icon_5e89a6cbff471c65a89ade7f77e6b917);
#
#
#         var popup_a2e620f10e64ee09c65d96bda463fd1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d32e51de86b32db24d70948c33da821 = $(`&lt;div id=&quot;html_4d32e51de86b32db24d70948c33da821&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_a2e620f10e64ee09c65d96bda463fd1c.setContent(html_4d32e51de86b32db24d70948c33da821);
#
#
#
#         marker_0909a94c2970361d087b6f02b33fc470.bindPopup(popup_a2e620f10e64ee09c65d96bda463fd1c)
#         ;
#
#
#
#
#             var marker_d55c26d660e82d2b3081cfed8a4d3832 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_98ed0c203561323f9467a28c52038895);
#
#
#             var icon_42ac696641c698584b87928578f2f856 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d55c26d660e82d2b3081cfed8a4d3832.setIcon(icon_42ac696641c698584b87928578f2f856);
#
#
#         var popup_3401a06f8f4890025236ac3678e16b97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d57dbd83452ccd6015850f8cb5f03a7 = $(`&lt;div id=&quot;html_1d57dbd83452ccd6015850f8cb5f03a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_3401a06f8f4890025236ac3678e16b97.setContent(html_1d57dbd83452ccd6015850f8cb5f03a7);
#
#
#
#         marker_d55c26d660e82d2b3081cfed8a4d3832.bindPopup(popup_3401a06f8f4890025236ac3678e16b97)
#         ;
#
#
#
#
#             var marker_415aa1a27f7d43f3a8592fad59e71add = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_98ed0c203561323f9467a28c52038895);
#
#
#             var icon_b40aa8ea5a36b5bc7917b2c2dddc4759 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_415aa1a27f7d43f3a8592fad59e71add.setIcon(icon_b40aa8ea5a36b5bc7917b2c2dddc4759);
#
#
#         var popup_c09ae56ffbdffcd81e6f8c272f85fd8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e888de3ddc7e9baa773cbcb7c120988e = $(`&lt;div id=&quot;html_e888de3ddc7e9baa773cbcb7c120988e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_c09ae56ffbdffcd81e6f8c272f85fd8e.setContent(html_e888de3ddc7e9baa773cbcb7c120988e);
#
#
#
#         marker_415aa1a27f7d43f3a8592fad59e71add.bindPopup(popup_c09ae56ffbdffcd81e6f8c272f85fd8e)
#         ;
#
#
#
#
#             var marker_13e874796d610f6949d51c43ec18aef0 = L.marker(
#                 [35.26134, -93.12126],
#                 {}
#             ).addTo(map_98ed0c203561323f9467a28c52038895);
#
#
#             var icon_f6effdec7d8dc0c498ab91a35a1bac9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;

# %%
make_map(df_2010, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acab3c74cbe532d26afeba3469a6d67f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acab3c74cbe532d26afeba3469a6d67f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acab3c74cbe532d26afeba3469a6d67f = L.map(
#                 &quot;map_acab3c74cbe532d26afeba3469a6d67f&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9871cc5b03c5d1d47dbed91927cd40b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_acab3c74cbe532d26afeba3469a6d67f);
#
#
#             var marker_c4c80b6fb05173d651c0110cc8129ad4 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_acab3c74cbe532d26afeba3469a6d67f);
#
#
#             var icon_292f0cc1001d831a1dbeb35951361c0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c4c80b6fb05173d651c0110cc8129ad4.setIcon(icon_292f0cc1001d831a1dbeb35951361c0c);
#
#
#         var popup_abcdd6cb4c275486d746a8fee03c78a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fab9630c23e3492c9fff105517360b55 = $(`&lt;div id=&quot;html_fab9630c23e3492c9fff105517360b55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_abcdd6cb4c275486d746a8fee03c78a4.setContent(html_fab9630c23e3492c9fff105517360b55);
#
#
#
#         marker_c4c80b6fb05173d651c0110cc8129ad4.bindPopup(popup_abcdd6cb4c275486d746a8fee03c78a4)
#         ;
#
#
#
#
#             var marker_756e7020298197184527a908ab781051 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_acab3c74cbe532d26afeba3469a6d67f);
#
#
#             var icon_e2e06e3ce2aa4e5a85d66d77172a8a4a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_756e7020298197184527a908ab781051.setIcon(icon_e2e06e3ce2aa4e5a85d66d77172a8a4a);
#
#
#         var popup_5c2482cabe15c3aba9c172ffcc738ded = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43834294679766682c8af6de109a160d = $(`&lt;div id=&quot;html_43834294679766682c8af6de109a160d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_5c2482cabe15c3aba9c172ffcc738ded.setContent(html_43834294679766682c8af6de109a160d);
#
#
#
#         marker_756e7020298197184527a908ab781051.bindPopup(popup_5c2482cabe15c3aba9c172ffcc738ded)
#         ;
#
#
#
#
#             var marker_b365dce39092f0636a731355c27df2a3 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_acab3c74cbe532d26afeba3469a6d67f);
#
#
#             var icon_8bada1641803da2ae8e326ba56ad9849 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b365dce39092f0636a731355c27df2a3.setIcon(icon_8bada1641803da2ae8e326ba56ad9849);
#
#
#         var popup_1cd261e5775ec4ca3c42a454497f859c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0be08c0d33df87bed872149f18915030 = $(`&lt;div id=&quot;html_0be08c0d33df87bed872149f18915030&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_1cd261e5775ec4ca3c42a454497f859c.setContent(html_0be08c0d33df87bed872149f18915030);
#
#
#
#         marker_b365dce39092f0636a731355c27df2a3.bindPopup(popup_1cd261e5775ec4ca3c42a454497f859c)
#         ;
#
#
#
#
#             var marker_d05f6c54f563211e105b256df0bfbb33 = L.marker(
#                 [35.26134, -93.12126],
#                 {}
#             ).addTo(map_acab3c74cbe532d26afeba3469a6d67f);
#
#
#             var icon_e1f885d4c3128e17e8834034229a01c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &q

# %%
make_map(df_2009, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e5712b7d413003db4681ebcf3329d68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e5712b7d413003db4681ebcf3329d68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e5712b7d413003db4681ebcf3329d68 = L.map(
#                 &quot;map_2e5712b7d413003db4681ebcf3329d68&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d10f7563a3f8454154872b3bd71ac1a6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e5712b7d413003db4681ebcf3329d68);
#
#
#             var marker_055689ee941158a501ac22c29a8d3354 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_2e5712b7d413003db4681ebcf3329d68);
#
#
#             var icon_98cfc15953b1317d0c071dda1862a016 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_055689ee941158a501ac22c29a8d3354.setIcon(icon_98cfc15953b1317d0c071dda1862a016);
#
#
#         var popup_64d3fb252ba861969bb5e6aebd0ebf1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a0cd526b7d73e7385222e911f7cfff3 = $(`&lt;div id=&quot;html_6a0cd526b7d73e7385222e911f7cfff3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_64d3fb252ba861969bb5e6aebd0ebf1d.setContent(html_6a0cd526b7d73e7385222e911f7cfff3);
#
#
#
#         marker_055689ee941158a501ac22c29a8d3354.bindPopup(popup_64d3fb252ba861969bb5e6aebd0ebf1d)
#         ;
#
#
#
#
#             var marker_fea2bcded6f3671d429dc088f88ad392 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_2e5712b7d413003db4681ebcf3329d68);
#
#
#             var icon_d600a3d0beb64684ba2e433578d72fa9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fea2bcded6f3671d429dc088f88ad392.setIcon(icon_d600a3d0beb64684ba2e433578d72fa9);
#
#
#         var popup_d182ede81b7435e04c85891bbef998d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08dc9ab927afeb5b35a41b27fc8cafb1 = $(`&lt;div id=&quot;html_08dc9ab927afeb5b35a41b27fc8cafb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_d182ede81b7435e04c85891bbef998d0.setContent(html_08dc9ab927afeb5b35a41b27fc8cafb1);
#
#
#
#         marker_fea2bcded6f3671d429dc088f88ad392.bindPopup(popup_d182ede81b7435e04c85891bbef998d0)
#         ;
#
#
#
#
#             var marker_c20dcaa47eac2c6bfc8f2d9fa7ea0743 = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_2e5712b7d413003db4681ebcf3329d68);
#
#
#             var icon_9af6fed887407ab2ca4a2f628285301a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c20dcaa47eac2c6bfc8f2d9fa7ea0743.setIcon(icon_9af6fed887407ab2ca4a2f628285301a);
#
#
#         var popup_a05623e3053f8a283381c94ca59a2859 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58432384e2039d9cdf86cff65e15a12c = $(`&lt;div id=&quot;html_58432384e2039d9cdf86cff65e15a12c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_a05623e3053f8a283381c94ca59a2859.setContent(html_58432384e2039d9cdf86cff65e15a12c);
#
#
#
#         marker_c20dcaa47eac2c6bfc8f2d9fa7ea0743.bindPopup(popup_a05623e3053f8a283381c94ca59a2859)
#         ;
#
#
#
#
#             var marker_ae59d7071746bdaac97e15f2556f2836 = L.marker(
#                 [35.26134, -93.12126],
#                 {}
#             ).addTo(map_2e5712b7d413003db4681ebcf3329d68);
#
#
#             var icon_9207b685390add60732e0d6457a4dac8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColo

# %%
make_map(df_2008, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d8cf9461e455e3b994d6906ed4da7b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d8cf9461e455e3b994d6906ed4da7b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d8cf9461e455e3b994d6906ed4da7b5 = L.map(
#                 &quot;map_1d8cf9461e455e3b994d6906ed4da7b5&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26eaf5978616916aa6337a88fd6981b9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1d8cf9461e455e3b994d6906ed4da7b5);
#
#
#             var marker_b73090a6efc9932ed7cc87d44d999405 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_1d8cf9461e455e3b994d6906ed4da7b5);
#
#
#             var icon_9f79269bee86ab87ab681427fd9c0d22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b73090a6efc9932ed7cc87d44d999405.setIcon(icon_9f79269bee86ab87ab681427fd9c0d22);
#
#
#         var popup_513cd20cd7a440ce545ff698158495fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_807ddf064a1cad8ccfee77f518a5ca8f = $(`&lt;div id=&quot;html_807ddf064a1cad8ccfee77f518a5ca8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_513cd20cd7a440ce545ff698158495fb.setContent(html_807ddf064a1cad8ccfee77f518a5ca8f);
#
#
#
#         marker_b73090a6efc9932ed7cc87d44d999405.bindPopup(popup_513cd20cd7a440ce545ff698158495fb)
#         ;
#
#
#
#
#             var marker_5fb6ed826d10984b9560aae935b93e73 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_1d8cf9461e455e3b994d6906ed4da7b5);
#
#
#             var icon_c93c5576565e2afc9d2f1712a85729a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5fb6ed826d10984b9560aae935b93e73.setIcon(icon_c93c5576565e2afc9d2f1712a85729a0);
#
#
#         var popup_7b3413368f97d9661a4b56ffac56cb55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a0e828526543311f06a5a7e86229125 = $(`&lt;div id=&quot;html_6a0e828526543311f06a5a7e86229125&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_7b3413368f97d9661a4b56ffac56cb55.setContent(html_6a0e828526543311f06a5a7e86229125);
#
#
#
#         marker_5fb6ed826d10984b9560aae935b93e73.bindPopup(popup_7b3413368f97d9661a4b56ffac56cb55)
#         ;
#
#
#
#
#             var marker_70d1ea06027070ea2bf1482eefa0a2aa = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_1d8cf9461e455e3b994d6906ed4da7b5);
#
#
#             var icon_a8beccd81799eb900b01527d18c50844 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_70d1ea06027070ea2bf1482eefa0a2aa.setIcon(icon_a8beccd81799eb900b01527d18c50844);
#
#
#         var popup_13a432b4ca3e7043c161ce4185dec1f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae36ab34931ef3589e466fc93ca9f3e0 = $(`&lt;div id=&quot;html_ae36ab34931ef3589e466fc93ca9f3e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_13a432b4ca3e7043c161ce4185dec1f4.setContent(html_ae36ab34931ef3589e466fc93ca9f3e0);
#
#
#
#         marker_70d1ea06027070ea2bf1482eefa0a2aa.bindPopup(popup_13a432b4ca3e7043c161ce4185dec1f4)
#         ;
#
#
#
#
#             var marker_112690ebc4c42b0b681dbec56bcab6d6 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_1d8cf9461e455e3b994d6906ed4da7b5);
#
#
#             var icon_11a952866ee97ca5c2d6ceab9d3bc24b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColo

# %%
make_map(df_2007, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e26d907b60415a4791c042798a31e6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e26d907b60415a4791c042798a31e6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e26d907b60415a4791c042798a31e6d = L.map(
#                 &quot;map_3e26d907b60415a4791c042798a31e6d&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7103490bafa6d8d47de0b539563660f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3e26d907b60415a4791c042798a31e6d);
#
#
#             var marker_4d724c5d1392542db765fda703c9d3b0 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_3e26d907b60415a4791c042798a31e6d);
#
#
#             var icon_2dcb448a01bdd004a16e486fa2fe1e3b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4d724c5d1392542db765fda703c9d3b0.setIcon(icon_2dcb448a01bdd004a16e486fa2fe1e3b);
#
#
#         var popup_ca261ffc65f34038f0739c3a893c137a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_88329c3984a247c1e928c363d4d87780 = $(`&lt;div id=&quot;html_88329c3984a247c1e928c363d4d87780&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_ca261ffc65f34038f0739c3a893c137a.setContent(html_88329c3984a247c1e928c363d4d87780);
#
#
#
#         marker_4d724c5d1392542db765fda703c9d3b0.bindPopup(popup_ca261ffc65f34038f0739c3a893c137a)
#         ;
#
#
#
#
#             var marker_8c3ec83c5f2b99cd9031e9c5920d7f64 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_3e26d907b60415a4791c042798a31e6d);
#
#
#             var icon_a76d54d9211688c111685c566900bf27 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c3ec83c5f2b99cd9031e9c5920d7f64.setIcon(icon_a76d54d9211688c111685c566900bf27);
#
#
#         var popup_59930ea15a9191547173727b0c92b8c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_077c2a775a189a8797e1a144242a67b1 = $(`&lt;div id=&quot;html_077c2a775a189a8797e1a144242a67b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_59930ea15a9191547173727b0c92b8c8.setContent(html_077c2a775a189a8797e1a144242a67b1);
#
#
#
#         marker_8c3ec83c5f2b99cd9031e9c5920d7f64.bindPopup(popup_59930ea15a9191547173727b0c92b8c8)
#         ;
#
#
#
#
#             var marker_4b6a39efc8096f138a82472e99d2235c = L.marker(
#                 [35.05482, -93.377547],
#                 {}
#             ).addTo(map_3e26d907b60415a4791c042798a31e6d);
#
#
#             var icon_bdaf60b7a836ccfebb280124913838f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4b6a39efc8096f138a82472e99d2235c.setIcon(icon_bdaf60b7a836ccfebb280124913838f5);
#
#
#         var popup_5ab45f258a809e0901eedc10768578cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2df3be48043195cd8670dd00178b8e67 = $(`&lt;div id=&quot;html_2df3be48043195cd8670dd00178b8e67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Continental Grain Co&lt;/div&gt;`)[0];
#                 popup_5ab45f258a809e0901eedc10768578cf.setContent(html_2df3be48043195cd8670dd00178b8e67);
#
#
#
#         marker_4b6a39efc8096f138a82472e99d2235c.bindPopup(popup_5ab45f258a809e0901eedc10768578cf)
#         ;
#
#
#
#
#             var marker_6f68126bb7bc63d60e9ce18d29c6bf86 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_3e26d907b60415a4791c042798a31e6d);
#
#
#             var icon_9a6ee565a42e92f5337aa670aec3ba45 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&qu

# %%
make_map(df_2006, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec9e510884b1d605b5167c47ae22cc03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec9e510884b1d605b5167c47ae22cc03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec9e510884b1d605b5167c47ae22cc03 = L.map(
#                 &quot;map_ec9e510884b1d605b5167c47ae22cc03&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d37328f815800aa1441c2c146784be7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec9e510884b1d605b5167c47ae22cc03);
#
#
#             var marker_a277ffe6b7e4e40856fe54f214c902ab = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_ec9e510884b1d605b5167c47ae22cc03);
#
#
#             var icon_e820f5cbdc99ffdf924ada896ee95040 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a277ffe6b7e4e40856fe54f214c902ab.setIcon(icon_e820f5cbdc99ffdf924ada896ee95040);
#
#
#         var popup_604148d99172d975ebfc4596a421a2bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_092a96486fd1d73ef07ec28e1005c074 = $(`&lt;div id=&quot;html_092a96486fd1d73ef07ec28e1005c074&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_604148d99172d975ebfc4596a421a2bb.setContent(html_092a96486fd1d73ef07ec28e1005c074);
#
#
#
#         marker_a277ffe6b7e4e40856fe54f214c902ab.bindPopup(popup_604148d99172d975ebfc4596a421a2bb)
#         ;
#
#
#
#
#             var marker_25b918606b7f35f04e07ac31dc03b64e = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_ec9e510884b1d605b5167c47ae22cc03);
#
#
#             var icon_a1858689004c1ae1925063a8fa51ac22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_25b918606b7f35f04e07ac31dc03b64e.setIcon(icon_a1858689004c1ae1925063a8fa51ac22);
#
#
#         var popup_e9fe14437cdc6b4c92926bc94e790fad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3be768726041cebc41a5449e41b626a0 = $(`&lt;div id=&quot;html_3be768726041cebc41a5449e41b626a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Small Biz&lt;/div&gt;`)[0];
#                 popup_e9fe14437cdc6b4c92926bc94e790fad.setContent(html_3be768726041cebc41a5449e41b626a0);
#
#
#
#         marker_25b918606b7f35f04e07ac31dc03b64e.bindPopup(popup_e9fe14437cdc6b4c92926bc94e790fad)
#         ;
#
#
#
#
#             var marker_fb158b954031a6ca8ed3f95d97c410e2 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_ec9e510884b1d605b5167c47ae22cc03);
#
#
#             var icon_c08130df09e4439f64891661e7113169 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fb158b954031a6ca8ed3f95d97c410e2.setIcon(icon_c08130df09e4439f64891661e7113169);
#
#
#         var popup_d3764444206edb4e33a4a994fcff4c36 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b80050c5d096d0b7f8dd5631b062fce = $(`&lt;div id=&quot;html_6b80050c5d096d0b7f8dd5631b062fce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_d3764444206edb4e33a4a994fcff4c36.setContent(html_6b80050c5d096d0b7f8dd5631b062fce);
#
#
#
#         marker_fb158b954031a6ca8ed3f95d97c410e2.bindPopup(popup_d3764444206edb4e33a4a994fcff4c36)
#         ;
#
#
#
#
#             var marker_4e0f4f3c46ce3400864851b7cc44ce7f = L.marker(
#                 [36.312737, -93.009443],
#                 {}
#             ).addTo(map_ec9e510884b1d605b5167c47ae22cc03);
#
#
#             var icon_69c8e7526e35d3c8029e0c1e8f391add = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &

# %%
make_map(df_2005, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e0e79769c9b9ea2c79c9441ec1de336 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e0e79769c9b9ea2c79c9441ec1de336&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e0e79769c9b9ea2c79c9441ec1de336 = L.map(
#                 &quot;map_8e0e79769c9b9ea2c79c9441ec1de336&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4eef699fb953f118b5d0aca305a3a891 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8e0e79769c9b9ea2c79c9441ec1de336);
#
#
#             var marker_9628ec564cf777604bd863c70d354084 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_8e0e79769c9b9ea2c79c9441ec1de336);
#
#
#             var icon_b5bcaca990816e95cc803ed7037717de = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9628ec564cf777604bd863c70d354084.setIcon(icon_b5bcaca990816e95cc803ed7037717de);
#
#
#         var popup_66a4b65add86c66fb4c490c6310fd83b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b1485e9d82b6263084ba7b6382779ce = $(`&lt;div id=&quot;html_8b1485e9d82b6263084ba7b6382779ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_66a4b65add86c66fb4c490c6310fd83b.setContent(html_8b1485e9d82b6263084ba7b6382779ce);
#
#
#
#         marker_9628ec564cf777604bd863c70d354084.bindPopup(popup_66a4b65add86c66fb4c490c6310fd83b)
#         ;
#
#
#
#
#             var marker_699d7e44a45f99dde8114f204f9b9f65 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_8e0e79769c9b9ea2c79c9441ec1de336);
#
#
#             var icon_ec7a962b8f2a7e2a85f09db796f56724 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_699d7e44a45f99dde8114f204f9b9f65.setIcon(icon_ec7a962b8f2a7e2a85f09db796f56724);
#
#
#         var popup_112e69a45c06f745adc3ed971e3e3bd2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a60a6b38a6f19281a147d223d22abbd = $(`&lt;div id=&quot;html_7a60a6b38a6f19281a147d223d22abbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_112e69a45c06f745adc3ed971e3e3bd2.setContent(html_7a60a6b38a6f19281a147d223d22abbd);
#
#
#
#         marker_699d7e44a45f99dde8114f204f9b9f65.bindPopup(popup_112e69a45c06f745adc3ed971e3e3bd2)
#         ;
#
#
#
#
#             var marker_0d4f92d2c7e08f7846f6f8af8a389a90 = L.marker(
#                 [36.33187, -93.44364],
#                 {}
#             ).addTo(map_8e0e79769c9b9ea2c79c9441ec1de336);
#
#
#             var icon_fb7e5578a0737aa00d6566edac6e642e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d4f92d2c7e08f7846f6f8af8a389a90.setIcon(icon_fb7e5578a0737aa00d6566edac6e642e);
#
#
#         var popup_d876807e8b5a6fbd0b8acdbb6ce88a1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee5d71f9fad6a87cf370df91ea29984a = $(`&lt;div id=&quot;html_ee5d71f9fad6a87cf370df91ea29984a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_d876807e8b5a6fbd0b8acdbb6ce88a1f.setContent(html_ee5d71f9fad6a87cf370df91ea29984a);
#
#
#
#         marker_0d4f92d2c7e08f7846f6f8af8a389a90.bindPopup(popup_d876807e8b5a6fbd0b8acdbb6ce88a1f)
#         ;
#
#
#
#
#             var marker_018e179c05bbc0afeed0dd5031c2339f = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_8e0e79769c9b9ea2c79c9441ec1de336);
#
#
#             var icon_33ffe31c9be621852f344c7fb65dec44 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;ico

# %%
make_map(df_2004, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccd0b691854385d3c782d353fa3ae616 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccd0b691854385d3c782d353fa3ae616&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccd0b691854385d3c782d353fa3ae616 = L.map(
#                 &quot;map_ccd0b691854385d3c782d353fa3ae616&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c781ddecdcc434989693e8a22529de1d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ccd0b691854385d3c782d353fa3ae616);
#
#
#             var marker_c5ef7c248a10cc4fb5d66b246c676dda = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_ccd0b691854385d3c782d353fa3ae616);
#
#
#             var icon_55035b3a6c458a79e29c62992be32787 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c5ef7c248a10cc4fb5d66b246c676dda.setIcon(icon_55035b3a6c458a79e29c62992be32787);
#
#
#         var popup_87be7ea7c94347b0732c51cb6674a3bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f971ffa6c84b1078e4678616aeef392c = $(`&lt;div id=&quot;html_f971ffa6c84b1078e4678616aeef392c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_87be7ea7c94347b0732c51cb6674a3bc.setContent(html_f971ffa6c84b1078e4678616aeef392c);
#
#
#
#         marker_c5ef7c248a10cc4fb5d66b246c676dda.bindPopup(popup_87be7ea7c94347b0732c51cb6674a3bc)
#         ;
#
#
#
#
#             var marker_09e67b4a8017a43fe8e80bdff86a9a70 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_ccd0b691854385d3c782d353fa3ae616);
#
#
#             var icon_5f5a73970ec884d384775915892c592b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_09e67b4a8017a43fe8e80bdff86a9a70.setIcon(icon_5f5a73970ec884d384775915892c592b);
#
#
#         var popup_0daccacb38a7b09c625f986896c1d781 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_328fa7ecd5910478d60655d42c543704 = $(`&lt;div id=&quot;html_328fa7ecd5910478d60655d42c543704&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_0daccacb38a7b09c625f986896c1d781.setContent(html_328fa7ecd5910478d60655d42c543704);
#
#
#
#         marker_09e67b4a8017a43fe8e80bdff86a9a70.bindPopup(popup_0daccacb38a7b09c625f986896c1d781)
#         ;
#
#
#
#
#             var marker_3846f10de5c2b93e625276289f6cf691 = L.marker(
#                 [36.33187, -93.44364],
#                 {}
#             ).addTo(map_ccd0b691854385d3c782d353fa3ae616);
#
#
#             var icon_4683cbc6354a1fc21a167d34c9d55c73 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3846f10de5c2b93e625276289f6cf691.setIcon(icon_4683cbc6354a1fc21a167d34c9d55c73);
#
#
#         var popup_c0b6869a16c145255e87888e9d1a8025 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27ce3374cb85ee1b674f0514d040aa41 = $(`&lt;div id=&quot;html_27ce3374cb85ee1b674f0514d040aa41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_c0b6869a16c145255e87888e9d1a8025.setContent(html_27ce3374cb85ee1b674f0514d040aa41);
#
#
#
#         marker_3846f10de5c2b93e625276289f6cf691.bindPopup(popup_c0b6869a16c145255e87888e9d1a8025)
#         ;
#
#
#
#
#             var marker_45542d7f09e16ed387df4c8fff5874f3 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_ccd0b691854385d3c782d353fa3ae616);
#
#
#             var icon_f813c051e0b456b7717e4cd21fefc25f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;ico

# %%
make_map(df_2003, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d76413b0cef0f291d25afc5b389483a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d76413b0cef0f291d25afc5b389483a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d76413b0cef0f291d25afc5b389483a = L.map(
#                 &quot;map_4d76413b0cef0f291d25afc5b389483a&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b3bd895eb0b9a26c976f0c6154f6ca4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4d76413b0cef0f291d25afc5b389483a);
#
#
#             var marker_46bfe31824bc00134613e0bcc79437e2 = L.marker(
#                 [35.42806, -94.33672],
#                 {}
#             ).addTo(map_4d76413b0cef0f291d25afc5b389483a);
#
#
#             var icon_ffb9530a6ad941caa1225848f91e9975 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_46bfe31824bc00134613e0bcc79437e2.setIcon(icon_ffb9530a6ad941caa1225848f91e9975);
#
#
#         var popup_994867b6ebe1bc800a0f1da6f799dd63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9357f28f043cc8fb3bbb96f3df956fc = $(`&lt;div id=&quot;html_d9357f28f043cc8fb3bbb96f3df956fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_994867b6ebe1bc800a0f1da6f799dd63.setContent(html_d9357f28f043cc8fb3bbb96f3df956fc);
#
#
#
#         marker_46bfe31824bc00134613e0bcc79437e2.bindPopup(popup_994867b6ebe1bc800a0f1da6f799dd63)
#         ;
#
#
#
#
#             var marker_7ab41f991e0dae748a188381b1d4aa3e = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_4d76413b0cef0f291d25afc5b389483a);
#
#
#             var icon_96a6ce74837a38977ebde1a24d70cc35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ab41f991e0dae748a188381b1d4aa3e.setIcon(icon_96a6ce74837a38977ebde1a24d70cc35);
#
#
#         var popup_9ea0710b2c8ac1451bd11c5ccd70881a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39d196f6e957b5be43003b1006ae41e4 = $(`&lt;div id=&quot;html_39d196f6e957b5be43003b1006ae41e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_9ea0710b2c8ac1451bd11c5ccd70881a.setContent(html_39d196f6e957b5be43003b1006ae41e4);
#
#
#
#         marker_7ab41f991e0dae748a188381b1d4aa3e.bindPopup(popup_9ea0710b2c8ac1451bd11c5ccd70881a)
#         ;
#
#
#
#
#             var marker_241140e0b0a6655f73ec039de8fc5287 = L.marker(
#                 [36.15401, -94.15459],
#                 {}
#             ).addTo(map_4d76413b0cef0f291d25afc5b389483a);
#
#
#             var icon_40343fe7b169fa3b60924b7203c1fdf7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_241140e0b0a6655f73ec039de8fc5287.setIcon(icon_40343fe7b169fa3b60924b7203c1fdf7);
#
#
#         var popup_215ae0565a7b0977d9e1069bf4817ef7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4dce318bd50d25b58510faf1b87b5dbd = $(`&lt;div id=&quot;html_4dce318bd50d25b58510faf1b87b5dbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_215ae0565a7b0977d9e1069bf4817ef7.setContent(html_4dce318bd50d25b58510faf1b87b5dbd);
#
#
#
#         marker_241140e0b0a6655f73ec039de8fc5287.bindPopup(popup_215ae0565a7b0977d9e1069bf4817ef7)
#         ;
#
#
#
#
#             var marker_68cd90b4adccdcc60e4b711d4370930e = L.marker(
#                 [36.31803, -94.12137],
#                 {}
#             ).addTo(map_4d76413b0cef0f291d25afc5b389483a);
#
#
#             var icon_897b11820a76281db9da8bfacfad4ba3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;ico

# %%
make_map(df_2002, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1a837979daa638471ecb63a8bbf8158 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1a837979daa638471ecb63a8bbf8158&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1a837979daa638471ecb63a8bbf8158 = L.map(
#                 &quot;map_d1a837979daa638471ecb63a8bbf8158&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69929695f344a7fa90da7693d95e6ade = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d1a837979daa638471ecb63a8bbf8158);
#
#
#             var marker_ce8083c93ea582a23ef2380df961190a = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_d1a837979daa638471ecb63a8bbf8158);
#
#
#             var icon_18b604c54f472c96b63552a09ac1a1ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ce8083c93ea582a23ef2380df961190a.setIcon(icon_18b604c54f472c96b63552a09ac1a1ba);
#
#
#         var popup_cf8ed8188f64b43feac3b340257f2c7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72f2bdd6e482c3199c3ad0e2dde9d94b = $(`&lt;div id=&quot;html_72f2bdd6e482c3199c3ad0e2dde9d94b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_cf8ed8188f64b43feac3b340257f2c7b.setContent(html_72f2bdd6e482c3199c3ad0e2dde9d94b);
#
#
#
#         marker_ce8083c93ea582a23ef2380df961190a.bindPopup(popup_cf8ed8188f64b43feac3b340257f2c7b)
#         ;
#
#
#
#
#             var marker_4a169cf2858e8bded08aabce9d785090 = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_d1a837979daa638471ecb63a8bbf8158);
#
#
#             var icon_c865ccba10977377b4834294483829c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a169cf2858e8bded08aabce9d785090.setIcon(icon_c865ccba10977377b4834294483829c2);
#
#
#         var popup_2823c60babf303135638bdac47c87105 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d6f56038b8e195aff9300bdd0151106 = $(`&lt;div id=&quot;html_7d6f56038b8e195aff9300bdd0151106&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_2823c60babf303135638bdac47c87105.setContent(html_7d6f56038b8e195aff9300bdd0151106);
#
#
#
#         marker_4a169cf2858e8bded08aabce9d785090.bindPopup(popup_2823c60babf303135638bdac47c87105)
#         ;
#
#
#
#
#             var marker_9a707f00f0a4584ec83191eeef5d8a29 = L.marker(
#                 [36.33641, -94.12464],
#                 {}
#             ).addTo(map_d1a837979daa638471ecb63a8bbf8158);
#
#
#             var icon_7971b3d9eb447b00d353c3ebfa726437 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a707f00f0a4584ec83191eeef5d8a29.setIcon(icon_7971b3d9eb447b00d353c3ebfa726437);
#
#
#         var popup_ac8a9dc3a6b14d4abe519cb977c3fbae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a6c4bb2c56ae63907f72ae95fb12651 = $(`&lt;div id=&quot;html_4a6c4bb2c56ae63907f72ae95fb12651&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_ac8a9dc3a6b14d4abe519cb977c3fbae.setContent(html_4a6c4bb2c56ae63907f72ae95fb12651);
#
#
#
#         marker_9a707f00f0a4584ec83191eeef5d8a29.bindPopup(popup_ac8a9dc3a6b14d4abe519cb977c3fbae)
#         ;
#
#
#
#
#             var marker_faf31e902ca5aac64f3663e4a5c2b02f = L.marker(
#                 [35.436053, -94.35322],
#                 {}
#             ).addTo(map_d1a837979daa638471ecb63a8bbf8158);
#
#
#             var icon_6a0e42fc2f4681a022c1a3136d0a588d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&q

# %%
make_map(df_2001, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4dda492ab4b204566369174ff81a080 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4dda492ab4b204566369174ff81a080&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4dda492ab4b204566369174ff81a080 = L.map(
#                 &quot;map_d4dda492ab4b204566369174ff81a080&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20773225f92876c3f5780de9ed65d24c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d4dda492ab4b204566369174ff81a080);
#
#
#             var marker_745ae7f266119af915f6cad3a7bfb56f = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_d4dda492ab4b204566369174ff81a080);
#
#
#             var icon_2ea999ac00e5de7337d6380cf0d10ebd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_745ae7f266119af915f6cad3a7bfb56f.setIcon(icon_2ea999ac00e5de7337d6380cf0d10ebd);
#
#
#         var popup_934bfd2997f9a2249cf156cbd476efe5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a7617b64689ab3d03ec6d77666a6344 = $(`&lt;div id=&quot;html_8a7617b64689ab3d03ec6d77666a6344&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_934bfd2997f9a2249cf156cbd476efe5.setContent(html_8a7617b64689ab3d03ec6d77666a6344);
#
#
#
#         marker_745ae7f266119af915f6cad3a7bfb56f.bindPopup(popup_934bfd2997f9a2249cf156cbd476efe5)
#         ;
#
#
#
#
#             var marker_c7b88520d5bb4a71b38c21bf6caf6bd1 = L.marker(
#                 [35.771495, -91.649756],
#                 {}
#             ).addTo(map_d4dda492ab4b204566369174ff81a080);
#
#
#             var icon_dd433a6829eb09e220e3e51d6c51f769 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c7b88520d5bb4a71b38c21bf6caf6bd1.setIcon(icon_dd433a6829eb09e220e3e51d6c51f769);
#
#
#         var popup_e77740a12ba18014d90694a87130dfc3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05862ac2a775706e39af8f0fb2c8cb2b = $(`&lt;div id=&quot;html_05862ac2a775706e39af8f0fb2c8cb2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_e77740a12ba18014d90694a87130dfc3.setContent(html_05862ac2a775706e39af8f0fb2c8cb2b);
#
#
#
#         marker_c7b88520d5bb4a71b38c21bf6caf6bd1.bindPopup(popup_e77740a12ba18014d90694a87130dfc3)
#         ;
#
#
#
#
#             var marker_63818146e813a14854843cde6ff06ae9 = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_d4dda492ab4b204566369174ff81a080);
#
#
#             var icon_cfac5e86b195548db081fcdfcc9d1ede = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_63818146e813a14854843cde6ff06ae9.setIcon(icon_cfac5e86b195548db081fcdfcc9d1ede);
#
#
#         var popup_50e59bfa7892426ec682d685d11fd508 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef9d23ec9b849da25f1d7d9be82383eb = $(`&lt;div id=&quot;html_ef9d23ec9b849da25f1d7d9be82383eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_50e59bfa7892426ec682d685d11fd508.setContent(html_ef9d23ec9b849da25f1d7d9be82383eb);
#
#
#
#         marker_63818146e813a14854843cde6ff06ae9.bindPopup(popup_50e59bfa7892426ec682d685d11fd508)
#         ;
#
#
#
#
#             var marker_ada1af9f914d62fa431e65b3adc92a3e = L.marker(
#                 [35.436053, -94.35322],
#                 {}
#             ).addTo(map_d4dda492ab4b204566369174ff81a080);
#
#
#             var icon_82bb6691a01fd8d8b8d5416041384504 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quo

# %%
make_map(df_2000, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e63b76ce0591de3772c7c9d7686ce80 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e63b76ce0591de3772c7c9d7686ce80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e63b76ce0591de3772c7c9d7686ce80 = L.map(
#                 &quot;map_0e63b76ce0591de3772c7c9d7686ce80&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dca3e31194801c8157e1e926546a6cdd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e63b76ce0591de3772c7c9d7686ce80);
#
#
#             var marker_5843098f6b338a39d44681cefdff85ed = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_0e63b76ce0591de3772c7c9d7686ce80);
#
#
#             var icon_249c2d4f2d5f7625afa6b46c2169fb63 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5843098f6b338a39d44681cefdff85ed.setIcon(icon_249c2d4f2d5f7625afa6b46c2169fb63);
#
#
#         var popup_e5c78cba1dc85323c1eaddd3a97d3882 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07ab591da70596df83b2a3bd276e8444 = $(`&lt;div id=&quot;html_07ab591da70596df83b2a3bd276e8444&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_e5c78cba1dc85323c1eaddd3a97d3882.setContent(html_07ab591da70596df83b2a3bd276e8444);
#
#
#
#         marker_5843098f6b338a39d44681cefdff85ed.bindPopup(popup_e5c78cba1dc85323c1eaddd3a97d3882)
#         ;
#
#
#
#
#             var marker_ac2b74c04bec7752faa0f8e209ac6a3b = L.marker(
#                 [35.771495, -91.649756],
#                 {}
#             ).addTo(map_0e63b76ce0591de3772c7c9d7686ce80);
#
#
#             var icon_cf82e9efd5dd6cd6978f0823dd031000 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ac2b74c04bec7752faa0f8e209ac6a3b.setIcon(icon_cf82e9efd5dd6cd6978f0823dd031000);
#
#
#         var popup_ff221d5751b7afd7e39dce5ddd4204a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf085fb4251d2f19fa3d36e7e6d77abb = $(`&lt;div id=&quot;html_cf085fb4251d2f19fa3d36e7e6d77abb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_ff221d5751b7afd7e39dce5ddd4204a8.setContent(html_cf085fb4251d2f19fa3d36e7e6d77abb);
#
#
#
#         marker_ac2b74c04bec7752faa0f8e209ac6a3b.bindPopup(popup_ff221d5751b7afd7e39dce5ddd4204a8)
#         ;
#
#
#
#
#             var marker_34af51349424a5c265b94e50c8ba2240 = L.marker(
#                 [36.33113, -93.42862],
#                 {}
#             ).addTo(map_0e63b76ce0591de3772c7c9d7686ce80);
#
#
#             var icon_3b9a17f1d91b5f2f6df9f4991a0566a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34af51349424a5c265b94e50c8ba2240.setIcon(icon_3b9a17f1d91b5f2f6df9f4991a0566a2);
#
#
#         var popup_f66d26b85b8c202abab0c9bfe93c5cef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d3722c95e2fbd9ae4c84bba78c03c7d = $(`&lt;div id=&quot;html_8d3722c95e2fbd9ae4c84bba78c03c7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_f66d26b85b8c202abab0c9bfe93c5cef.setContent(html_8d3722c95e2fbd9ae4c84bba78c03c7d);
#
#
#
#         marker_34af51349424a5c265b94e50c8ba2240.bindPopup(popup_f66d26b85b8c202abab0c9bfe93c5cef)
#         ;
#
#
#
#
#             var marker_7f5ad2b65e64db983eca4c9aaf170105 = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_0e63b76ce0591de3772c7c9d7686ce80);
#
#
#             var icon_eabd200c8cc9695587f2c1befea4178e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot

# %%
make_map(df_1999, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2ff4920d233654ec0275bb4001542fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2ff4920d233654ec0275bb4001542fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2ff4920d233654ec0275bb4001542fa = L.map(
#                 &quot;map_e2ff4920d233654ec0275bb4001542fa&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96eabf31e4dd1116a6da62f4ae006b05 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e2ff4920d233654ec0275bb4001542fa);
#
#
#             var marker_3514752dbbc04f10abea347227a82015 = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_e2ff4920d233654ec0275bb4001542fa);
#
#
#             var icon_4e6496ed1a8e3f84ae47eab1c3fce32f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3514752dbbc04f10abea347227a82015.setIcon(icon_4e6496ed1a8e3f84ae47eab1c3fce32f);
#
#
#         var popup_e2d1701681c66fe8ad3b78d847f2638f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_097dd182a347e1298c677a0bb0120e9e = $(`&lt;div id=&quot;html_097dd182a347e1298c677a0bb0120e9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_e2d1701681c66fe8ad3b78d847f2638f.setContent(html_097dd182a347e1298c677a0bb0120e9e);
#
#
#
#         marker_3514752dbbc04f10abea347227a82015.bindPopup(popup_e2d1701681c66fe8ad3b78d847f2638f)
#         ;
#
#
#
#
#             var marker_f2b193083b96f3ef562cb2f4cb5569f6 = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_e2ff4920d233654ec0275bb4001542fa);
#
#
#             var icon_d5f1566212261e96e96c5d967f3e242b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f2b193083b96f3ef562cb2f4cb5569f6.setIcon(icon_d5f1566212261e96e96c5d967f3e242b);
#
#
#         var popup_e22c149994bf86ab028495590a8c52cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff0a292507dbb0b1cc244829fca8b278 = $(`&lt;div id=&quot;html_ff0a292507dbb0b1cc244829fca8b278&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_e22c149994bf86ab028495590a8c52cb.setContent(html_ff0a292507dbb0b1cc244829fca8b278);
#
#
#
#         marker_f2b193083b96f3ef562cb2f4cb5569f6.bindPopup(popup_e22c149994bf86ab028495590a8c52cb)
#         ;
#
#
#
#
#             var marker_7d32532e18059657d5000bc789f138d7 = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_e2ff4920d233654ec0275bb4001542fa);
#
#
#             var icon_cf440e869a0539548016d303734255c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7d32532e18059657d5000bc789f138d7.setIcon(icon_cf440e869a0539548016d303734255c8);
#
#
#         var popup_f62c5f6160064951187c8a22705ce285 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4fbd81a3703262855a6d407a795defc3 = $(`&lt;div id=&quot;html_4fbd81a3703262855a6d407a795defc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_f62c5f6160064951187c8a22705ce285.setContent(html_4fbd81a3703262855a6d407a795defc3);
#
#
#
#         marker_7d32532e18059657d5000bc789f138d7.bindPopup(popup_f62c5f6160064951187c8a22705ce285)
#         ;
#
#
#
#
#             var marker_7d93cb6434f5d8807928fb95c5f1cde3 = L.marker(
#                 [36.18153, -94.13086],
#                 {}
#             ).addTo(map_e2ff4920d233654ec0275bb4001542fa);
#
#
#             var icon_e3680680261cfaef62c6f6e4a4e199ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot

# %%
make_map(df_1998, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e85d860c3a8256be86403e9a80998b3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e85d860c3a8256be86403e9a80998b3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e85d860c3a8256be86403e9a80998b3a = L.map(
#                 &quot;map_e85d860c3a8256be86403e9a80998b3a&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ff1a5be50eb2039e874b0ea340fe3b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e85d860c3a8256be86403e9a80998b3a);
#
#
#             var marker_bae1cd1f4eaffec50976b4094b0a2e33 = L.marker(
#                 [35.42518, -94.33175],
#                 {}
#             ).addTo(map_e85d860c3a8256be86403e9a80998b3a);
#
#
#             var icon_549a8d97c4173964e0886e783ee2189d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bae1cd1f4eaffec50976b4094b0a2e33.setIcon(icon_549a8d97c4173964e0886e783ee2189d);
#
#
#         var popup_a41b81223af5201e74bbee661fc789b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2bf1ffb4aa910190c6e9633612a7e6f3 = $(`&lt;div id=&quot;html_2bf1ffb4aa910190c6e9633612a7e6f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_a41b81223af5201e74bbee661fc789b7.setContent(html_2bf1ffb4aa910190c6e9633612a7e6f3);
#
#
#
#         marker_bae1cd1f4eaffec50976b4094b0a2e33.bindPopup(popup_a41b81223af5201e74bbee661fc789b7)
#         ;
#
#
#
#
#             var marker_042d7e7d2d430570568fda47c238ae92 = L.marker(
#                 [35.455247, -94.339599],
#                 {}
#             ).addTo(map_e85d860c3a8256be86403e9a80998b3a);
#
#
#             var icon_defb3bae537955b7f59623c8bd40d2c1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_042d7e7d2d430570568fda47c238ae92.setIcon(icon_defb3bae537955b7f59623c8bd40d2c1);
#
#
#         var popup_70ba0587d053b475e326da7137bfb3b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23967fb42fc8e2c9e082ad498cd0c81b = $(`&lt;div id=&quot;html_23967fb42fc8e2c9e082ad498cd0c81b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_70ba0587d053b475e326da7137bfb3b5.setContent(html_23967fb42fc8e2c9e082ad498cd0c81b);
#
#
#
#         marker_042d7e7d2d430570568fda47c238ae92.bindPopup(popup_70ba0587d053b475e326da7137bfb3b5)
#         ;
#
#
#
#
#             var marker_312d64745571943944e3b8b278f88458 = L.marker(
#                 [36.181573, -94.131369],
#                 {}
#             ).addTo(map_e85d860c3a8256be86403e9a80998b3a);
#
#
#             var icon_e2db1872b3cad88a9fd27d040b8ff313 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_312d64745571943944e3b8b278f88458.setIcon(icon_e2db1872b3cad88a9fd27d040b8ff313);
#
#
#         var popup_1dbdb4e629fc324947160b4c72ec3133 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55f8deb1897ac5963fd2d88bc8f2c07e = $(`&lt;div id=&quot;html_55f8deb1897ac5963fd2d88bc8f2c07e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cargil Inc&lt;/div&gt;`)[0];
#                 popup_1dbdb4e629fc324947160b4c72ec3133.setContent(html_55f8deb1897ac5963fd2d88bc8f2c07e);
#
#
#
#         marker_312d64745571943944e3b8b278f88458.bindPopup(popup_1dbdb4e629fc324947160b4c72ec3133)
#         ;
#
#
#
#
#             var marker_824f786c14e3085093ec3f1120f5d6bc = L.marker(
#                 [36.035059, -94.169424],
#                 {}
#             ).addTo(map_e85d860c3a8256be86403e9a80998b3a);
#
#
#             var icon_3ddc630992e103a43c5e95c3abe389cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&

# %%
make_map(df_1997, map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73a3c75294678f33b3298aaf4d34744c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73a3c75294678f33b3298aaf4d34744c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73a3c75294678f33b3298aaf4d34744c = L.map(
#                 &quot;map_73a3c75294678f33b3298aaf4d34744c&quot;,
#                 {
#                     center: [35.201, -91.8318],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2bc47fec480d49a2034e715ca73a8f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_73a3c75294678f33b3298aaf4d34744c);
#
#
#             var marker_9b57ba8d7e4103308524c537098a3259 = L.marker(
#                 [35.76443, -91.64885],
#                 {}
#             ).addTo(map_73a3c75294678f33b3298aaf4d34744c);
#
#
#             var icon_2e18b33c89c5982376b6faee9d8f5dd7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b57ba8d7e4103308524c537098a3259.setIcon(icon_2e18b33c89c5982376b6faee9d8f5dd7);
#
#
#         var popup_f309e522606e93a2c5edd819561ac8da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21bb9a609204319068714eb78f01b040 = $(`&lt;div id=&quot;html_21bb9a609204319068714eb78f01b040&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;None&lt;/div&gt;`)[0];
#                 popup_f309e522606e93a2c5edd819561ac8da.setContent(html_21bb9a609204319068714eb78f01b040);
#
#
#
#         marker_9b57ba8d7e4103308524c537098a3259.bindPopup(popup_f309e522606e93a2c5edd819561ac8da)
#         ;
#
#
#
#
#             var marker_369a0fbc1d6e40c3db47f3c35dcbc369 = L.marker(
#                 [36.33113, -93.42862],
#                 {}
#             ).addTo(map_73a3c75294678f33b3298aaf4d34744c);
#
#
#             var icon_4aa8011f85d1957f62df51511190a7ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_369a0fbc1d6e40c3db47f3c35dcbc369.setIcon(icon_4aa8011f85d1957f62df51511190a7ea);
#
#
#         var popup_ba12652362b2db47413a6b8d70d1f629 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43297a5c0c98df6112d749e3cc1fff78 = $(`&lt;div id=&quot;html_43297a5c0c98df6112d749e3cc1fff78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_ba12652362b2db47413a6b8d70d1f629.setContent(html_43297a5c0c98df6112d749e3cc1fff78);
#
#
#
#         marker_369a0fbc1d6e40c3db47f3c35dcbc369.bindPopup(popup_ba12652362b2db47413a6b8d70d1f629)
#         ;
#
#
#
#
#             var marker_26d4b91cf98cf563c05fdf29abb2fca3 = L.marker(
#                 [36.317124, -94.121375],
#                 {}
#             ).addTo(map_73a3c75294678f33b3298aaf4d34744c);
#
#
#             var icon_4bbd07c9f0fdeea07e34e6a58a13a39d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_26d4b91cf98cf563c05fdf29abb2fca3.setIcon(icon_4bbd07c9f0fdeea07e34e6a58a13a39d);
#
#
#         var popup_e026e7802ea81412e98268dcc4f52c1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d943f326393e1f0d60a7e3487e4f1188 = $(`&lt;div id=&quot;html_d943f326393e1f0d60a7e3487e4f1188&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tyson Foods Inc&lt;/div&gt;`)[0];
#                 popup_e026e7802ea81412e98268dcc4f52c1e.setContent(html_d943f326393e1f0d60a7e3487e4f1188);
#
#
#
#         marker_26d4b91cf98cf563c05fdf29abb2fca3.bindPopup(popup_e026e7802ea81412e98268dcc4f52c1e)
#         ;
#
#
#
#
#             var marker_c19cf1f1a70a2066c13fef69efb8ae35 = L.marker(
#                 [36.167844, -94.137676],
#                 {}
#             ).addTo(map_73a3c75294678f33b3298aaf4d34744c);
#
#
#             var icon_434cf5458a5897549099de288559a6f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&
