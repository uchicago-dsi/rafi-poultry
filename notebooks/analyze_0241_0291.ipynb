# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_0241 = pd.read_csv("../data/code_0241.csv")
df_0241.head()
# Out:
#    Unnamed: 0                  COMPANY                ADDRESS LINE 1  \
# 0           0             DAIRYNET INC  2301 RESEARCH PARK WAY # 155
# 1           1  PRAIRIE FARMS DAIRY INC                 808 E MAIN ST
# 2           2            K C DAIRY LLP                48612 212TH ST
# 3           3          R & D DAIRY INC             52825 HIGHWAY 275
# 4           4                STOP & GO                5566 ALEXIS RD
#
#         CITY STATE  ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ...  \
# 0  BROOKINGS    SD    57006  1724.0           11        605       2  ...
# 1   STREATOR    IL    61364  3004.0           99        815       2  ...
# 2     ELKTON    SD    57026  6716.0           11        605       2  ...
# 3    OAKDALE    NE    68761  3013.0            3        402       2  ...
# 4   SYLVANIA    OH    43560  2456.0           95        419       2  ...
#
#   POPULATION CODE CENSUS TRACT  CENSUS BLOCK   LATITUDE  LONGITUDE MATCH CODE  \
# ...

# %%
df_0241["SIC6_DESCRIPTIONS (SIC)"].value_counts()

df_0241.iloc[0]["SIC CODE"] == 74201

# df["SIC CODE"].astype(str)
for i in range(len(df_0241)):
    print(i)
    if df_0241.iloc[i]["SIC CODE"] == 24101:
        print("here")
        print(df_0241.iloc[i])
        break

# print("yo", len(df))
# Out:
# 0
# 1
# here
# Unnamed: 0                                                   1
# COMPANY                                PRAIRIE FARMS DAIRY INC
# ADDRESS LINE 1                                   808 E MAIN ST
# CITY                                                  STREATOR
# STATE                                                       IL
# ZIPCODE                                                  61364
# ZIP4                                                    3004.0
# COUNTY CODE                                                 99
# AREA CODE                                                  815
# IDCODE                                                       2
# LOCATION EMPLOYEE SIZE CODE                                  C
# LOCATION SALES VOLUME CODE                                   C
# PRIMARY SIC CODE                                         24103
# SIC6_DESCRIPTIONS                                  DAIRY FARMS
# PRIMARY NAICS CODE                                  11212002.0
# ...

# %%
df_0291 = pd.read_csv("../data/code_0291.csv")
df_0291.head()
# Out:
#    Unnamed: 0                      COMPANY        ADDRESS LINE 1  \
# 0           0                 CHURCH RANCH      20009 HIGHWAY 72
# 1           1         UNITED PRODUCERS INC  3491 E STATE ROAD 44
# 2           2  IVEY RANCH COUNTRY CLUB HOA       74580 VARNER RD
# 3           3           DALE SYBRANT RANCH        45240 859TH RD
# 4           4             BRANDT CATTLE CO         299 W MAIN ST
#
#              CITY STATE  ZIPCODE    ZIP4  COUNTY CODE  AREA CODE  IDCODE  ...  \
# 0          ARVADA    CO    80007  8236.0           59        303       2  ...
# 1       RUSHVILLE    IN    46173  7846.0          139        765       2  ...
# 2  THOUSAND PALMS    CA    92276  4201.0           65        760       2  ...
# 3         BASSETT    NE    68714  6077.0          149        402       2  ...
# 4         BRAWLEY    CA    92227  2240.0           25        760       2  ...
#
#   POPULATION CODE CENSUS TRACT  CENSUS BLOCK   LATITUDE   LONGITUDE  \
# ...

# %%
df_0291["SIC6_DESCRIPTIONS (SIC)"].value_counts()
# Out:
# SIC6_DESCRIPTIONS (SIC)
# RANCHES                                  1383
# LIVESTOCK BROKERS                          74
# REPTILES                                   52
# FEDERAL GOVERNMENT CONTRACTORS             31
# LIVESTOCK BUYERS (WHLS)                    29
#                                          ...
# TOURIST INFORMATION                         1
# AGRICULTURAL CONSULTANTS                    1
# ENTERTAINERS-ADULT                          1
# MOBILE HOMES-PARKS & COMMUNITIES            1
# CONVENTION & MEETING FACILITIES & SVC       1
# Name: count, Length: 261, dtype: int64

# %%
# ranch analysis

df_ranch = df_0291[df_0291["SIC6_DESCRIPTIONS (SIC)"] == "RANCHES"]

df_ranch["STATE"].value_counts()
# Out:
# STATE
# TX    301
# CA    236
# CO     94
# MT     90
# AZ     61
# FL     54
# WY     49
# OR     42
# OK     41
# WA     32
# NE     30
# SD     29
# UT     27
# NM     27
# ND     26
# ID     19
# NV     19
# KS     18
# MO     15
# PA     14
# MI     13
# WI     12
# MN     11
# GA     11
# IL     10
# AR     10
# IN      8
# NC      7
# NY      7
# MS      7
# LA      7
# OH      6
# IA      6
# HI      5
# ME      5
# TN      4
# AL      4
# VT      3
# NJ      3
# KY      3
# AK      3
# MD      3
# VA      2
# WV      2
# PR      2
# SC      2
# NH      1
# MA      1
# CT      1
# Name: count, dtype: int64

# %%
# livestock borkers

df_livestock_borker = df_0291[df_0291["SIC6_DESCRIPTIONS (SIC)"] == "LIVESTOCK BROKERS"]

df_livestock_borker.head()

df_livestock_borker["STATE"].value_counts()
# Out:
# STATE
# IA    13
# WI     7
# MN     6
# VA     5
# KY     4
# PA     4
# IN     4
# MT     3
# NE     3
# WY     2
# SD     2
# ND     2
# IL     2
# GA     2
# OH     2
# WA     2
# MO     1
# MI     1
# SC     1
# NC     1
# FL     1
# AZ     1
# HI     1
# TN     1
# NY     1
# NJ     1
# KS     1
# Name: count, dtype: int64

# %%
# FEDERAL GOVERNMENT CONTRACTORS

df_fed_gov_contract = df_0291[df_0291["SIC6_DESCRIPTIONS (SIC)"] == "FEDERAL GOVERNMENT CONTRACTORS"]

df_fed_gov_contract["STATE"].value_counts()
# Out:
# STATE
# CA    7
# MT    3
# AZ    3
# FL    2
# TX    2
# MO    2
# SD    1
# NE    1
# IL    1
# OR    1
# CO    1
# OK    1
# WY    1
# LA    1
# VT    1
# AK    1
# HI    1
# WA    1
# Name: count, dtype: int64
